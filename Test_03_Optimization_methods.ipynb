# %%
import MyNN
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import sklearn.linear_model

# %matplotlib inline

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[0, :].min() - 0.2, X[0, :].max() + 0.2
    y_min, y_max = X[1, :].min() - 0.2, X[1, :].max() + 0.2
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[0, :], X[1, :], c=y, cmap=plt.cm.Spectral)

def predict(model, X):
    Z = model.forward(X)
    pred = (Z>0.5)
    return pred

# %%
train_X, train_Y = sklearn.datasets.make_moons(n_samples=300, noise=0.2)
plt.scatter(train_X[:,0], train_X[:,1], c=train_Y, s=40, cmap=plt.cm.Spectral)
train_X = train_X.T
train_Y = train_Y.T.reshape((1,300))

# %%
nn = MyNN.MyNN(2)
nn.add(5, "ReLU")
nn.add(2, 'ReLU')
nn.add(1, 'Sigmoid')
nn.compile('Cross entropy', "GD")

# %%
nn.optimize(train_X, train_Y, lr=0.0007, num_epochs=10000, batch_size=64, report_cost=True, report_cost_freq=1000)
# Out:
# Cost after 1 iterations: 0.7366459323027029
# Cost after 1000 iterations: 0.7195251773959277
# Cost after 2000 iterations: 0.6712941787188875
# Cost after 3000 iterations: 0.5656623308161792
# Cost after 4000 iterations: 0.47240880622963705
# Cost after 5000 iterations: 0.4183883361201763
# Cost after 6000 iterations: 0.3895463957078847
# Cost after 7000 iterations: 0.3597281905321559
# Cost after 8000 iterations: 0.3572628266107541
# Cost after 9000 iterations: 0.3495182620627257
# Cost after 10000 iterations: 0.33897249910990257

# %%
plot_decision_boundary(lambda x: predict(nn, x.T), train_X, train_Y)
# Out:
# /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
nn = MyNN.MyNN(2)
nn.add(5, "ReLU")
nn.add(2, 'ReLU')
nn.add(1, 'Sigmoid')
nn.compile('Cross entropy', "GDwM")

# %%
nn.optimize(train_X, train_Y, lr=0.0007, num_epochs=10000, batch_size=64, report_cost=True, report_cost_freq=1000)
# Out:
# Cost after 1 iterations: 0.7742322317285685
# Cost after 1000 iterations: 0.741750782607992
# Cost after 2000 iterations: 0.7374119017705575
# Cost after 3000 iterations: 0.7250784364936532
# Cost after 4000 iterations: 0.6587267215963251
# Cost after 5000 iterations: 0.51710188722071
# Cost after 6000 iterations: 0.4216250905051138
# Cost after 7000 iterations: 0.3773429948380119
# Cost after 8000 iterations: 0.34658959472741036
# Cost after 9000 iterations: 0.3360033521871568
# Cost after 10000 iterations: 0.34560152345463907

# %%
plot_decision_boundary(lambda x: predict(nn, x.T), train_X, train_Y)
# Out:
# /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
nn = MyNN.MyNN(2)
nn.add(5, "ReLU")
nn.add(2, 'ReLU')
nn.add(1, 'Sigmoid')
nn.compile('Cross entropy', "Adam")

# %%
nn.optimize(train_X, train_Y, lr=0.0007, num_epochs=10000, batch_size=64, report_cost=True, report_cost_freq=1000)
# Out:
# Cost after 1 iterations: 0.7856849860156198
# Cost after 1000 iterations: 0.22382303025370898
# Cost after 2000 iterations: 0.14315013454608908
# Cost after 3000 iterations: 0.11013244838280596
# Cost after 4000 iterations: 0.10669551441087118
# Cost after 5000 iterations: 0.11321066880286222
# Cost after 6000 iterations: 0.11452618264790611
# Cost after 7000 iterations: 0.11230045154966713
# Cost after 8000 iterations: 0.10433718093776781
# Cost after 9000 iterations: 0.10710953142182776
# Cost after 10000 iterations: 0.10581686532595463

# %%
plot_decision_boundary(lambda x: predict(nn, x.T), train_X, train_Y)
# Out:
# /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
