# %%
import MyNN
import gym
import numpy as np
from collections import deque
import _pickle as pickle

import matplotlib.pyplot as plt

# %%
class ACAgent:
    def __init__(self, state_size, action_size, variances, gamma=0.995, lam=0.98,
                 actor_lr=0.001, critic_lr=0.001, method='PPO_CEM', logvar_speed=50):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma  # discount rate
        self.lam = lam # GAE disc rate
        self.method = method
        self.actor = self._build_model()
        self.critic = self._build_vf()
        self.actor.lr = actor_lr
        self.critic.lr = critic_lr
        self.scaler = MyNN.Scaler(state_size)
        self.variances = variances
        self.replay_buff_x = None
        self.replay_buff_y = None
        self.n_updates = 0
        self.grads_velo = np.zeros(variances.shape)
        self.grads_vars = np.zeros(variances.shape)
        self.var_save = None
        self.logwar_speed = logvar_speed
        self.logger = {'scores' :[] , 'adv': [], 'grads' :[], 'results' : [], 'result': 0, 'vars' : [],
                       'mean_scores': deque(maxlen=10), 'solved' : False, 'five_games' : deque(maxlen=5),
                      'best_five':-1000, 'best_score':-1000, 'threshold_crossed': None, 'episodes_played':0}


    def _build_model(self):
        model = MyNN.MyNN(self.state_size+1)
        model.add((self.state_size+1)*10, 'Tanh')
        model.add(int(np.sqrt(self.action_size*(self.state_size+1))*10), 'Tanh')
        model.add(self.action_size*10, 'Tanh')
        model.add(self.action_size, 'Linear')
        model.compile(self.method, 'Adam')
        return model
    
    def _build_vf(self):
        model = MyNN.MyNN(self.state_size+1)
        model.add((self.state_size+1)*10, 'Tanh')
        model.add(int(np.sqrt(self.state_size*50)), 'Tanh')
        model.add(5, 'Tanh')
        model.add(1, 'Linear')
        model.compile('MSE', 'Adam')
        return model
    
    def value_function_fit(self, x, y):
        if self.replay_buff_x is None:
            x_train, y_train = x, y
        else:
            x_train = np.hstack([x, self.replay_buff_x])
            y_train = np.hstack([y, self.replay_buff_y])
        self.replay_buff_x = x
        self.replay_buff_y = y
        self.critic.optimize(x_train, y_train, num_epochs=10, 
                             report_cost=False, batch_size=256)

    def get_means(self, state):
        result = self.actor.forward(state, caching='no')
        return result
    
    def update_variances(self, actions, means, adv,old_means, old_var, prob_exp, beta, DKL, DKL_targ, eta):
        self.n_updates += 1
        var = self.variances
        n = means.shape[1]
        grads = np.square(actions-means)/var
        grads = (grads-1)/(2)
        grads = grads*adv*prob_exp
        DKL_term = (-1/2)*(1 - np.divide(np.square(means-old_means), var) - np.divide(old_var, var))*beta
        if DKL > DKL_targ*2:
            DKL_add_term = (-1/2)*(1 - np.divide(np.square(means-old_means), var) - np.divide(old_var, var))*eta*(2*DKL - 4*DKL_targ)
            DKL_term = DKL_term + DKL_add_term
        grads = (1/n)*(grads + DKL_term)
        grads = np.sum(grads, axis=1, keepdims=True)
        self.grads_velo = self.grads_velo*0.9 + 0.1*grads
        corrected_v = self.grads_velo/(1-0.9**self.n_updates)
        self.grads_vars = self.grads_vars*0.99 + 0.01*np.square(grads)
        corrected_b = self.grads_vars/(1-0.99**self.n_updates)
        self.variances = np.maximum((np.exp(np.log(var) + self.actor.lr*self.logwar_speed*corrected_v/(np.sqrt(corrected_b)+1e-8))), 0.001)
    
    def save(self, path):
        save_dict = {'act_size': self.action_size , 'state_size' : self.state_size, 'gamma' : self.gamma,
                    'lamda' : self.lam, 'actor_dict': self.actor.nn_to_dict(), 'critic_dict': self.critic.nn_to_dict(),
                    'scaler_tupl': self.scaler.save('aa', to_tupl=True), 'vars' : self.variances,
                    'buff_x': self.replay_buff_x, 'buff_y': self.replay_buff_y, 'n_updates' : self.n_updates,
                    'grads_velo' : self.grads_velo, 'grads_vars': self.grads_vars, 'logvar_speed':self.logwar_speed,
                    'logger' : self.logger}
        pickle.dump(save_dict, open(path, 'wb'))
    
    def load(self, path):
        save_dict = pickle.load(open(path, 'rb'))
        self.state_size = save_dict['state_size']
        self.action_size = save_dict['act_size']
        self.gamma = save_dict['gamma']
        self.lam = save_dict['lamda']
        self.actor.load('aa', save_dict['actor_dict'])
        self.critic.load('aa', save_dict['critic_dict'])
        self.scaler.load('aa', save_dict['scaler_tupl'])
        self.variances = save_dict['vars']
        self.replay_buff_x = save_dict['buff_x']
        self.replay_buff_y = save_dict['buff_y']
        self.n_updates = save_dict['n_updates']
        self.grads_velo = save_dict['grads_velo']
        self.grads_vars = save_dict['grads_vars']
        self.logwar_speed = save_dict['logvar_speed']
        self.logger = save_dict['logger']
    
    def quick_save(self):
        agent.actor.quick_save()
        self.var_save = (self.grads_velo, self.grads_vars, self.n_updates, self.variances)
    
    def quick_load(self):
        agent.actor.quick_load()
        (self.grads_velo, self.grads_vars, self.n_updates, self.variances) = self.var_save

# %%
def running_reward(rewards, gamma):
    result = []
    run_rew = 0
    for reward in  rewards[0,:][::-1]:
        run_rew = run_rew*gamma + reward
        result.append(run_rew)
    return np.array(result[::-1]).reshape(1,-1)

def add_gae(traj, gamma, lam):
    rewards = traj['rewards']*(1-gamma)
    values = traj['values']
    traj['tds'] = rewards - values + np.append(traj['values'][0, 1:] * agent.gamma, 0).reshape(1,-1)
    gae = running_reward(traj['tds'], gamma*lam)
    return gae

def compute_DKL(means0, means1, vars0, vars1):
    k = means0.shape[0]
    tr = np.sum(np.divide(vars0, vars1))
    means = np.sum(np.divide(np.square(means1-means0), vars1))
    logs = np.log(np.prod(vars1)) - np.log(np.prod(vars0))
    result = 0.5*(tr + means - k + logs)
    return result/means0.shape[1]

# %%
def play_game(agent, render=False):
    state = env.reset().reshape((agent.state_size,1))
    unscaled_states = []
    states = []
    meanss = []
    actions = []
    rewards = []
    done = False
    mean, var = agent.scaler.get()
    time = 0.0
    while not done:
        if render:
            env.render()
        unscaled_states.append(state)
        scaled_state = np.vstack(((state-mean)/var, [[time]]))
        states.append(scaled_state)
        means = agent.get_means(scaled_state)
        meanss.append(means)
        action = means + agent.variances*np.random.normal(size=(agent.action_size,1))
        actions.append(action)
        state, reward, done, _ = env.step(action.T)
        state = state.reshape((agent.state_size,1))
        rewards.append(reward)
        time += 1e-3
        if done:
            break
    return {'unscaled': np.hstack(unscaled_states), 'states' : np.hstack(states),
            'means': np.hstack(meanss), 'actions': np.hstack(actions),
            'rewards': np.array(rewards).reshape(1,-1)}

# %%
def play_n_games(agent, n=20):
    trajectories = []
    for i in range(n):
        trajectory = play_game(agent)
        trajectories.append(trajectory)
        
        agent.logger['episodes_played'] += 1
        result = np.sum(trajectory['rewards'])
        agent.logger['five_games'].append(result)
        if np.mean(agent.logger['five_games']) > agent.logger['best_five']:
            agent.logger['best_five'] = np.mean(agent.logger['five_games'])
            
        if result > agent.logger['threshold'] and (agent.logger['threshold_crossed'] is None):
            agent.logger['threshold_crossed'] = agent.logger['episodes_played']
    return trajectories

# %%
def build_train_set(agent, trajectories):
    for traj in trajectories:
        traj['disc_sum_rew'] = running_reward(traj['rewards']*(1-agent.gamma), agent.gamma)
        traj['values'] = agent.critic.forward(traj['states'])
        traj['GAE'] = add_gae(traj, agent.gamma, agent.lam)
    X = np.hstack([t['states'] for t in trajectories])
    Y = np.hstack([t['means'] for t in trajectories])
    actions = np.hstack([t['actions'] for t in trajectories])
    disc_sum_rew = np.hstack([t['disc_sum_rew'] for t in trajectories])
    adv = np.hstack([t['GAE'] for t in trajectories])
    adv = (adv - adv.mean())/(adv.std() + 1e-6)
    return X, Y, actions, adv, disc_sum_rew

# %%
env = gym.make('Hopper-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.shape[0]
variances = np.exp(np.zeros((action_size,1)))

base_lr = 9e-4/np.sqrt(int(np.sqrt(action_size*state_size)*10))
vf_lr = 1e-2/np.sqrt(int(np.sqrt(state_size*50)))
logvar_speed = (action_size*100)//48
n_episods = 20

agent = ACAgent(state_size, action_size, actor_lr=base_lr,
                critic_lr=vf_lr, gamma=0.995, lam=0.98, method='Cont_PPO',
               variances= variances, logvar_speed = logvar_speed)
d = {'beta': 1, 'eta':50, 'DKL_targ' : 0.003}

# %%
agent.logger['threshold'] = 2000
solved_score = 3500

trajectories = play_n_games(agent, n=n_episods)
score = np.mean([(np.sum(t['rewards']), np.var(t['rewards'])) for t in trajectories], axis=0)

agent.logger['episodes_played'] = 0
agent.logger['result'] = score[0]

# %%
# %%time
for time in range(1, 30000//n_episods+1):
    trajectories = play_n_games(agent, n=n_episods)
    agent.scaler.update(np.hstack([t['unscaled'] for t in trajectories]))
    score = np.mean([(np.sum(t['rewards']), np.var(t['rewards'])) for t in trajectories], axis=0)
    agent.logger['scores'].append(score)
    X_batch, d['old_means'], d['actions'], d['adv'], disc_sum_rew = build_train_set(agent, trajectories)
    d['old_vars'] = agent.variances
    print(time, score[0])
    
    i = 1
    agent.quick_save()
    save_beta = d['beta']
    
    while i < 21:
        restart = False
        d['means'] = agent.actor.forward(X_batch)
        agent.actor.cache['A0'] = X_batch
        d['vars'] = agent.variances
        d['DKL'] = compute_DKL(d['old_means'], d['means'], d['old_vars'], d['vars'])
        
        if i > 10 and d['DKL'] > d['DKL_targ']*4:
            print('DKL diverges badly, loading earlier version, increasing beta and starting training again')
            restart = True
            adj_lr = agent.actor.lr
            d['beta'] = np.minimum(35, d['beta']*1.5)
            if d['beta'] > 30:
                adj_lr = np.maximum(agent.actor.lr/1.5, base_lr*0.1)
                if adj_lr < base_lr*0.11:
                    print('Skipping current set of gradients, restore agent and beta')
                    agent.quick_load()
                    pickle.dump(d, open('spoiled_dict_'+str(time), 'wb'))
                    d['beta'] = save_beta
                    break
                print('Decreasing learning rate, currnet lr multipler is {}'.format(adj_lr/base_lr))
            agent.quick_load()
            agent.actor.lr = adj_lr
            i = 1
        
        if not restart:
            log_p = -0.5*(np.log(d['vars']) + np.divide(np.square(d['actions'] - d['means']), d['vars']))
            log_old_p = -0.5*(np.log(d['old_vars']) + np.divide(np.square(d['actions'] - d['old_means']), d['old_vars']))
            d['prob_exp'] = np.exp(log_p - log_old_p)
            agent.logger['adv'].append([np.min(d['adv']), np.max(d['adv']), np.mean(np.abs(d['adv']))])
            grads = agent.actor.get_grads(d)
            agent.logger['grads'].append([np.min(grads), np.max(grads), np.mean(grads), np.mean(np.abs(grads))])
            agent.actor.backward(_, _, _, grads=grads)
            agent.actor.number_of_updates +=1
            agent.actor.update_parameters()
            agent.update_variances(d['actions'], d['means'], d['adv'], d['old_means'],
                                   d['old_vars'], d['prob_exp'], d['beta'], d['DKL'], d['DKL_targ'], d['eta'])
            i += 1
        
    if d['DKL'] > d['DKL_targ']*2:
        d['beta'] = np.minimum(35, d['beta']*1.5)
        print('Increasing beta')
        if d['beta'] > 30 and agent.actor.lr>base_lr*0.05:
            agent.actor.lr = np.maximum(agent.actor.lr/1.5, base_lr*0.1)
            print('Decreasing learning rate')
    elif d['DKL'] < d['DKL_targ']*0.5:
        d['beta'] = np.maximum(1/35, d['beta']/1.5)
        print('Decreasing beta')
        if d['beta'] < 1/30 and agent.actor.lr<base_lr*20:
            agent.actor.lr = np.minimum(agent.actor.lr*1.5, base_lr*10)
            print('Increasing learning rate')
    else:
        print('Beta remains the same')
    
    if score[0] > agent.logger['best_score']:
        agent.save('best')
        agent.logger['best_score'] = score[0]
    
    agent.logger['mean_scores'].append(score[0])
    if np.mean(agent.logger['mean_scores']) >= solved_score:
        agent.logger['solved'] = True
        
    agent.value_function_fit(X_batch, disc_sum_rew)
    agent.logger['result'] = agent.logger['result']*0.98+score[0]*0.02
    agent.logger['results'].append(agent.logger['result'])
    agent.logger['vars'].append(agent.variances)
    
    print('DKL:{:f}, lr_mlt: {:f}, beta: {:f}'.format(d['DKL'], agent.actor.lr/base_lr, d['beta']))
    print('********************************')

if agent.logger['solved']:
    print('Environment is solved')
# Out:
# 1 13.667563553080246
# Increasing beta
# DKL:0.010099, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 2 17.940991196775634
# Beta remains the same
# DKL:0.005496, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 3 14.606043052138876
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Increasing beta
# DKL:0.009035, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 4 19.513982251966258
# Beta remains the same
# DKL:0.003286, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 5 22.95548067670884
# Beta remains the same
# DKL:0.002616, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 6 18.34146478372509
# Beta remains the same
# DKL:0.004988, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 7 33.15765913812268
# Beta remains the same
# DKL:0.003919, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 8 22.33836631374681
# Beta remains the same
# DKL:0.001809, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 9 30.34798168804973
# Beta remains the same
# DKL:0.004208, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 10 24.513282364288205
# Beta remains the same
# DKL:0.004321, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 11 39.3474059270212
# Beta remains the same
# DKL:0.004446, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 12 47.9333826509903
# Beta remains the same
# DKL:0.002904, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 13 53.26015880311655
# Beta remains the same
# DKL:0.003547, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 14 58.14143831768547
# Beta remains the same
# DKL:0.003324, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 15 77.45442067898692
# Beta remains the same
# DKL:0.002611, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 16 65.67865772118628
# Beta remains the same
# DKL:0.003016, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 17 112.77422985313665
# Beta remains the same
# DKL:0.002333, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 18 107.98940113622216
# Beta remains the same
# DKL:0.002312, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 19 109.42333649439611
# Beta remains the same
# DKL:0.003155, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 20 129.67502425281305
# Decreasing beta
# DKL:0.001422, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 21 146.48020548796106
# Increasing beta
# DKL:0.006588, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 22 134.6145839725745
# Beta remains the same
# DKL:0.003274, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 23 161.7819831283768
# Beta remains the same
# DKL:0.002396, lr_mlt: 1.000000, beta: 3.375000
# ********************************
# 24 154.4514449680613
# Decreasing beta
# DKL:0.001128, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 25 173.38015712283513
# Beta remains the same
# DKL:0.002917, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 26 163.85401218950307
# Beta remains the same
# DKL:0.003547, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 27 184.38086730368292
# Beta remains the same
# DKL:0.002168, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 28 183.56503271436335
# Beta remains the same
# DKL:0.004662, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 29 192.48582096415151
# Beta remains the same
# DKL:0.002405, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 30 183.03831457501488
# Beta remains the same
# DKL:0.002652, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 31 202.35917918585787
# Beta remains the same
# DKL:0.003082, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 32 202.47896994591125
# Beta remains the same
# DKL:0.002955, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 33 201.16636981256627
# Beta remains the same
# DKL:0.002728, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 34 205.8690542739956
# Beta remains the same
# DKL:0.001518, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 35 207.08777047148754
# Beta remains the same
# DKL:0.002962, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 36 202.65977012846278
# Beta remains the same
# DKL:0.002131, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 37 195.43809432683472
# Beta remains the same
# DKL:0.003248, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 38 203.16067821465094
# Beta remains the same
# DKL:0.002719, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 39 211.2095534040522
# Beta remains the same
# DKL:0.002682, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 40 212.6597128618202
# Beta remains the same
# DKL:0.001822, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 41 212.673990844459
# Beta remains the same
# DKL:0.002674, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 42 211.25101451126034
# Beta remains the same
# DKL:0.002840, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 43 217.77659486081876
# Beta remains the same
# DKL:0.002224, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 44 215.68953955280261
# Decreasing beta
# DKL:0.001410, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 45 221.9974266208397
# Increasing beta
# DKL:0.007027, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 46 226.56939493833428
# Beta remains the same
# DKL:0.001932, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 47 224.84227988776402
# Beta remains the same
# DKL:0.002264, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 48 231.4476344660919
# Beta remains the same
# DKL:0.002083, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 49 231.58277903978447
# Beta remains the same
# DKL:0.004195, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 50 238.59580085844513
# Beta remains the same
# DKL:0.004834, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 51 238.09000277161869
# Beta remains the same
# DKL:0.002127, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 52 247.4890170701106
# Beta remains the same
# DKL:0.002940, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 53 247.77329313540517
# Beta remains the same
# DKL:0.005913, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 54 260.24274504188736
# Beta remains the same
# DKL:0.003469, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 55 250.81632556884261
# Beta remains the same
# DKL:0.001942, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 56 256.4508655957429
# Beta remains the same
# DKL:0.002221, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 57 259.33234099043284
# Beta remains the same
# DKL:0.002757, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 58 258.4690310907355
# Beta remains the same
# DKL:0.001690, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 59 261.9470655036499
# Beta remains the same
# DKL:0.004124, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 60 274.33846298637843
# Beta remains the same
# DKL:0.005410, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 61 264.2067743021837
# Beta remains the same
# DKL:0.001728, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 62 267.18085075581746
# Decreasing beta
# DKL:0.001414, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 63 279.1723054584671
# Increasing beta
# DKL:0.007013, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 64 285.1941260196042
# Beta remains the same
# DKL:0.004277, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 65 294.9710928032547
# Beta remains the same
# DKL:0.004859, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 66 315.27575102231657
# Beta remains the same
# DKL:0.003536, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 67 325.3218933716465
# Beta remains the same
# DKL:0.004065, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 68 356.34415324864835
# Beta remains the same
# DKL:0.002505, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 69 348.45433581242304
# Decreasing beta
# DKL:0.001279, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 70 343.91884649851175
# Beta remains the same
# DKL:0.005022, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 71 362.0628801517404
# Beta remains the same
# DKL:0.001821, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 72 357.48869279704866
# Beta remains the same
# DKL:0.004557, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 73 354.7105432582581
# Beta remains the same
# DKL:0.003200, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 74 379.5603957968057
# Beta remains the same
# DKL:0.005340, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 75 382.5956615733738
# Beta remains the same
# DKL:0.003948, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 76 386.76980983631836
# Beta remains the same
# DKL:0.004204, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 77 389.8542059275726
# Beta remains the same
# DKL:0.003634, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 78 399.9649463873488
# Beta remains the same
# DKL:0.004223, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 79 408.3450216526774
# Beta remains the same
# DKL:0.005003, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 80 413.83912255418346
# Beta remains the same
# DKL:0.003505, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 81 425.2267377676545
# Beta remains the same
# DKL:0.003096, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 82 423.8750284385819
# Beta remains the same
# DKL:0.004977, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 83 431.4148858463683
# Beta remains the same
# DKL:0.002830, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 84 445.05032847830626
# Beta remains the same
# DKL:0.004602, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 85 450.19991171610957
# Beta remains the same
# DKL:0.002862, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 86 449.4483589510131
# Beta remains the same
# DKL:0.003394, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 87 456.3666988936212
# Increasing beta
# DKL:0.009965, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 88 455.8197425510919
# Beta remains the same
# DKL:0.002393, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 89 459.37227836225946
# Beta remains the same
# DKL:0.003017, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 90 471.7580931281826
# Beta remains the same
# DKL:0.002204, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 91 466.77266117565557
# Beta remains the same
# DKL:0.002800, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 92 473.97916800051615
# Beta remains the same
# DKL:0.003208, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 93 493.72008170337057
# Beta remains the same
# DKL:0.002028, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 94 496.7835358017417
# Beta remains the same
# DKL:0.001936, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 95 508.03217721602493
# Beta remains the same
# DKL:0.002095, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 96 505.12404537757004
# Beta remains the same
# DKL:0.002152, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 97 501.2799081971901
# Beta remains the same
# DKL:0.003345, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 98 534.4874595635159
# Beta remains the same
# DKL:0.002470, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 99 537.9820232335891
# Beta remains the same
# DKL:0.002101, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 100 553.0271914168222
# Beta remains the same
# DKL:0.003590, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 101 545.4218950814112
# Beta remains the same
# DKL:0.001840, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 102 547.6506615105898
# Beta remains the same
# DKL:0.002439, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 103 568.5269508195745
# Beta remains the same
# DKL:0.002212, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 104 570.2587951956756
# Beta remains the same
# DKL:0.001980, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 105 556.4952048416061
# Decreasing beta
# DKL:0.001108, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 106 552.2969200426322
# Beta remains the same
# DKL:0.004126, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 107 566.8934198378108
# Beta remains the same
# DKL:0.002794, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 108 577.6609114404991
# Beta remains the same
# DKL:0.003609, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 109 590.4909380412638
# Beta remains the same
# DKL:0.002595, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 110 589.0658826677358
# Beta remains the same
# DKL:0.003523, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 111 607.4201001733006
# Beta remains the same
# DKL:0.002458, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 112 612.3982505939815
# Beta remains the same
# DKL:0.003098, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 113 608.2190038951713
# Beta remains the same
# DKL:0.003328, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 114 625.8620111917301
# Beta remains the same
# DKL:0.003627, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 115 621.0141138653877
# Beta remains the same
# DKL:0.003159, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 116 644.291728773795
# Beta remains the same
# DKL:0.003972, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 117 631.0673664564019
# Beta remains the same
# DKL:0.002809, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 118 642.5051243861093
# Beta remains the same
# DKL:0.003105, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 119 669.6645235742919
# Beta remains the same
# DKL:0.002681, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 120 646.1611426253415
# Beta remains the same
# DKL:0.003207, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 121 636.7270225846646
# Beta remains the same
# DKL:0.003694, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 122 641.4580965692801
# Beta remains the same
# DKL:0.004915, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 123 641.0012037752152
# Beta remains the same
# DKL:0.003630, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 124 651.2507599192288
# Beta remains the same
# DKL:0.002277, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 125 673.4008696702608
# Beta remains the same
# DKL:0.002597, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 126 650.9752993400687
# Beta remains the same
# DKL:0.003208, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 127 650.443237212471
# Beta remains the same
# DKL:0.003122, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 128 658.4292991825871
# Beta remains the same
# DKL:0.001609, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 129 673.3382729891497
# Beta remains the same
# DKL:0.002910, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 130 666.0878157243939
# Beta remains the same
# DKL:0.003175, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 131 688.1164225260861
# Beta remains the same
# DKL:0.003243, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 132 679.1724593296377
# Beta remains the same
# DKL:0.005083, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 133 676.9211837149868
# Beta remains the same
# DKL:0.002469, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 134 699.1541068354562
# Beta remains the same
# DKL:0.002093, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 135 661.4741075054915
# Beta remains the same
# DKL:0.005571, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 136 697.4391975461677
# Beta remains the same
# DKL:0.002551, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 137 700.6635606405158
# Beta remains the same
# DKL:0.001696, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 138 696.0110060929431
# Beta remains the same
# DKL:0.002644, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 139 712.4699137829884
# Beta remains the same
# DKL:0.003297, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 140 681.5485506598054
# Beta remains the same
# DKL:0.002447, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 141 703.9565757336961
# Beta remains the same
# DKL:0.002169, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 142 707.9924659833267
# Beta remains the same
# DKL:0.004897, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 143 716.6389389073396
# Beta remains the same
# DKL:0.003096, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 144 719.2518082256872
# Beta remains the same
# DKL:0.002950, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 145 711.4273609426021
# Beta remains the same
# DKL:0.003014, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 146 720.5980182239673
# Beta remains the same
# DKL:0.002408, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 147 698.6315733773129
# Beta remains the same
# DKL:0.003659, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 148 727.0891050340347
# Beta remains the same
# DKL:0.003517, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 149 730.472182360241
# Beta remains the same
# DKL:0.002535, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 150 721.9575618590783
# Beta remains the same
# DKL:0.003032, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 151 714.0299708454806
# Beta remains the same
# DKL:0.003447, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 152 731.0484615332991
# Beta remains the same
# DKL:0.004914, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 153 737.4811105558972
# Beta remains the same
# DKL:0.002606, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 154 730.3079338091375
# Beta remains the same
# DKL:0.002996, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 155 748.3729849570935
# Beta remains the same
# DKL:0.003271, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 156 760.7290132642817
# Beta remains the same
# DKL:0.003395, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 157 738.5857277519187
# Beta remains the same
# DKL:0.002094, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 158 778.308482759816
# Beta remains the same
# DKL:0.002955, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 159 749.9235725171463
# Beta remains the same
# DKL:0.001891, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 160 759.4892106102891
# Beta remains the same
# DKL:0.002149, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 161 748.0951168058256
# Beta remains the same
# DKL:0.002865, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 162 776.6957801976962
# Beta remains the same
# DKL:0.003064, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 163 780.4631570719357
# Beta remains the same
# DKL:0.002642, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 164 807.5242883317584
# Beta remains the same
# DKL:0.001933, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 165 826.4280741608205
# Beta remains the same
# DKL:0.002168, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 166 800.6791554432539
# Beta remains the same
# DKL:0.002548, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 167 805.6365561623245
# Beta remains the same
# DKL:0.002617, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 168 779.4511990135336
# Beta remains the same
# DKL:0.002800, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 169 818.0883302819059
# Beta remains the same
# DKL:0.002085, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 170 797.1872246970418
# Beta remains the same
# DKL:0.002874, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 171 856.5776899000945
# Beta remains the same
# DKL:0.002239, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 172 829.3455017403542
# Beta remains the same
# DKL:0.002388, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 173 855.8566609539446
# Beta remains the same
# DKL:0.002699, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 174 809.6544216787604
# Beta remains the same
# DKL:0.002161, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 175 862.4413409347064
# Beta remains the same
# DKL:0.002458, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 176 860.941704006948
# Beta remains the same
# DKL:0.003299, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 177 818.451385989167
# Beta remains the same
# DKL:0.002529, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 178 857.2259563639375
# Beta remains the same
# DKL:0.003221, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 179 885.0472733081994
# Beta remains the same
# DKL:0.002030, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 180 900.5827375479676
# Beta remains the same
# DKL:0.002626, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 181 855.9877899736579
# Beta remains the same
# DKL:0.002962, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 182 853.5657167692103
# Beta remains the same
# DKL:0.002277, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 183 917.1283584886849
# Beta remains the same
# DKL:0.002299, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 184 878.142128653297
# Beta remains the same
# DKL:0.004581, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 185 884.4585859326514
# Beta remains the same
# DKL:0.002524, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 186 870.9256113663229
# Beta remains the same
# DKL:0.002496, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 187 919.4889052171554
# Beta remains the same
# DKL:0.002233, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 188 915.3839134180838
# Beta remains the same
# DKL:0.002376, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 189 909.4891145905673
# Beta remains the same
# DKL:0.002364, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 190 874.7030591940344
# Beta remains the same
# DKL:0.002901, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 191 911.2107857135913
# Beta remains the same
# DKL:0.004531, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 192 913.5670150273005
# Beta remains the same
# DKL:0.002200, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 193 919.8703169988673
# Beta remains the same
# DKL:0.001920, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 194 916.8778228163701
# Beta remains the same
# DKL:0.002114, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 195 939.54351482189
# Beta remains the same
# DKL:0.002491, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 196 936.9098772615376
# Beta remains the same
# DKL:0.002550, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 197 924.6492929873863
# Beta remains the same
# DKL:0.003292, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 198 908.1065317727993
# Beta remains the same
# DKL:0.002072, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 199 938.1700189408708
# Beta remains the same
# DKL:0.002105, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 200 947.5533262815846
# Beta remains the same
# DKL:0.002329, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 201 942.4117754562337
# Beta remains the same
# DKL:0.003839, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 202 893.6858572271312
# Beta remains the same
# DKL:0.002552, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 203 955.3073724962311
# Beta remains the same
# DKL:0.003332, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 204 915.040802979615
# Beta remains the same
# DKL:0.002181, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 205 912.7830131705216
# Beta remains the same
# DKL:0.002276, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 206 932.2137444429915
# Beta remains the same
# DKL:0.002487, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 207 949.7379288298725
# Beta remains the same
# DKL:0.002121, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 208 935.2159461978647
# Beta remains the same
# DKL:0.002364, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 209 897.3310347245794
# Beta remains the same
# DKL:0.005119, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 210 929.0370749362534
# Beta remains the same
# DKL:0.002081, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 211 934.677471725328
# Beta remains the same
# DKL:0.002176, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 212 956.9040917692339
# Beta remains the same
# DKL:0.002368, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 213 962.4668450328667
# Beta remains the same
# DKL:0.003279, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 214 936.8910810302013
# Beta remains the same
# DKL:0.002796, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 215 925.7885914548757
# Beta remains the same
# DKL:0.002715, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 216 964.5979311793384
# Beta remains the same
# DKL:0.001948, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 217 939.4953454076731
# Beta remains the same
# DKL:0.002585, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 218 933.3331584441718
# Beta remains the same
# DKL:0.001556, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 219 915.8725676476631
# Beta remains the same
# DKL:0.003715, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 220 945.2764061351343
# Beta remains the same
# DKL:0.002697, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 221 927.4304998857264
# Beta remains the same
# DKL:0.002361, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 222 954.2262837945993
# Beta remains the same
# DKL:0.001943, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 223 970.7294316405838
# Beta remains the same
# DKL:0.002240, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 224 943.4880009179999
# Beta remains the same
# DKL:0.002361, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 225 939.4761339949004
# Beta remains the same
# DKL:0.001949, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 226 964.8074729778975
# Beta remains the same
# DKL:0.001949, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 227 937.8732499262908
# Beta remains the same
# DKL:0.002284, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 228 950.6373649975255
# Beta remains the same
# DKL:0.002184, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 229 950.6973306811702
# Decreasing beta
# DKL:0.001370, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 230 951.8015357347124
# Beta remains the same
# DKL:0.004815, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 231 966.0630483573188
# Beta remains the same
# DKL:0.004789, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 232 950.4300017815913
# Beta remains the same
# DKL:0.005790, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 233 972.0281533514019
# Increasing beta
# DKL:0.006071, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 234 977.5223467716156
# Beta remains the same
# DKL:0.002440, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 235 965.8324378930349
# Beta remains the same
# DKL:0.001620, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 236 961.548950387118
# Beta remains the same
# DKL:0.002685, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 237 964.2552708683504
# Beta remains the same
# DKL:0.002189, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 238 989.8640248821044
# Beta remains the same
# DKL:0.001957, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 239 985.8867031560407
# Beta remains the same
# DKL:0.002033, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 240 1002.3366689202052
# Beta remains the same
# DKL:0.002439, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 241 991.2628672327655
# Beta remains the same
# DKL:0.002376, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 242 999.2634590492144
# Beta remains the same
# DKL:0.002382, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 243 933.4259507250092
# Beta remains the same
# DKL:0.002937, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 244 991.428622407619
# Beta remains the same
# DKL:0.002589, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 245 981.510494639813
# Beta remains the same
# DKL:0.002174, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 246 958.7864597470628
# Beta remains the same
# DKL:0.004823, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 247 985.1168528372888
# Beta remains the same
# DKL:0.001779, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 248 1009.6610453039102
# Beta remains the same
# DKL:0.001784, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 249 987.6488511412657
# Beta remains the same
# DKL:0.003136, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 250 982.8800009961994
# Beta remains the same
# DKL:0.002468, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 251 990.6175801875949
# Beta remains the same
# DKL:0.003042, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 252 950.5127569403405
# Beta remains the same
# DKL:0.002609, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 253 1034.958704981802
# Beta remains the same
# DKL:0.002115, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 254 1018.4633318236602
# Beta remains the same
# DKL:0.003231, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 255 932.6577714789779
# Increasing beta
# DKL:0.006284, lr_mlt: 1.000000, beta: 2.250000
# ********************************
# 256 1003.233378930099
# Decreasing beta
# DKL:0.001003, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 257 1028.464944431241
# Beta remains the same
# DKL:0.002148, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 258 1042.5001228329852
# Beta remains the same
# DKL:0.002701, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 259 1015.7004106061601
# Beta remains the same
# DKL:0.002457, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 260 1077.9406656731403
# Beta remains the same
# DKL:0.002384, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 261 1122.326657620958
# Beta remains the same
# DKL:0.002284, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 262 1095.9228451679087
# Beta remains the same
# DKL:0.002680, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 263 1099.5024459273789
# Beta remains the same
# DKL:0.002120, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 264 1133.0882038830844
# Beta remains the same
# DKL:0.001996, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 265 1117.6648667518639
# Beta remains the same
# DKL:0.001704, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 266 1128.7443719951111
# Beta remains the same
# DKL:0.002231, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 267 1143.983697183152
# Beta remains the same
# DKL:0.001950, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 268 1079.2538633957843
# Beta remains the same
# DKL:0.002657, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 269 1025.818133381123
# Beta remains the same
# DKL:0.002543, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 270 1165.0835029423542
# Beta remains the same
# DKL:0.002180, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 271 1162.8328285787877
# Beta remains the same
# DKL:0.001975, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 272 1183.4606813276957
# Beta remains the same
# DKL:0.001649, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 273 1152.5415769979127
# Beta remains the same
# DKL:0.001754, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 274 1173.8040908900064
# Beta remains the same
# DKL:0.002074, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 275 1253.674002694509
# Beta remains the same
# DKL:0.001946, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 276 1165.9889582349228
# Beta remains the same
# DKL:0.002640, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 277 1224.233647942528
# Beta remains the same
# DKL:0.002263, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 278 1189.519335680307
# Beta remains the same
# DKL:0.002095, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 279 1229.1439646129288
# Beta remains the same
# DKL:0.002167, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 280 1245.966006644619
# Beta remains the same
# DKL:0.001831, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 281 1249.0791928444762
# Beta remains the same
# DKL:0.002127, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 282 1286.6728583155393
# Beta remains the same
# DKL:0.002479, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 283 1159.756445672821
# Beta remains the same
# DKL:0.002585, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 284 1266.568132585438
# Beta remains the same
# DKL:0.002255, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 285 1216.1777693432655
# Beta remains the same
# DKL:0.001613, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 286 1352.166755083936
# Beta remains the same
# DKL:0.002361, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 287 1378.563671028114
# Beta remains the same
# DKL:0.001732, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 288 1275.0863094775875
# Beta remains the same
# DKL:0.001706, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 289 1305.8097877900445
# Beta remains the same
# DKL:0.002023, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 290 1290.031132895475
# Beta remains the same
# DKL:0.002496, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 291 1434.7926345125265
# Decreasing beta
# DKL:0.001393, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 292 1217.2592358314057
# Beta remains the same
# DKL:0.002480, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 293 1339.091078471433
# Beta remains the same
# DKL:0.003146, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 294 1264.5562097464676
# Beta remains the same
# DKL:0.004047, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 295 1366.9593257409952
# Beta remains the same
# DKL:0.002812, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 296 1643.5159543386349
# Beta remains the same
# DKL:0.002708, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 297 1469.0902580322079
# Beta remains the same
# DKL:0.003961, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 298 1374.4862373572375
# Beta remains the same
# DKL:0.003323, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 299 1357.1522520674125
# Beta remains the same
# DKL:0.005330, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 300 1275.4446066623946
# Beta remains the same
# DKL:0.003256, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 301 1422.7600680857568
# Beta remains the same
# DKL:0.002365, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 302 1432.3215021956098
# Beta remains the same
# DKL:0.004088, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 303 1382.0381199312992
# Beta remains the same
# DKL:0.003994, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 304 1378.8003155409012
# Beta remains the same
# DKL:0.004411, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 305 1304.2566240843162
# Beta remains the same
# DKL:0.003020, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 306 1548.4876742809715
# Beta remains the same
# DKL:0.002735, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 307 1372.1914526066432
# Beta remains the same
# DKL:0.003383, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 308 1361.0151648461854
# Beta remains the same
# DKL:0.003187, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 309 1306.0279276313663
# Beta remains the same
# DKL:0.003348, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 310 1261.3472354634748
# Beta remains the same
# DKL:0.003161, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 311 1377.5436636329594
# Beta remains the same
# DKL:0.003397, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 312 1554.3442513774514
# Beta remains the same
# DKL:0.002069, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 313 1575.8820798185684
# Beta remains the same
# DKL:0.002878, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 314 1632.8477695909598
# Beta remains the same
# DKL:0.003525, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 315 1490.1995928893073
# Beta remains the same
# DKL:0.002822, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 316 1326.4959676193412
# Beta remains the same
# DKL:0.004191, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 317 1421.5818957798979
# Beta remains the same
# DKL:0.003875, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 318 1517.8375648741367
# Beta remains the same
# DKL:0.002559, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 319 1537.829802988391
# Beta remains the same
# DKL:0.002635, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 320 1512.1767461840375
# Beta remains the same
# DKL:0.005337, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 321 1606.063314508516
# Beta remains the same
# DKL:0.003396, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 322 1530.0636566760566
# Beta remains the same
# DKL:0.003979, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 323 1518.6286789853875
# Beta remains the same
# DKL:0.003561, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 324 1447.7046391057365
# Beta remains the same
# DKL:0.004695, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 325 1640.8830806064936
# Beta remains the same
# DKL:0.004159, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 326 1483.9256947917675
# Increasing beta
# DKL:0.008826, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 327 1554.7964867896524
# Beta remains the same
# DKL:0.001751, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 328 1683.0129405423572
# Beta remains the same
# DKL:0.001565, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 329 1726.623650433173
# Beta remains the same
# DKL:0.001721, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 330 1508.3023361718474
# Beta remains the same
# DKL:0.002132, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 331 1416.0987509253757
# Beta remains the same
# DKL:0.001825, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 332 1816.0806781197498
# Decreasing beta
# DKL:0.001406, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 333 1672.7081445515491
# Beta remains the same
# DKL:0.002465, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 334 1732.6479697336422
# Beta remains the same
# DKL:0.004874, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 335 1639.2629752834277
# Beta remains the same
# DKL:0.002822, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 336 1723.8009475076226
# Beta remains the same
# DKL:0.002345, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 337 1576.1308349946055
# Beta remains the same
# DKL:0.003194, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 338 1781.1183382994327
# Beta remains the same
# DKL:0.003038, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 339 1871.8440724643847
# Beta remains the same
# DKL:0.002782, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 340 1871.9988206293583
# Beta remains the same
# DKL:0.002749, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 341 1656.1526163618666
# Beta remains the same
# DKL:0.003872, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 342 1595.4709120427278
# Beta remains the same
# DKL:0.003010, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 343 1791.9728165332867
# Beta remains the same
# DKL:0.002479, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 344 1588.2824542096703
# Beta remains the same
# DKL:0.002462, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 345 1487.9774404703717
# Beta remains the same
# DKL:0.004324, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 346 1699.1634511172147
# Beta remains the same
# DKL:0.002813, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 347 1819.939510404783
# Beta remains the same
# DKL:0.003536, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 348 1727.8169460383092
# Beta remains the same
# DKL:0.003011, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 349 1788.251054473119
# Beta remains the same
# DKL:0.002860, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 350 1687.1017859991796
# Beta remains the same
# DKL:0.002405, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 351 1731.963405247813
# Beta remains the same
# DKL:0.002544, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 352 1880.7504658948885
# Beta remains the same
# DKL:0.003223, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 353 1607.790586558359
# Beta remains the same
# DKL:0.002186, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 354 1695.2926790377355
# Beta remains the same
# DKL:0.004060, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 355 1634.045081653164
# Beta remains the same
# DKL:0.003708, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 356 1806.536637529663
# Beta remains the same
# DKL:0.003089, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 357 1781.907072016263
# Beta remains the same
# DKL:0.002763, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 358 1841.6725202124792
# Beta remains the same
# DKL:0.002822, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 359 2041.8646279788445
# Beta remains the same
# DKL:0.003349, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 360 1904.571755959326
# Beta remains the same
# DKL:0.002867, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 361 1915.432851616848
# Beta remains the same
# DKL:0.002479, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 362 1949.8852763271557
# Beta remains the same
# DKL:0.003265, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 363 1680.5364220795097
# Beta remains the same
# DKL:0.003835, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 364 1698.297617292997
# Beta remains the same
# DKL:0.004623, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 365 1944.0921350734861
# Beta remains the same
# DKL:0.002380, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 366 2121.9109272037995
# Beta remains the same
# DKL:0.001830, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 367 1639.8626211022427
# Beta remains the same
# DKL:0.002893, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 368 1891.0568744871423
# Beta remains the same
# DKL:0.003600, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 369 2205.0583441913327
# Beta remains the same
# DKL:0.001621, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 370 1867.4513097105016
# Beta remains the same
# DKL:0.002402, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 371 1794.4104551477571
# Beta remains the same
# DKL:0.002002, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 372 1876.687450225439
# Increasing beta
# DKL:0.006643, lr_mlt: 1.000000, beta: 1.500000
# ********************************
# 373 1885.4111697108408
# Decreasing beta
# DKL:0.001315, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 374 1804.4048129243492
# Beta remains the same
# DKL:0.002194, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 375 1685.889297922949
# Beta remains the same
# DKL:0.003028, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 376 2092.32138249358
# Beta remains the same
# DKL:0.002181, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 377 2077.0101049378045
# Beta remains the same
# DKL:0.004188, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 378 1661.549036592393
# Beta remains the same
# DKL:0.004032, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 379 1645.1871847358714
# Beta remains the same
# DKL:0.003727, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 380 1958.3146630217184
# Beta remains the same
# DKL:0.002411, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 381 1801.131197496535
# Beta remains the same
# DKL:0.002487, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 382 1792.8003653688597
# Beta remains the same
# DKL:0.003799, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 383 1767.3139853107082
# Beta remains the same
# DKL:0.002308, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 384 1945.8480463684955
# Beta remains the same
# DKL:0.002238, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 385 1693.3323376589547
# Beta remains the same
# DKL:0.002988, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 386 2251.1714328039216
# Beta remains the same
# DKL:0.002340, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# 387 1795.9179994634283
# Beta remains the same
# DKL:0.001961, lr_mlt: 1.000000, beta: 1.000000
# ********************************
# ...
# Increasing beta
# DKL:0.007838, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1381 2936.468481897117
# Beta remains the same
# DKL:0.004674, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1382 2817.0141758235536
# Beta remains the same
# DKL:0.001817, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1383 2839.357603738676
# Decreasing beta
# DKL:0.000901, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1384 2975.8726852451778
# Decreasing beta
# DKL:0.001325, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1385 2949.7082220497364
# Increasing beta
# DKL:0.008546, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1386 2820.8479918841
# Beta remains the same
# DKL:0.005905, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1387 2804.882536958154
# Increasing beta
# DKL:0.007293, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1388 2834.3696487129587
# Decreasing beta
# DKL:0.000564, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1389 2740.499949954737
# Beta remains the same
# DKL:0.004935, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1390 2820.8721714316443
# Decreasing beta
# DKL:0.000733, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1391 2822.2143634355084
# Beta remains the same
# DKL:0.002285, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1392 2863.3837554951524
# Beta remains the same
# DKL:0.004260, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1393 2873.2105590915085
# Increasing beta
# DKL:0.008610, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1394 2943.6256995622034
# Decreasing beta
# DKL:0.001029, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1395 2899.8581433594018
# Increasing beta
# DKL:0.006030, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1396 2935.2979204042676
# Decreasing beta
# DKL:0.000613, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1397 2918.5116744428096
# Beta remains the same
# DKL:0.004088, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1398 3118.558612594545
# Increasing beta
# DKL:0.007596, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1399 3279.1565873727873
# Beta remains the same
# DKL:0.001757, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1400 3193.4006334155733
# Beta remains the same
# DKL:0.004798, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1401 3275.1245342721422
# Increasing beta
# DKL:0.007931, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1402 3116.723227534652
# Decreasing beta
# DKL:0.001364, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1403 3269.1487019236165
# Beta remains the same
# DKL:0.003044, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1404 3320.589559650148
# Increasing beta
# DKL:0.007492, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1405 3223.3188071796
# Decreasing beta
# DKL:0.001315, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1406 3107.4536043303588
# Beta remains the same
# DKL:0.001771, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1407 3139.356659779026
# Beta remains the same
# DKL:0.004675, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1408 3401.3723040017876
# Beta remains the same
# DKL:0.004977, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1409 3422.595426281051
# Increasing beta
# DKL:0.009563, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1410 3279.257497418056
# Beta remains the same
# DKL:0.002655, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1411 3279.830552281846
# Beta remains the same
# DKL:0.005350, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1412 3301.418816953329
# Increasing beta
# DKL:0.007949, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1413 3235.3517235923127
# Decreasing beta
# DKL:0.000509, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1414 3360.830947490385
# Decreasing beta
# DKL:0.000572, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1415 3336.0339896203973
# Increasing beta
# DKL:0.008728, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1416 3509.428561278419
# Beta remains the same
# DKL:0.003748, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1417 3305.126437111828
# Increasing beta
# DKL:0.007337, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1418 3339.161701329324
# Decreasing beta
# DKL:0.000499, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1419 3199.2845715379726
# Decreasing beta
# DKL:0.000637, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1420 3419.0683149906754
# Decreasing beta
# DKL:0.000468, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1421 3286.653329841299
# Increasing beta
# DKL:0.007053, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1422 3269.2247358090885
# Beta remains the same
# DKL:0.002352, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1423 3266.238424601554
# Decreasing beta
# DKL:0.000393, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1424 3386.4459236665825
# Decreasing beta
# DKL:0.001124, lr_mlt: 10.000000, beta: 0.144643
# ********************************
# 1425 3408.224981286117
# Increasing beta
# DKL:0.007276, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1426 3034.258069373629
# Beta remains the same
# DKL:0.003731, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1427 2914.4883375788554
# Decreasing beta
# DKL:0.001002, lr_mlt: 10.000000, beta: 0.144643
# ********************************
# 1428 2772.0445509778992
# Increasing beta
# DKL:0.006043, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1429 2570.5979350901553
# Increasing beta
# DKL:0.006967, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1430 2680.4396901371756
# Beta remains the same
# DKL:0.001791, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1431 2479.125557849797
# Decreasing beta
# DKL:0.000401, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1432 2505.7587430127196
# Beta remains the same
# DKL:0.002159, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1433 2672.5316938731817
# Beta remains the same
# DKL:0.002492, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1434 2318.9953562935216
# Beta remains the same
# DKL:0.004016, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1435 2603.7841452654175
# Beta remains the same
# DKL:0.003150, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1436 2414.234162526381
# Decreasing beta
# DKL:0.001477, lr_mlt: 10.000000, beta: 0.144643
# ********************************
# 1437 2379.8057204949505
# Increasing beta
# DKL:0.006563, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1438 2394.294362603073
# Beta remains the same
# DKL:0.003036, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1439 2190.5053121423384
# Beta remains the same
# DKL:0.004670, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1440 2466.148781947196
# Increasing beta
# DKL:0.006370, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1441 2586.9957680343045
# Decreasing beta
# DKL:0.000848, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1442 2520.86920494645
# Decreasing beta
# DKL:0.000818, lr_mlt: 10.000000, beta: 0.144643
# ********************************
# 1443 2557.053527006029
# Beta remains the same
# DKL:0.001828, lr_mlt: 10.000000, beta: 0.144643
# ********************************
# 1444 2458.473351675185
# Increasing beta
# DKL:0.007196, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1445 1790.9603368507615
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Increasing beta
# DKL:0.008355, lr_mlt: 10.000000, beta: 2.471359
# ********************************
# 1446 1665.6970929393751
# Decreasing beta
# DKL:0.000045, lr_mlt: 10.000000, beta: 1.647573
# ********************************
# 1447 1648.5321264349463
# Decreasing beta
# DKL:0.000070, lr_mlt: 10.000000, beta: 1.098382
# ********************************
# 1448 1778.5929679644662
# Decreasing beta
# DKL:0.000120, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1449 1937.3143637443245
# Decreasing beta
# DKL:0.000209, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1450 1905.489797323316
# Beta remains the same
# DKL:0.002485, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1451 1566.46942508273
# Decreasing beta
# DKL:0.000763, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1452 1985.0627199437772
# Increasing beta
# DKL:0.009689, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1453 2061.4171079685834
# Decreasing beta
# DKL:0.000631, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1454 2101.771746321813
# Increasing beta
# DKL:0.008294, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1455 2267.2755545121977
# Decreasing beta
# DKL:0.000383, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1456 2084.1164122180853
# Decreasing beta
# DKL:0.001117, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1457 1608.573993906452
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Increasing beta
# DKL:0.010256, lr_mlt: 10.000000, beta: 1.647573
# ********************************
# 1458 1978.927587178306
# Decreasing beta
# DKL:0.000059, lr_mlt: 10.000000, beta: 1.098382
# ********************************
# 1459 2170.8348882966397
# Decreasing beta
# DKL:0.000082, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1460 1986.901964692502
# Decreasing beta
# DKL:0.000149, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1461 1823.3071910403519
# Decreasing beta
# DKL:0.001095, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1462 1738.5128516614138
# Beta remains the same
# DKL:0.002190, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1463 1830.752260076155
# Beta remains the same
# DKL:0.001838, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1464 1783.6551907680237
# Decreasing beta
# DKL:0.000656, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1465 2286.1978564613455
# Increasing beta
# DKL:0.006849, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1466 2295.87063597123
# Decreasing beta
# DKL:0.000892, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1467 2263.2793250708764
# Increasing beta
# DKL:0.006206, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1468 2408.8592646451916
# Decreasing beta
# DKL:0.001291, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1469 2467.142204319428
# Beta remains the same
# DKL:0.005625, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1470 2708.17124040817
# Increasing beta
# DKL:0.007078, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1471 2622.7167967222244
# Decreasing beta
# DKL:0.000685, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1472 2050.4768490209394
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Increasing beta
# DKL:0.011064, lr_mlt: 10.000000, beta: 1.098382
# ********************************
# 1473 1934.468561197357
# Decreasing beta
# DKL:0.000779, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1474 1522.8791612729178
# Beta remains the same
# DKL:0.003908, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1475 1598.2320953365822
# Decreasing beta
# DKL:0.000449, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1476 1489.6489637524046
# Decreasing beta
# DKL:0.001264, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1477 1606.3487953422864
# Increasing beta
# DKL:0.007352, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1478 1686.6747953153208
# Decreasing beta
# DKL:0.000700, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1479 1718.9893718808828
# Beta remains the same
# DKL:0.001951, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1480 1598.7027134546754
# Increasing beta
# DKL:0.009049, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1481 2182.6140449664745
# Decreasing beta
# DKL:0.001055, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1482 2318.8941843985085
# Decreasing beta
# DKL:0.000916, lr_mlt: 10.000000, beta: 0.216964
# ********************************
# 1483 2176.6836169295966
# Increasing beta
# DKL:0.010164, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1484 2238.7222924244243
# Beta remains the same
# DKL:0.002430, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1485 2304.0541271281227
# Beta remains the same
# DKL:0.005675, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1486 2292.768684476717
# Increasing beta
# DKL:0.008673, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1487 2471.246353571732
# Decreasing beta
# DKL:0.001300, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1488 2454.9899188037043
# Beta remains the same
# DKL:0.002054, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1489 2429.6806039109547
# Beta remains the same
# DKL:0.003086, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1490 2353.455873663487
# Increasing beta
# DKL:0.009367, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1491 2369.211985686391
# Increasing beta
# DKL:0.006978, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1492 2237.6108748669185
# Beta remains the same
# DKL:0.001892, lr_mlt: 10.000000, beta: 0.732254
# ********************************
# 1493 2232.4969411495745
# Decreasing beta
# DKL:0.000244, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1494 2510.0581695800483
# Decreasing beta
# DKL:0.000365, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1495 2690.7759705919107
# Beta remains the same
# DKL:0.001706, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1496 2027.844681994639
# Increasing beta
# DKL:0.007061, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# 1497 2094.8318202012115
# Decreasing beta
# DKL:0.001010, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1498 2353.0775356504346
# Beta remains the same
# DKL:0.002639, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1499 2170.637127072011
# Beta remains the same
# DKL:0.003489, lr_mlt: 10.000000, beta: 0.325446
# ********************************
# 1500 2427.462011476652
# Increasing beta
# DKL:0.007522, lr_mlt: 10.000000, beta: 0.488170
# ********************************
# Environment is solved
# CPU times: user 11h 56min 19s, sys: 9h 35min 32s, total: 21h 31min 52s
# Wall time: 7h 47min 12s

# %%
plt.plot(agent.logger['results'])
plt.show()

# %%
plt.plot(agent.logger['scores'])
plt.show()

# %%
for i in range(agent.action_size):
    plt.plot(np.array(agent.logger['vars'])[:,i])
plt.show()

# %%
agent.logger['best_five']
# Out:
# 4110.9514698207995

# %%
traj = play_game(agent, render=True)

# %%
np.sum(traj['rewards'])
# Out:
# 1847.4100348503548

# %%
agent.logger['solved']
# Out:
# True

# %%
agent.logger['threshold_crossed']
# Out:
# 5695

# %%
agent.logger['episodes_played']
# Out:
# 30000

# %%
plt.plot(agent.logger['adv'])
plt.show()

# %%
plt.plot(np.array(agent.logger['grads'])[:,:2])
plt.show()

# %%
plt.plot(np.array(agent.logger['grads'])[:,2:])
plt.show()

# %%
agent.load('best')

# %%
traj = play_game(agent, render=True)

# %%
np.sum(traj['rewards'])
# Out:
# 4110.785937589199
