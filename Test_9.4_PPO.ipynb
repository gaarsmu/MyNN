# %%
import os
path = os.environ['MyNN']
os.sys.path.append(path)
import MyNN
import gym
import numpy as np
from collections import deque
import _pickle as pickle

import matplotlib.pyplot as plt

# %%
class ACAgent:
    def __init__(self, state_size, action_size, variances, gamma=0.995, lam=0.98,
                 actor_lr=0.001, critic_lr=0.001, method='PPO_CEM', logvar_speed=50):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma  # discount rate
        self.lam = lam # GAE disc rate
        self.method = method
        self.actor = self._build_model()
        self.critic = self._build_vf()
        self.actor.lr = actor_lr
        self.critic.lr = critic_lr
        self.scaler = MyNN.Scaler(state_size)
        self.variances = variances
        self.replay_buff_x = None
        self.replay_buff_y = None
        self.n_updates = 0
        self.grads_velo = np.zeros(variances.shape)
        self.grads_vars = np.zeros(variances.shape)
        self.var_save = None
        self.logwar_speed = logvar_speed
        self.logger = {'scores' :[] , 'adv': [], 'grads' :[], 'results' : [], 'result': 0, 'vars' : [],
                       'mean_scores': deque(maxlen=10), 'solved' : False, 'five_games' : deque(maxlen=5),
                      'best_five':-1000, 'best_score':-1000, 'threshold_crossed': None}


    def _build_model(self):
        model = MyNN.MyNN(self.state_size)
        model.add(self.state_size*10, 'Tanh')
        model.add(int(np.sqrt(self.action_size*self.state_size)*10), 'Tanh')
        model.add(self.action_size*10, 'Tanh')
        model.add(self.action_size, 'Linear')
        model.compile(self.method, 'Adam')
        return model
    
    def _build_vf(self):
        model = MyNN.MyNN(self.state_size)
        model.add(self.state_size*10, 'Tanh')
        model.add(int(np.sqrt(self.state_size*50)), 'Tanh')
        model.add(5, 'Tanh')
        model.add(1, 'Linear')
        model.compile('MSE', 'Adam')
        return model
    
    def value_function_fit(self, x, y):
        if self.replay_buff_x is None:
            x_train, y_train = x, y
        else:
            x_train = np.hstack([x, self.replay_buff_x])
            y_train = np.hstack([y, self.replay_buff_y])
        self.replay_buff_x = x
        self.replay_buff_y = y
        self.critic.optimize(x_train, y_train, num_epochs=10, 
                             report_cost=False, batch_size=128)

    def get_means(self, state):
        result = self.actor.forward(state, caching='no')
        return result
    
    def update_variances(self, actions, means, adv,old_means, old_var, prob_exp, beta, DKL, DKL_targ, eta):
        self.n_updates += 1
        var = self.variances
        n = means.shape[1]
        grads = np.square(actions-means)/var
        grads = (grads-1)/(2)
        grads = grads*adv*prob_exp
        DKL_term = (-1/2)*(1 - np.divide(np.square(means-old_means), var) - np.divide(old_var, var))*beta
        if DKL > DKL_targ*2:
            DKL_add_term = (-1/2)*(1 - np.divide(np.square(means-old_means), var) - np.divide(old_var, var))*eta*(2*DKL - 4*DKL_targ)
            DKL_term = DKL_term + DKL_add_term
        grads = (1/n)*(grads + DKL_term)
        grads = np.sum(grads, axis=1, keepdims=True)
        self.grads_velo = self.grads_velo*0.9 + 0.1*grads
        corrected_v = self.grads_velo/(1-0.9**self.n_updates)
        self.grads_vars = self.grads_vars*0.99 + 0.01*np.square(grads)
        corrected_b = self.grads_vars/(1-0.99**self.n_updates)
        self.variances = np.maximum((np.exp(np.log(var) + self.actor.lr*self.logwar_speed*corrected_v/(np.sqrt(corrected_b)+1e-8))), 0.001)
    
    def save(self, path):
        save_dict = {'act_size': self.action_size , 'state_size' : self.state_size, 'gamma' : self.gamma,
                    'lamda' : self.lam, 'actor_dict': self.actor.nn_to_dict, 'critic_dict': self.critic.nn_to_dict,
                    'scaler_tupl': self.scaler.save('aa', to_tupl=True), 'vars' : self.variances,
                    'buff_x': self.replay_buff_x, 'buff_y': self.replay_buff_y, 'n_updates' : self.n_updates,
                    'grads_velo' : self.grads_velo, 'grads_vars': self.grads_vars, 'logvar_speed':self.logwar_speed,
                    'logger' : self.logger}
        pickle.dump(save_dict, open(path, 'wb'))
    
    def load(self, path):
        save_dict = pickle.load(open(path, 'rb'))
        self.state_size = save_dict['state_size']
        self.action_size = save_dict['act_size']
        self.gamma = save_dict['gamma']
        self.lam = save_dict['lamda']
        self.actor = self.actor.load('aa', save_dict['actor_dict'])
        self.critic = self.critic.load('aa', save_dict['critic_dict'])
        self.scaler = self.scaler.load('aa', save_dict['scaler_tupl'])
        self.variances = save_dict['vars']
        self.replay_buff_x = save_dict['buff_x']
        self.replay_buff_y = save_dict['buff_y']
        self.n_updates = save_dict['n_updates']
        self.grads_velo = save_dict['grads_velo']
        self.grads_vars = save_dict['grads_vars']
        self.logwar_speed = save_dict['logvar_speed']
        self.logger = save_dict['logger']
    
    def quick_save(self):
        agent.actor.quick_save()
        self.var_save = (self.grads_velo, self.grads_vars, self.n_updates, self.variances)
    
    def quick_load(self):
        agent.actor.quick_load()
        (self.grads_velo, self.grads_vars, self.n_updates, self.variances) = self.var_save

# %%
def running_reward(rewards, gamma):
    result = []
    run_rew = 0
    for reward in  rewards[0,:][::-1]:
        run_rew = run_rew*gamma + reward
        result.append(run_rew)
    return np.array(result[::-1]).reshape(1,-1)

def add_gae(traj, gamma, lam):
    rewards = traj['rewards'] #*(1-gamma)
    values = traj['values']
    traj['tds'] = rewards - values + np.append(traj['values'][0, 1:] * agent.gamma, 0).reshape(1,-1)
    gae = running_reward(traj['tds'], gamma*lam)
    return gae

def compute_DKL(means0, means1, vars0, vars1):
    k = means0.shape[0]
    tr = np.sum(np.divide(vars0, vars1))
    means = np.sum(np.divide(np.square(means1-means0), vars1))
    logs = np.log(np.prod(vars1)) - np.log(np.prod(vars0))
    result = 0.5*(tr + means - k + logs)
    return result/means0.shape[1]

# %%
def play_game(agent, render=False):
    state = env.reset().reshape((agent.state_size,1))
    unscaled_states = []
    states = []
    meanss = []
    actions = []
    rewards = []
    done = False
    mean, var = agent.scaler.get()
    while not done:
        if render:
            env.render()
        unscaled_states.append(state)
        scaled_state = (state-mean)/var
        states.append(scaled_state)
        means = agent.get_means(scaled_state)
        meanss.append(means)
        action = means + agent.variances*np.random.normal(size=(agent.action_size,1))
        actions.append(action)
        state, reward, done, _ = env.step(action.T)
        state = state.reshape((agent.state_size,1))
        rewards.append(reward)
        if done:
            break
    return {'unscaled': np.hstack(unscaled_states), 'states' : np.hstack(states),
            'means': np.hstack(meanss), 'actions': np.hstack(actions),
            'rewards': np.array(rewards).reshape(1,-1)}

# %%
def play_n_games(agent, n=20):
    trajectories = []
    for i in range(n):
        trajectory = play_game(agent)
        trajectories.append(trajectory)
        
        result = np.sum(trajectory['rewards'])
        agent.logger['five_games'].append(result)
        if np.mean(agent.logger['five_games']) > agent.logger['best_five']:
            agent.logger['best_five'] = np.mean(agent.logger['five_games'])
    return trajectories

# %%
def build_train_set(agent, trajectories):
    for traj in trajectories:
        traj['disc_sum_rew'] = running_reward(traj['rewards'], agent.gamma) #*(1-agent.gamma)
        traj['values'] = agent.critic.forward(traj['states'])
        traj['GAE'] = add_gae(traj, agent.gamma, agent.lam)
    X = np.hstack([t['states'] for t in trajectories])
    Y = np.hstack([t['means'] for t in trajectories])
    actions = np.hstack([t['actions'] for t in trajectories])
    disc_sum_rew = np.hstack([t['disc_sum_rew'] for t in trajectories])
    adv = np.hstack([t['GAE'] for t in trajectories])
    adv = (adv - adv.mean())/(adv.std() + 1e-6)
    return X, Y, actions, np.clip(adv, -15, 15), disc_sum_rew

# %%
env = gym.make('Hopper-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.shape[0]
variances = np.ones((action_size,1))

base_lr = 1e-4/np.sqrt(int(np.sqrt(action_size*state_size)*10))
vf_lr = 1e-2/np.sqrt(int(np.sqrt(state_size*50)))
logvar_speed = (action_size*100)//48

agent = ACAgent(state_size, action_size, actor_lr=base_lr,
                critic_lr=vf_lr, gamma=0.95, lam=0.98, method='Cont_PPO',
               variances= variances, logvar_speed = logvar_speed)
d = {'beta': 1, 'eta':30, 'DKL_targ' : 0.003}

# %%
trajectories = play_n_games(agent, n=10)
score = np.mean([(np.sum(t['rewards']), np.var(t['rewards'])) for t in trajectories], axis=0)

threshold = 2000
solved_score = 3000
agent.logger['result'] = score[0]

# %%
for time in range(1, 3000):
    trajectories = play_n_games(agent, n=10)
    agent.scaler.update(np.hstack([t['unscaled'] for t in trajectories]))
    score = np.mean([(np.sum(t['rewards']), np.var(t['rewards'])) for t in trajectories], axis=0)
    agent.logger['scores'].append(score)
    X_batch, d['old_means'], d['actions'], d['adv'], disc_sum_rew = build_train_set(agent, trajectories)
    d['old_vars'] = agent.variances
    print(time, score[0])
    
    i = 1
    agent.quick_save()
    while i < 20:
        d['means'] = agent.actor.forward(X_batch)
        agent.actor.cache['A0'] = X_batch
        d['vars'] = agent.variances
        d['DKL'] = compute_DKL(d['old_means'], d['means'], d['old_vars'], d['vars'])
        
        if d['DKL'] > d['DKL_targ']*4:
            print('DKL diverges badly, loading earlier version, increasing beta and starting training again')
            d['beta'] = np.minimum(4, d['beta']*1.2)
            if d['beta'] > 3.9:
                adj_lr = np.maximum(agent.actor.lr/1.44, base_lr*0.05)
                d['beta'] = 1
                print('Decreasing learning rate, currnet lr multipler is {}'.format(agent.actor.lr/base_lr))
            agent.quick_load()
            if d['beta'] > 3.9:
                agent.actor.lr = adj_lr
            i = 1
        
        log_p = -0.5*(np.log(d['vars']) + np.divide(np.square(d['actions'] - d['means']), d['vars']))
        log_old_p = -0.5*(np.log(d['old_vars']) + np.divide(np.square(d['actions'] - d['old_means']), d['old_vars']))
        d['prob_exp'] = np.exp(log_p - log_old_p)
        agent.logger['adv'].append([np.min(d['adv']), np.max(d['adv']), np.mean(np.abs(d['adv']))])
        grads = agent.actor.get_grads(d)
        agent.logger['grads'].append([np.min(grads), np.max(grads), np.mean(grads), np.mean(np.abs(grads))])
        agent.actor.backward(_, _, _, grads=grads)
        agent.actor.number_of_updates +=1
        agent.actor.update_parameters()
        agent.update_variances(d['actions'], d['means'], d['adv'], d['old_means'],
                               d['old_vars'], d['prob_exp'], d['beta'], d['DKL'], d['DKL_targ'], d['eta'])
        i += 1
        
    if d['DKL'] > d['DKL_targ']*2:
        d['beta'] = np.minimum(4, d['beta']*1.2)
        print('Increasing beta')
        if d['beta'] > 3.9:
            agent.actor.lr = np.maximum(agent.actor.lr/1.44, base_lr*0.05)
            d['beta'] = 1
            print('Decreasing learning rate')
    elif d['DKL'] < d['DKL_targ']*0.5:
        d['beta'] = np.maximum(1/4, d['beta']/1.2)
        print('Decreasing beta')
        if d['beta'] < 1/3.9:
            agent.actor.lr = np.minimum(agent.actor.lr*1.2, base_lr*20)
            d['beta'] = 1
            print('Increasing learning rate')
    else:
        print('Beta remains the same')
    
    if score[0] > agent.logger['best_score']:
        agent.save('best')
        agent.logger['best_score'] = score[0]
    
    if score[0] > threshold and (agent.logger['threshold_crossed'] is None):
        agent.logger['threshold_crossed'] = time*10
    
    agent.logger['mean_scores'].append(score[0])
    if np.mean(agent.logger['mean_scores']) >= solved_score:
        agent.logger['solved'] = True
        
    agent.value_function_fit(X_batch, disc_sum_rew)
    agent.logger['result'] = agent.logger['result']*0.98+score[0]*0.02
    agent.logger['results'].append(agent.logger['result'])
    agent.logger['vars'].append(agent.variances)
    
    print('DKL:{:f}, lr_mlt: {}, beta: {}'.format(d['DKL'], agent.actor.lr/base_lr, d['beta']))
    print('********************************')

if agent.logger['solved']:
    print('Environment is solved')
# Out:
# 1 14.319159828435954
# Decreasing beta
# DKL:0.001138, lr_mlt: 1.0, beta: 0.8333333333333334
# ********************************
# 2 12.49628231535387
# Decreasing beta
# DKL:0.000587, lr_mlt: 1.0, beta: 0.6944444444444445
# ********************************
# 3 11.284133165070463
# Decreasing beta
# DKL:0.000701, lr_mlt: 1.0, beta: 0.5787037037037038
# ********************************
# 4 11.265092611556588
# Decreasing beta
# DKL:0.000394, lr_mlt: 1.0, beta: 0.48225308641975323
# ********************************
# 5 10.856270192396353
# Decreasing beta
# DKL:0.000709, lr_mlt: 1.0, beta: 0.401877572016461
# ********************************
# 6 10.7320393936708
# Decreasing beta
# DKL:0.000735, lr_mlt: 1.0, beta: 0.3348979766803842
# ********************************
# 7 10.245110535486683
# Decreasing beta
# DKL:0.000423, lr_mlt: 1.0, beta: 0.2790816472336535
# ********************************
# 8 9.791951886229024
# Decreasing beta
# Increasing learning rate
# DKL:0.000359, lr_mlt: 1.2, beta: 1
# ********************************
# 9 13.564496305143852
# Beta remains the same
# DKL:0.002890, lr_mlt: 1.2, beta: 1
# ********************************
# 10 14.647253575182912
# Beta remains the same
# DKL:0.001667, lr_mlt: 1.2, beta: 1
# ********************************
# 11 15.801918404502013
# Decreasing beta
# DKL:0.001347, lr_mlt: 1.2, beta: 0.8333333333333334
# ********************************
# 12 13.149802285543348
# Decreasing beta
# DKL:0.000986, lr_mlt: 1.2, beta: 0.6944444444444445
# ********************************
# 13 14.545043935545817
# Decreasing beta
# DKL:0.001486, lr_mlt: 1.2, beta: 0.5787037037037038
# ********************************
# 14 15.802836666594706
# Beta remains the same
# DKL:0.001552, lr_mlt: 1.2, beta: 0.5787037037037038
# ********************************
# 15 14.981343911325933
# Decreasing beta
# DKL:0.001297, lr_mlt: 1.2, beta: 0.48225308641975323
# ********************************
# 16 19.8799487134798
# Beta remains the same
# DKL:0.001734, lr_mlt: 1.2, beta: 0.48225308641975323
# ********************************
# 17 16.998578375792555
# Decreasing beta
# DKL:0.001488, lr_mlt: 1.2, beta: 0.401877572016461
# ********************************
# 18 16.90184750025799
# Beta remains the same
# DKL:0.002027, lr_mlt: 1.2, beta: 0.401877572016461
# ********************************
# 19 19.910210005374662
# Decreasing beta
# DKL:0.001432, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 20 30.96881298206069
# Beta remains the same
# DKL:0.003513, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 21 20.86990507331592
# Beta remains the same
# DKL:0.002327, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 22 39.0168598897101
# Beta remains the same
# DKL:0.005132, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 23 33.971920250032056
# Beta remains the same
# DKL:0.001996, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 24 47.71521062139941
# Beta remains the same
# DKL:0.003858, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 25 60.99691828673066
# Beta remains the same
# DKL:0.002130, lr_mlt: 1.2, beta: 0.3348979766803842
# ********************************
# 26 35.17487433519578
# Decreasing beta
# DKL:0.001392, lr_mlt: 1.2, beta: 0.2790816472336535
# ********************************
# 27 39.0276660554441
# Beta remains the same
# DKL:0.002213, lr_mlt: 1.2, beta: 0.2790816472336535
# ********************************
# 28 53.740038389417556
# Decreasing beta
# Increasing learning rate
# DKL:0.001056, lr_mlt: 1.44, beta: 1
# ********************************
# 29 49.00475909400009
# Decreasing beta
# DKL:0.000776, lr_mlt: 1.44, beta: 0.8333333333333334
# ********************************
# 30 22.937837595856735
# Decreasing beta
# DKL:0.001027, lr_mlt: 1.44, beta: 0.6944444444444445
# ********************************
# 31 54.932161472686644
# Decreasing beta
# DKL:0.001460, lr_mlt: 1.44, beta: 0.5787037037037038
# ********************************
# 32 51.94161997387857
# Decreasing beta
# DKL:0.000664, lr_mlt: 1.44, beta: 0.48225308641975323
# ********************************
# 33 57.34331489152883
# Beta remains the same
# DKL:0.001667, lr_mlt: 1.44, beta: 0.48225308641975323
# ********************************
# 34 44.667863238085474
# Decreasing beta
# DKL:0.001482, lr_mlt: 1.44, beta: 0.401877572016461
# ********************************
# 35 21.642790551980685
# Decreasing beta
# DKL:0.001073, lr_mlt: 1.44, beta: 0.3348979766803842
# ********************************
# 36 51.707962936990405
# Decreasing beta
# DKL:0.001210, lr_mlt: 1.44, beta: 0.2790816472336535
# ********************************
# 37 54.575011069298
# Decreasing beta
# Increasing learning rate
# DKL:0.001133, lr_mlt: 1.728, beta: 1
# ********************************
# 38 37.39703503828432
# Decreasing beta
# DKL:0.001389, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 39 47.47680237303199
# Beta remains the same
# DKL:0.001933, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 40 59.57964146560403
# Decreasing beta
# DKL:0.001489, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 41 45.520197700667815
# Decreasing beta
# DKL:0.001079, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 42 97.58706654529904
# Beta remains the same
# DKL:0.002601, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 43 60.8534203469884
# Beta remains the same
# DKL:0.002861, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 44 88.27999671935142
# Beta remains the same
# DKL:0.004578, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 45 92.4505547481655
# Beta remains the same
# DKL:0.002061, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 46 111.44738516372038
# Decreasing beta
# DKL:0.000873, lr_mlt: 1.728, beta: 0.48225308641975323
# ********************************
# 47 108.17752324576648
# Beta remains the same
# DKL:0.003820, lr_mlt: 1.728, beta: 0.48225308641975323
# ********************************
# 48 119.54868236417958
# Beta remains the same
# DKL:0.005610, lr_mlt: 1.728, beta: 0.48225308641975323
# ********************************
# 49 100.87946675071878
# Increasing beta
# DKL:0.007524, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 50 132.17652205959112
# Increasing beta
# DKL:0.007905, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 51 148.08303086989864
# Beta remains the same
# DKL:0.003527, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 52 200.78683650681188
# Increasing beta
# DKL:0.007575, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 53 243.17607473600475
# Beta remains the same
# DKL:0.003677, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 54 226.36172595517434
# Beta remains the same
# DKL:0.003686, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 55 205.62701619443683
# Beta remains the same
# DKL:0.003309, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 56 262.2293960384459
# Beta remains the same
# DKL:0.005436, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 57 198.77395947570156
# Increasing beta
# DKL:0.008191, lr_mlt: 1.728, beta: 1.0
# ********************************
# 58 233.4139910962878
# Beta remains the same
# DKL:0.002795, lr_mlt: 1.728, beta: 1.0
# ********************************
# 59 249.00263217264666
# Beta remains the same
# DKL:0.002858, lr_mlt: 1.728, beta: 1.0
# ********************************
# 60 297.0408647651747
# Beta remains the same
# DKL:0.004870, lr_mlt: 1.728, beta: 1.0
# ********************************
# 61 306.3964745621057
# Increasing beta
# DKL:0.006419, lr_mlt: 1.728, beta: 1.2
# ********************************
# 62 272.16924199769744
# Beta remains the same
# DKL:0.002245, lr_mlt: 1.728, beta: 1.2
# ********************************
# 63 310.317407787524
# Beta remains the same
# DKL:0.003149, lr_mlt: 1.728, beta: 1.2
# ********************************
# 64 314.1477370346007
# Beta remains the same
# DKL:0.002092, lr_mlt: 1.728, beta: 1.2
# ********************************
# 65 307.2556741532791
# Beta remains the same
# DKL:0.002119, lr_mlt: 1.728, beta: 1.2
# ********************************
# 66 296.0822703248788
# Increasing beta
# DKL:0.007207, lr_mlt: 1.728, beta: 1.44
# ********************************
# 67 316.91053998359837
# Beta remains the same
# DKL:0.001555, lr_mlt: 1.728, beta: 1.44
# ********************************
# 68 322.0227557764978
# Beta remains the same
# DKL:0.002660, lr_mlt: 1.728, beta: 1.44
# ********************************
# 69 290.6995020750087
# Increasing beta
# DKL:0.006815, lr_mlt: 1.728, beta: 1.728
# ********************************
# 70 308.9310114407851
# Beta remains the same
# DKL:0.003443, lr_mlt: 1.728, beta: 1.728
# ********************************
# 71 317.6385294755547
# Beta remains the same
# DKL:0.002691, lr_mlt: 1.728, beta: 1.728
# ********************************
# 72 313.9623167911851
# Beta remains the same
# DKL:0.002186, lr_mlt: 1.728, beta: 1.728
# ********************************
# 73 315.04721962915363
# Beta remains the same
# DKL:0.002831, lr_mlt: 1.728, beta: 1.728
# ********************************
# 74 336.0856889274816
# Beta remains the same
# DKL:0.001860, lr_mlt: 1.728, beta: 1.728
# ********************************
# 75 336.9235905015378
# Decreasing beta
# DKL:0.000919, lr_mlt: 1.728, beta: 1.44
# ********************************
# 76 305.654398148244
# Beta remains the same
# DKL:0.003589, lr_mlt: 1.728, beta: 1.44
# ********************************
# 77 324.48517865164166
# Decreasing beta
# DKL:0.001488, lr_mlt: 1.728, beta: 1.2
# ********************************
# 78 346.52915735710405
# Beta remains the same
# DKL:0.003038, lr_mlt: 1.728, beta: 1.2
# ********************************
# 79 319.4687207811874
# Beta remains the same
# DKL:0.003087, lr_mlt: 1.728, beta: 1.2
# ********************************
# 80 349.48179397078167
# Decreasing beta
# DKL:0.000888, lr_mlt: 1.728, beta: 1.0
# ********************************
# 81 340.7857335121066
# Beta remains the same
# DKL:0.005056, lr_mlt: 1.728, beta: 1.0
# ********************************
# 82 343.03975874272896
# Beta remains the same
# DKL:0.002176, lr_mlt: 1.728, beta: 1.0
# ********************************
# 83 335.92119176693376
# Beta remains the same
# DKL:0.005729, lr_mlt: 1.728, beta: 1.0
# ********************************
# 84 347.08543734865987
# Beta remains the same
# DKL:0.005305, lr_mlt: 1.728, beta: 1.0
# ********************************
# 85 365.25288991863505
# Beta remains the same
# DKL:0.002343, lr_mlt: 1.728, beta: 1.0
# ********************************
# 86 383.89072742688984
# Beta remains the same
# DKL:0.002361, lr_mlt: 1.728, beta: 1.0
# ********************************
# 87 360.296118275441
# Beta remains the same
# DKL:0.003688, lr_mlt: 1.728, beta: 1.0
# ********************************
# 88 367.69908743140445
# Beta remains the same
# DKL:0.001695, lr_mlt: 1.728, beta: 1.0
# ********************************
# 89 381.7367423606506
# Beta remains the same
# DKL:0.003201, lr_mlt: 1.728, beta: 1.0
# ********************************
# 90 383.1994688059367
# Beta remains the same
# DKL:0.002378, lr_mlt: 1.728, beta: 1.0
# ********************************
# 91 339.87866595987435
# Beta remains the same
# DKL:0.002996, lr_mlt: 1.728, beta: 1.0
# ********************************
# 92 380.93865446822593
# Beta remains the same
# DKL:0.002160, lr_mlt: 1.728, beta: 1.0
# ********************************
# 93 380.0746058331031
# Beta remains the same
# DKL:0.001554, lr_mlt: 1.728, beta: 1.0
# ********************************
# 94 373.5745540960317
# Beta remains the same
# DKL:0.003507, lr_mlt: 1.728, beta: 1.0
# ********************************
# 95 403.4998114688071
# Decreasing beta
# DKL:0.001228, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 96 407.758467140218
# Beta remains the same
# DKL:0.001767, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 97 374.5251244774746
# Beta remains the same
# DKL:0.003203, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 98 380.5781636807762
# Beta remains the same
# DKL:0.003990, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 99 374.15099412091075
# Beta remains the same
# DKL:0.005131, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 100 391.9497269588386
# Beta remains the same
# DKL:0.002003, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 101 386.05110703768776
# Beta remains the same
# DKL:0.001795, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 102 381.33009505335747
# Decreasing beta
# DKL:0.001444, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 103 398.6239599484326
# Decreasing beta
# DKL:0.001133, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 104 405.5894114892082
# Beta remains the same
# DKL:0.001918, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 105 390.20132879889496
# Decreasing beta
# DKL:0.001495, lr_mlt: 1.728, beta: 0.48225308641975323
# ********************************
# 106 402.3020617180431
# Decreasing beta
# DKL:0.001145, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 107 396.5758442095552
# Beta remains the same
# DKL:0.002011, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 108 383.15531372539203
# Beta remains the same
# DKL:0.003175, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 109 389.3671526431429
# Increasing beta
# DKL:0.008820, lr_mlt: 1.728, beta: 0.4822530864197532
# ********************************
# 110 372.6913161448943
# Beta remains the same
# DKL:0.002916, lr_mlt: 1.728, beta: 0.4822530864197532
# ********************************
# 111 380.02721826652504
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Beta remains the same
# DKL:0.002665, lr_mlt: 1.728, beta: 2.48832
# ********************************
# 112 376.38167090462815
# Decreasing beta
# DKL:0.000731, lr_mlt: 1.728, beta: 2.0736
# ********************************
# 113 416.16476204511383
# Beta remains the same
# DKL:0.001504, lr_mlt: 1.728, beta: 2.0736
# ********************************
# 114 381.30354934280274
# Decreasing beta
# DKL:0.001101, lr_mlt: 1.728, beta: 1.728
# ********************************
# 115 398.8725559458563
# Decreasing beta
# DKL:0.000685, lr_mlt: 1.728, beta: 1.44
# ********************************
# 116 373.3609910648242
# Decreasing beta
# DKL:0.000763, lr_mlt: 1.728, beta: 1.2
# ********************************
# 117 425.2723150856092
# Decreasing beta
# DKL:0.000849, lr_mlt: 1.728, beta: 1.0
# ********************************
# 118 404.6788585951455
# Decreasing beta
# DKL:0.001045, lr_mlt: 1.728, beta: 0.8333333333333334
# ********************************
# 119 397.46998140227106
# Decreasing beta
# DKL:0.001051, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 120 400.445103515123
# Beta remains the same
# DKL:0.004141, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 121 428.6701632087219
# Beta remains the same
# DKL:0.003436, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 122 385.9836156301369
# Beta remains the same
# DKL:0.003581, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 123 447.32080187682396
# Beta remains the same
# DKL:0.001626, lr_mlt: 1.728, beta: 0.6944444444444445
# ********************************
# 124 468.58742648012105
# Decreasing beta
# DKL:0.000845, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 125 393.70435852796356
# Beta remains the same
# DKL:0.002897, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 126 426.60214776222557
# Beta remains the same
# DKL:0.002979, lr_mlt: 1.728, beta: 0.5787037037037038
# ********************************
# 127 403.3984165939478
# Decreasing beta
# DKL:0.000884, lr_mlt: 1.728, beta: 0.48225308641975323
# ********************************
# 128 404.995205034635
# Decreasing beta
# DKL:0.001377, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 129 405.0083620830371
# Beta remains the same
# DKL:0.002269, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 130 422.0256967058846
# Beta remains the same
# DKL:0.002347, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 131 436.6935029553756
# Beta remains the same
# DKL:0.002167, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 132 421.2999241199188
# Beta remains the same
# DKL:0.002340, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 133 474.4551900263162
# Beta remains the same
# DKL:0.002204, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 134 432.91188940485006
# Beta remains the same
# DKL:0.002049, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 135 467.4252689069187
# Beta remains the same
# DKL:0.001692, lr_mlt: 1.728, beta: 0.401877572016461
# ********************************
# 136 482.2910567627064
# Decreasing beta
# DKL:0.001315, lr_mlt: 1.728, beta: 0.3348979766803842
# ********************************
# 137 463.1929059246301
# Decreasing beta
# DKL:0.000773, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 138 471.9969948789729
# Beta remains the same
# DKL:0.004077, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 139 482.3747283219062
# Beta remains the same
# DKL:0.002742, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 140 514.7915045767074
# Beta remains the same
# DKL:0.004959, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 141 445.60196638117213
# Beta remains the same
# DKL:0.002587, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 142 453.88154718963926
# Beta remains the same
# DKL:0.002509, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 143 526.3025324322505
# Beta remains the same
# DKL:0.003936, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 144 421.6385955650191
# Beta remains the same
# DKL:0.003288, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 145 369.52184786463295
# Increasing beta
# DKL:0.006701, lr_mlt: 1.728, beta: 0.3348979766803842
# ********************************
# 146 469.1103506318435
# Beta remains the same
# DKL:0.002153, lr_mlt: 1.728, beta: 0.3348979766803842
# ********************************
# 147 476.989121606918
# Decreasing beta
# DKL:0.001027, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 148 462.2962305352991
# Beta remains the same
# DKL:0.001606, lr_mlt: 1.728, beta: 0.2790816472336535
# ********************************
# 149 442.8063292764874
# Decreasing beta
# Increasing learning rate
# DKL:0.001243, lr_mlt: 2.0736, beta: 1
# ********************************
# 150 432.5177549296419
# Beta remains the same
# DKL:0.002164, lr_mlt: 2.0736, beta: 1
# ********************************
# 151 432.8339269088268
# Decreasing beta
# DKL:0.001228, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 152 393.3862782563528
# Beta remains the same
# DKL:0.002434, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 153 462.2493754638243
# Beta remains the same
# DKL:0.001650, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 154 482.4149044059457
# Beta remains the same
# DKL:0.001814, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 155 441.52165509976305
# Beta remains the same
# DKL:0.002863, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 156 424.03573391411385
# Increasing beta
# DKL:0.007288, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 157 434.17363024440846
# Beta remains the same
# DKL:0.003812, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 158 438.7160981685656
# Decreasing beta
# DKL:0.001020, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 159 471.65367822877005
# Beta remains the same
# DKL:0.002768, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 160 423.9824623879451
# Beta remains the same
# DKL:0.001529, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 161 399.22536254072645
# Decreasing beta
# DKL:0.000499, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 162 418.1089026889131
# Beta remains the same
# DKL:0.003634, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 163 439.1693394343113
# Beta remains the same
# DKL:0.004897, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 164 421.1835125783189
# Beta remains the same
# DKL:0.002877, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 165 432.0466186825129
# Beta remains the same
# DKL:0.002963, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 166 402.3404590722213
# Beta remains the same
# DKL:0.001605, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 167 442.6367787734189
# Beta remains the same
# DKL:0.002828, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 168 430.8106039875471
# Increasing beta
# DKL:0.006957, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 169 519.9264647308646
# Beta remains the same
# DKL:0.002079, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 170 418.0987773346407
# Beta remains the same
# DKL:0.005019, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 171 418.4556853980301
# Decreasing beta
# DKL:0.001295, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 172 414.39312226825984
# Beta remains the same
# DKL:0.001735, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 173 394.3964894202028
# Beta remains the same
# DKL:0.002152, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 174 375.68672359054005
# Beta remains the same
# DKL:0.003863, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 175 420.5747986507009
# Beta remains the same
# DKL:0.003229, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 176 403.5010653681558
# Beta remains the same
# DKL:0.002999, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 177 408.5187104630588
# Decreasing beta
# DKL:0.001223, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 178 382.289847621628
# Beta remains the same
# DKL:0.001561, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 179 378.22433123277426
# Decreasing beta
# DKL:0.001126, lr_mlt: 2.0736, beta: 0.48225308641975323
# ********************************
# 180 428.37678402491395
# Increasing beta
# DKL:0.007752, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 181 380.4828399024759
# Beta remains the same
# DKL:0.001971, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 182 398.8075270782068
# Beta remains the same
# DKL:0.002332, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 183 417.90429150372
# Beta remains the same
# DKL:0.003303, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 184 390.9468160461573
# Beta remains the same
# DKL:0.002304, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 185 447.2032468776589
# Increasing beta
# DKL:0.009399, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 186 397.2168110838429
# Beta remains the same
# DKL:0.003840, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 187 379.0276635943248
# Beta remains the same
# DKL:0.004776, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 188 385.48157527129746
# Beta remains the same
# DKL:0.001986, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 189 384.5901134451927
# Increasing beta
# DKL:0.007963, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 190 433.8179059167304
# Decreasing beta
# DKL:0.001275, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 191 421.17174371947624
# Beta remains the same
# DKL:0.003445, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 192 422.4185629318399
# Beta remains the same
# DKL:0.002043, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 193 459.7964441405428
# Beta remains the same
# DKL:0.002331, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 194 469.0674327965222
# Beta remains the same
# DKL:0.003175, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 195 429.5306500462454
# Increasing beta
# DKL:0.006696, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 196 441.78450396173884
# Decreasing beta
# DKL:0.001062, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 197 436.41605371655095
# Beta remains the same
# DKL:0.003799, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 198 456.62993984630805
# Beta remains the same
# DKL:0.003028, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 199 435.06760322332104
# Increasing beta
# DKL:0.007505, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 200 426.93373098252584
# Beta remains the same
# DKL:0.002484, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 201 453.67395236925194
# Decreasing beta
# DKL:0.001263, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 202 434.11584869486217
# Beta remains the same
# DKL:0.003507, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 203 437.6416117758864
# Beta remains the same
# DKL:0.003711, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 204 455.68289419906216
# Beta remains the same
# DKL:0.003732, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 205 471.96115532781096
# Beta remains the same
# DKL:0.003792, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 206 454.206348798495
# Beta remains the same
# DKL:0.004601, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 207 521.5851190082699
# Beta remains the same
# DKL:0.002006, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 208 469.26703957353766
# Beta remains the same
# DKL:0.003244, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 209 472.449361627708
# Decreasing beta
# DKL:0.001264, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 210 456.18993215468
# Beta remains the same
# DKL:0.001648, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 211 453.7040692245646
# Beta remains the same
# DKL:0.002492, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 212 470.6007832591425
# Increasing beta
# DKL:0.007315, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 213 449.4180989855014
# Decreasing beta
# DKL:0.000813, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 214 473.7557070592594
# Beta remains the same
# DKL:0.001596, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 215 426.7643792834575
# Increasing beta
# DKL:0.006409, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 216 427.44286331503264
# Beta remains the same
# DKL:0.003678, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 217 455.81371271978895
# Decreasing beta
# DKL:0.001006, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 218 457.76505970548413
# Beta remains the same
# DKL:0.003213, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 219 460.00521024915014
# Beta remains the same
# DKL:0.004414, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 220 482.00520907951795
# Beta remains the same
# DKL:0.003333, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 221 465.2753507776635
# Increasing beta
# DKL:0.008182, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 222 453.1414128125333
# Beta remains the same
# DKL:0.002289, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 223 442.4862731437479
# Decreasing beta
# DKL:0.000667, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 224 460.2192242821082
# Beta remains the same
# DKL:0.002093, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 225 484.1286157511824
# Increasing beta
# DKL:0.007745, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 226 476.9725374679791
# Increasing beta
# DKL:0.008227, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 227 482.6019982056734
# Beta remains the same
# DKL:0.002484, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 228 489.8266814307125
# Beta remains the same
# DKL:0.002362, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 229 499.0356797190451
# Beta remains the same
# DKL:0.002558, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 230 476.78496923938656
# Beta remains the same
# DKL:0.002719, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 231 462.77981297298646
# Decreasing beta
# DKL:0.001182, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 232 472.5457324222234
# Decreasing beta
# DKL:0.001459, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 233 458.72836653214347
# Beta remains the same
# DKL:0.004710, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 234 434.0951854908558
# Beta remains the same
# DKL:0.001637, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 235 458.6137301959275
# Beta remains the same
# DKL:0.002681, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 236 483.96725501944064
# Beta remains the same
# DKL:0.005209, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 237 446.5225201391865
# Beta remains the same
# DKL:0.001750, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 238 457.48865048634013
# Beta remains the same
# DKL:0.001763, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 239 473.5156300109599
# Beta remains the same
# DKL:0.003187, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 240 475.01086060615836
# Increasing beta
# DKL:0.008310, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 241 443.53214645844463
# Beta remains the same
# DKL:0.005504, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 242 472.7109352731868
# Beta remains the same
# DKL:0.003960, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 243 483.5995662466274
# Beta remains the same
# DKL:0.001525, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 244 447.5493865060336
# Increasing beta
# DKL:0.008003, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 245 433.91932529089206
# Beta remains the same
# DKL:0.004754, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 246 412.93643123307294
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Beta remains the same
# DKL:0.005000, lr_mlt: 2.0736, beta: 1.728
# ********************************
# 247 427.9789765273207
# Beta remains the same
# DKL:0.001733, lr_mlt: 2.0736, beta: 1.728
# ********************************
# 248 481.27798393312486
# Decreasing beta
# DKL:0.001412, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 249 481.86690802464517
# Beta remains the same
# DKL:0.003963, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 250 437.75932815216976
# Beta remains the same
# DKL:0.001583, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 251 458.5355126438761
# Beta remains the same
# DKL:0.004479, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 252 450.81276863779493
# Beta remains the same
# DKL:0.001555, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 253 484.92984219087276
# Decreasing beta
# DKL:0.001256, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 254 420.4817402193471
# Beta remains the same
# DKL:0.002674, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 255 478.5939572517265
# Beta remains the same
# DKL:0.002372, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 256 466.5572328351045
# Beta remains the same
# DKL:0.005301, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 257 425.01986990242096
# Decreasing beta
# DKL:0.001031, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 258 446.98298615941684
# Increasing beta
# DKL:0.006066, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 259 445.656163989957
# Beta remains the same
# DKL:0.002435, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 260 466.7308599289775
# Decreasing beta
# DKL:0.000580, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 261 450.13437940109924
# Beta remains the same
# DKL:0.002009, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 262 472.48975180058005
# Beta remains the same
# DKL:0.002616, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 263 428.20643402783844
# Beta remains the same
# DKL:0.001978, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 264 471.43285492806507
# Beta remains the same
# DKL:0.002701, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 265 455.20581783572106
# Increasing beta
# DKL:0.006205, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 266 460.4100692837793
# Beta remains the same
# DKL:0.001975, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 267 445.7433438419166
# Beta remains the same
# DKL:0.005581, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 268 453.31747212385727
# Beta remains the same
# DKL:0.002475, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 269 423.3489868810424
# Increasing beta
# DKL:0.008582, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 270 464.6051552570877
# Decreasing beta
# DKL:0.001105, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 271 478.0162596704681
# Beta remains the same
# DKL:0.002837, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 272 457.2969421991526
# Beta remains the same
# DKL:0.001940, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 273 450.7865922853139
# Beta remains the same
# DKL:0.003058, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 274 464.45011535838165
# Beta remains the same
# DKL:0.003997, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 275 454.99632805922346
# Decreasing beta
# DKL:0.001302, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 276 448.7354586105768
# Decreasing beta
# DKL:0.000554, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 277 467.6806597780293
# Beta remains the same
# DKL:0.003588, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 278 491.5481279494599
# Beta remains the same
# DKL:0.003084, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 279 462.02358165740077
# Decreasing beta
# DKL:0.001459, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 280 444.50959368398236
# Increasing beta
# DKL:0.006660, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 281 455.50878278600896
# Beta remains the same
# DKL:0.003865, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 282 459.52332439058546
# Increasing beta
# DKL:0.008974, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 283 443.5917488381825
# Beta remains the same
# DKL:0.004046, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 284 445.3263303717237
# Beta remains the same
# DKL:0.003536, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 285 468.6947231017858
# Beta remains the same
# DKL:0.001942, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 286 449.6963687366553
# Beta remains the same
# DKL:0.001828, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 287 466.0002115601943
# Beta remains the same
# DKL:0.003934, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 288 461.99489721327063
# Beta remains the same
# DKL:0.005545, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 289 468.9830552952534
# Beta remains the same
# DKL:0.002664, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 290 478.63182600615
# Decreasing beta
# DKL:0.000798, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 291 432.56996722571455
# Beta remains the same
# DKL:0.004722, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 292 475.050654360624
# Beta remains the same
# DKL:0.005690, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 293 495.74386970239175
# Beta remains the same
# DKL:0.002276, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 294 465.3932290127176
# Beta remains the same
# DKL:0.005938, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 295 467.69969995518096
# Beta remains the same
# DKL:0.003002, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 296 456.5743705511036
# Beta remains the same
# DKL:0.004001, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 297 456.5629458400998
# Beta remains the same
# DKL:0.004480, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 298 457.9035442503049
# Decreasing beta
# DKL:0.001256, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 299 476.9653510939079
# Beta remains the same
# DKL:0.005034, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 300 442.4845232109989
# Beta remains the same
# DKL:0.005237, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 301 464.1329567142335
# Decreasing beta
# DKL:0.001041, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 302 464.2379425624995
# Beta remains the same
# DKL:0.001941, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 303 473.0128573409972
# Increasing beta
# DKL:0.007283, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 304 467.8958240822659
# Beta remains the same
# DKL:0.004281, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 305 457.03079524628885
# Beta remains the same
# DKL:0.001790, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 306 464.46591082638736
# Beta remains the same
# DKL:0.002063, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 307 488.3428073246561
# Increasing beta
# DKL:0.007204, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 308 471.3278005880312
# Beta remains the same
# DKL:0.003111, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 309 487.28180661591085
# Decreasing beta
# DKL:0.001120, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 310 444.4791242514937
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Beta remains the same
# DKL:0.003246, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 311 458.5605533073361
# Beta remains the same
# DKL:0.001853, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 312 477.58015087029224
# Decreasing beta
# DKL:0.000845, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 313 461.8872788160355
# Decreasing beta
# DKL:0.001417, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 314 436.414219280197
# Beta remains the same
# DKL:0.004598, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 315 487.2681935834303
# Beta remains the same
# DKL:0.001925, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 316 489.8526755664172
# Beta remains the same
# DKL:0.002433, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 317 494.7088759771888
# Beta remains the same
# DKL:0.002317, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 318 486.900606499215
# Beta remains the same
# DKL:0.002249, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 319 484.67523826671004
# Decreasing beta
# DKL:0.001269, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 320 485.55221347438544
# Beta remains the same
# DKL:0.001881, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 321 478.8223752573052
# Beta remains the same
# DKL:0.002445, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 322 466.20595291911604
# Beta remains the same
# DKL:0.001694, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 323 490.9588242946828
# Beta remains the same
# DKL:0.005525, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 324 483.0633579297898
# Beta remains the same
# DKL:0.003210, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 325 480.56689718106634
# Beta remains the same
# DKL:0.003948, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 326 484.8380047611807
# Increasing beta
# DKL:0.006497, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 327 491.9614682063748
# Beta remains the same
# DKL:0.002383, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 328 477.97374180692503
# Beta remains the same
# DKL:0.002405, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 329 506.32907124820815
# Decreasing beta
# DKL:0.001384, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 330 483.33745081024125
# Beta remains the same
# DKL:0.004031, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 331 455.6386152878822
# Beta remains the same
# DKL:0.003357, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 332 447.2064534657149
# Beta remains the same
# DKL:0.003255, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 333 448.803080616285
# Beta remains the same
# DKL:0.005461, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 334 484.7640669400618
# Beta remains the same
# DKL:0.003000, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 335 480.3475928853936
# Beta remains the same
# DKL:0.002507, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 336 464.9587426950963
# Increasing beta
# DKL:0.006172, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 337 450.1283118538025
# Beta remains the same
# DKL:0.002698, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 338 480.1950377381174
# Decreasing beta
# DKL:0.001285, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 339 482.19100146829726
# Increasing beta
# DKL:0.008740, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 340 470.170899210301
# Beta remains the same
# DKL:0.002513, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 341 486.345217426718
# Beta remains the same
# DKL:0.003443, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 342 469.34299202131524
# Increasing beta
# DKL:0.006411, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 343 471.4873440006748
# Beta remains the same
# DKL:0.003198, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 344 466.5138186110709
# Decreasing beta
# DKL:0.001099, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 345 495.74452543069884
# Beta remains the same
# DKL:0.002333, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 346 469.23642168012776
# Decreasing beta
# DKL:0.000870, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 347 464.36028273050795
# Beta remains the same
# DKL:0.002831, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 348 474.14912228537577
# Beta remains the same
# DKL:0.003680, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 349 475.8004925284016
# Decreasing beta
# DKL:0.001355, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 350 472.794043548702
# Beta remains the same
# DKL:0.004710, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 351 459.9641893102374
# Increasing beta
# DKL:0.008981, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 352 502.97417520410045
# Increasing beta
# DKL:0.010568, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 353 456.6285871753059
# Beta remains the same
# DKL:0.004954, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 354 501.4572016107715
# Beta remains the same
# DKL:0.002575, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 355 475.68396819368655
# Decreasing beta
# DKL:0.000957, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 356 486.7893193761082
# Beta remains the same
# DKL:0.004987, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 357 488.10286718915876
# Increasing beta
# DKL:0.011596, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 358 494.18396337807883
# Beta remains the same
# DKL:0.002231, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 359 495.3764775219794
# Beta remains the same
# DKL:0.002188, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 360 470.11940022799115
# Beta remains the same
# DKL:0.004000, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 361 492.87533835619377
# Beta remains the same
# DKL:0.003624, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 362 488.9958835334144
# Beta remains the same
# DKL:0.002425, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 363 482.0413988124712
# Beta remains the same
# DKL:0.003621, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 364 497.48155244423816
# Increasing beta
# DKL:0.007107, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 365 478.6318356702477
# Beta remains the same
# DKL:0.002590, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 366 485.6450998058043
# Beta remains the same
# DKL:0.003000, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 367 480.5648184316418
# Beta remains the same
# DKL:0.001677, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 368 465.36679800363345
# Beta remains the same
# DKL:0.004645, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 369 485.4700552049866
# Increasing beta
# DKL:0.006057, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 370 477.23145442893156
# Beta remains the same
# DKL:0.003318, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 371 476.180862237614
# Beta remains the same
# DKL:0.002227, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 372 475.10321478364295
# Beta remains the same
# DKL:0.001729, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 373 484.20238270148565
# Beta remains the same
# DKL:0.002345, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 374 487.4955336166848
# Beta remains the same
# ...
# 2884 514.4096924740655
# Decreasing beta
# DKL:0.000825, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2885 527.04162604105
# Decreasing beta
# DKL:0.000892, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2886 523.5364061391094
# Decreasing beta
# DKL:0.001431, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2887 526.5729801450581
# Beta remains the same
# DKL:0.005037, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2888 526.1521775533026
# Increasing beta
# DKL:0.008513, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2889 519.8413685850925
# Decreasing beta
# DKL:0.001068, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2890 510.6671728220657
# Beta remains the same
# DKL:0.002157, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2891 518.4351519705699
# Beta remains the same
# DKL:0.001504, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2892 528.4386650776876
# Beta remains the same
# DKL:0.003960, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2893 525.5820729360219
# Beta remains the same
# DKL:0.002776, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2894 524.9234732844574
# Increasing beta
# DKL:0.010589, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2895 523.9487715242315
# Beta remains the same
# DKL:0.002117, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2896 529.3137537259944
# Decreasing beta
# DKL:0.001082, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2897 521.5237041858006
# Beta remains the same
# DKL:0.001913, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2898 515.567159778067
# Beta remains the same
# DKL:0.001581, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2899 517.3312404659744
# Decreasing beta
# DKL:0.001133, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2900 521.4514669361913
# Decreasing beta
# DKL:0.001422, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2901 514.7237695940314
# Increasing beta
# DKL:0.006895, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2902 528.4308672093592
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Beta remains the same
# DKL:0.004507, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2903 530.4772109582378
# Beta remains the same
# DKL:0.002062, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2904 521.7959641089667
# Beta remains the same
# DKL:0.002105, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2905 450.18015352847624
# Beta remains the same
# DKL:0.001923, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2906 532.0096448767493
# Decreasing beta
# DKL:0.000570, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2907 524.034153855179
# Decreasing beta
# DKL:0.001271, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2908 488.918401199244
# Beta remains the same
# DKL:0.002850, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2909 524.7031754424949
# Decreasing beta
# DKL:0.000917, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2910 534.0808216497805
# Beta remains the same
# DKL:0.002427, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2911 531.424642821454
# Beta remains the same
# DKL:0.002373, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2912 534.1498737052599
# Beta remains the same
# DKL:0.002235, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2913 525.8092542150907
# Decreasing beta
# DKL:0.001474, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2914 520.4544886774465
# Increasing beta
# DKL:0.010132, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2915 527.9386273832523
# Beta remains the same
# DKL:0.001649, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2916 493.5604292885672
# Increasing beta
# DKL:0.008247, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2917 535.2762037952343
# Beta remains the same
# DKL:0.002081, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2918 532.2497793031181
# Decreasing beta
# DKL:0.001052, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2919 525.5685313247731
# Increasing beta
# DKL:0.009474, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2920 528.1229174020762
# Beta remains the same
# DKL:0.001513, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2921 524.1406833596325
# Decreasing beta
# DKL:0.001096, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2922 535.3173006793746
# Beta remains the same
# DKL:0.002460, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2923 523.154087036319
# Beta remains the same
# DKL:0.002632, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2924 529.6199530584124
# Beta remains the same
# DKL:0.002145, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2925 483.8654110549843
# Increasing beta
# DKL:0.007198, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2926 533.5102582705474
# Beta remains the same
# DKL:0.004286, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2927 527.0705137323793
# Decreasing beta
# DKL:0.000869, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2928 457.3245122028673
# Increasing beta
# DKL:0.008869, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2929 524.6814057687045
# Beta remains the same
# DKL:0.002809, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2930 529.8682125321235
# Beta remains the same
# DKL:0.002799, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2931 525.2792540738002
# Decreasing beta
# DKL:0.000851, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2932 537.5641227380677
# Beta remains the same
# DKL:0.003052, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2933 527.5494775499238
# Beta remains the same
# DKL:0.001795, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2934 538.4035368239479
# Beta remains the same
# DKL:0.002204, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2935 494.37502088146647
# Beta remains the same
# DKL:0.002279, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2936 533.2664668306525
# Beta remains the same
# DKL:0.002655, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2937 538.826142623919
# Beta remains the same
# DKL:0.004598, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2938 514.7749076160226
# Beta remains the same
# DKL:0.002822, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2939 539.2887012852913
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Beta remains the same
# DKL:0.005223, lr_mlt: 2.0736, beta: 1.728
# ********************************
# 2940 524.084581480796
# Decreasing beta
# DKL:0.000777, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2941 534.5533913013821
# Increasing beta
# DKL:0.009262, lr_mlt: 2.0736, beta: 1.728
# ********************************
# 2942 514.7369806772388
# Decreasing beta
# DKL:0.000448, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2943 520.3617156597259
# Decreasing beta
# DKL:0.000905, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2944 527.5348067828312
# Decreasing beta
# DKL:0.000860, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2945 538.8728186055174
# Decreasing beta
# DKL:0.001019, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2946 531.3305512556095
# Decreasing beta
# DKL:0.001407, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2947 530.5415895957192
# Beta remains the same
# DKL:0.001856, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2948 528.3112765694248
# Increasing beta
# DKL:0.006217, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2949 528.1049273032706
# Beta remains the same
# DKL:0.002991, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2950 530.4375186927634
# Beta remains the same
# DKL:0.002684, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2951 527.7170582675675
# Beta remains the same
# DKL:0.003233, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2952 526.5422794551994
# Increasing beta
# DKL:0.010068, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2953 521.3770860643606
# Beta remains the same
# DKL:0.004083, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2954 534.2980527994392
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Increasing beta
# DKL:0.006657, lr_mlt: 2.0736, beta: 2.0736
# ********************************
# 2955 516.0495961688711
# Decreasing beta
# DKL:0.000506, lr_mlt: 2.0736, beta: 1.728
# ********************************
# 2956 525.8144311822547
# Decreasing beta
# DKL:0.000804, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2957 520.2683941220831
# Decreasing beta
# DKL:0.000685, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2958 517.2465652793857
# Decreasing beta
# DKL:0.001279, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2959 516.7747358472814
# Decreasing beta
# DKL:0.001409, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2960 527.1472895320843
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Beta remains the same
# DKL:0.005752, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2961 530.9937904058818
# Decreasing beta
# DKL:0.000463, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2962 537.2680964196807
# Beta remains the same
# DKL:0.002072, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2963 475.5248077291586
# Beta remains the same
# DKL:0.004415, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2964 532.5531770216755
# Beta remains the same
# DKL:0.001585, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2965 518.9352416877321
# Decreasing beta
# DKL:0.001425, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2966 526.2173549920041
# Beta remains the same
# DKL:0.001831, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2967 529.4594085629193
# Beta remains the same
# DKL:0.004193, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2968 524.0616217356775
# Increasing beta
# DKL:0.009168, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2969 529.4837176719768
# Decreasing beta
# DKL:0.001342, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2970 519.8507039412805
# Beta remains the same
# DKL:0.003177, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2971 539.0137679270815
# Decreasing beta
# DKL:0.000532, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2972 529.8993044574115
# Beta remains the same
# DKL:0.003640, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2973 525.35374578071
# Beta remains the same
# DKL:0.003360, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2974 531.0650731918497
# Beta remains the same
# DKL:0.004645, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2975 528.6739280673206
# Beta remains the same
# DKL:0.003488, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2976 535.2822870389116
# Beta remains the same
# DKL:0.002086, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2977 536.3671449758032
# Beta remains the same
# DKL:0.005071, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2978 517.4940072807258
# Beta remains the same
# DKL:0.001639, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2979 526.6236188361526
# Beta remains the same
# DKL:0.001507, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2980 535.9124524832298
# Beta remains the same
# DKL:0.002367, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2981 519.1663000335316
# Increasing beta
# DKL:0.009968, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2982 530.8150635246976
# Beta remains the same
# DKL:0.001589, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2983 534.479334718246
# Decreasing beta
# DKL:0.001024, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2984 529.0479966569728
# Decreasing beta
# DKL:0.001471, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2985 532.1720529568539
# Beta remains the same
# DKL:0.002483, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2986 523.929482316591
# Decreasing beta
# DKL:0.001449, lr_mlt: 2.0736, beta: 0.5787037037037038
# ********************************
# 2987 531.8805284028067
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Increasing beta
# DKL:0.006906, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2988 525.951410433359
# Decreasing beta
# DKL:0.000721, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2989 535.4365822862028
# Decreasing beta
# DKL:0.000975, lr_mlt: 2.0736, beta: 0.8333333333333334
# ********************************
# 2990 528.9678448762418
# Decreasing beta
# DKL:0.001134, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2991 525.9417015650969
# Beta remains the same
# DKL:0.002511, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2992 528.9102120063274
# Beta remains the same
# DKL:0.001908, lr_mlt: 2.0736, beta: 0.6944444444444445
# ********************************
# 2993 536.8287496451305
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# DKL diverges badly, loading earlier version, increasing beta and starting training again
# Decreasing beta
# DKL:0.001075, lr_mlt: 2.0736, beta: 1.44
# ********************************
# 2994 511.7434858181297
# Decreasing beta
# DKL:0.000461, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2995 530.7381787025049
# Decreasing beta
# DKL:0.000685, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2996 521.9927455497025
# Beta remains the same
# DKL:0.002357, lr_mlt: 2.0736, beta: 1.0
# ********************************
# 2997 532.4536842955115
# Increasing beta
# DKL:0.007851, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2998 492.46330708522464
# Beta remains the same
# DKL:0.003241, lr_mlt: 2.0736, beta: 1.2
# ********************************
# 2999 532.7388785499622
# Decreasing beta
# DKL:0.001052, lr_mlt: 2.0736, beta: 1.0
# ********************************

# %%
plt.plot(agent.logger['results'])
plt.show()

# %%
for i in range(3):
    plt.plot(np.array(agent.logger['vars'])[:,i])
plt.show()
