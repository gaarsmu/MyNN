# %%
import numpy as np
import MyNN
import matplotlib.pyplot as plt

# %%
X = (np.random.rand(2, 1000)-0.5)
Y = np.zeros((1,1000))
for i in range(1000):
    if X[0, i] >= X[1,i]:
        Y[0,i] = 1

# %%
nn = MyNN.MyNN(2)
nn.add(1, 'Sigmoid')
nn.compile('Cross entropy')

# %%
print(nn.f_script)
print(nn.b_script)
# Out:
# self.co=np.dot(self.body["W1"],self.co)+self.body["b1"]
# self.cache["Z1"]=self.co
# self.co=1/(1+np.exp(-self.co))
# self.cache["A1"]=self.co
#
# self.co=self.cache["A1"]*(1-self.cache["A1"])*self.co
# self.grads["db1"]=(1/self.batch_size)*np.sum(self.co, axis=1, keepdims=True)
# self.grads["dW1"]=(1/self.batch_size)*np.dot(self.co, self.cache["A0"].T)
# self.co=np.dot(self.body["W1"].T,self.co)

# %%
nn.optimize(X,Y,lr=1, num_iterations=5000,report_cost=True)
# Out:
# Cost after 0 iterations: 0.6081352067879207
# Cost after 100 iterations: 0.27054412686875545
# Cost after 200 iterations: 0.2094887600631257
# Cost after 300 iterations: 0.1806461888727904
# Cost after 400 iterations: 0.16285149745119282
# Cost after 500 iterations: 0.15038719936791123
# Cost after 600 iterations: 0.14098265150001332
# Cost after 700 iterations: 0.13353168413283742
# Cost after 800 iterations: 0.12742133865348396
# Cost after 900 iterations: 0.12228026501937536
# Cost after 1000 iterations: 0.11786822649562986
# Cost after 1100 iterations: 0.11402177650460493
# Cost after 1200 iterations: 0.11062518392250871
# Cost after 1300 iterations: 0.10759380270082915
# Cost after 1400 iterations: 0.10486403678261133
# Cost after 1500 iterations: 0.10238701208728966
# Cost after 1600 iterations: 0.10012443605094684
# Cost after 1700 iterations: 0.09804580204577021
# Cost after 1800 iterations: 0.09612645006717709
# Cost after 1900 iterations: 0.09434618934681015
# Cost after 2000 iterations: 0.09268829960737145
# Cost after 2100 iterations: 0.09113879347023167
# Cost after 2200 iterations: 0.08968586274731986
# Cost after 2300 iterations: 0.08831945662766955
# Cost after 2400 iterations: 0.08703095605518722
# Cost after 2500 iterations: 0.08581291932260633
# Cost after 2600 iterations: 0.08465888111710632
# Cost after 2700 iterations: 0.08356319218832328
# Cost after 2800 iterations: 0.08252089024398336
# Cost after 2900 iterations: 0.0815275951051292
# Cost after 3000 iterations: 0.08057942289172224
# Cost after 3100 iterations: 0.07967291527146166
# Cost after 3200 iterations: 0.07880498073167452
# Cost after 3300 iterations: 0.07797284552262744
# Cost after 3400 iterations: 0.07717401243724652
# Cost after 3500 iterations: 0.07640622598365786
# Cost after 3600 iterations: 0.07566744280619139
# Cost after 3700 iterations: 0.0749558064411805
# Cost after 3800 iterations: 0.07426962567314858
# Cost after 3900 iterations: 0.07360735589730681
# Cost after 4000 iterations: 0.07296758300492372
# Cost after 4100 iterations: 0.0723490093959282
# Cost after 4200 iterations: 0.07175044179322383
# Cost after 4300 iterations: 0.07117078058952289
# Cost after 4400 iterations: 0.07060901050301298
# Cost after 4500 iterations: 0.0700641923551318
# Cost after 4600 iterations: 0.06953545581389799
# Cost after 4700 iterations: 0.06902199297099693
# Cost after 4800 iterations: 0.06852305264121858
# Cost after 4900 iterations: 0.06803793528972853
# Cost after 5000 iterations: 0.0675659885066869

# %%
X = (np.random.rand(2, 1000)-0.5)
Y = np.zeros((1,1000))
for i in range(1000):
    if X[0, i] * X[1,i] >= 0:
        Y[0,i] = 1

# %%
plt.scatter(X[0,:], X[1,:], c=Y, cmap=plt.cm.Spectral)
plt.show()

# %%
nn = MyNN.MyNN(2)
nn.add(4, 'ReLU')
nn.add(1, 'Sigmoid')
nn.compile('Cross entropy')

# %%
print(nn.f_script)
print(nn.b_script)
# Out:
# self.co=np.dot(self.body["W1"],self.co)+self.body["b1"]
# self.cache["Z1"]=self.co
# self.co[self.co<0]=0
# self.cache["A1"]=self.co
# self.co=np.dot(self.body["W2"],self.co)+self.body["b2"]
# self.cache["Z2"]=self.co
# self.co=1/(1+np.exp(-self.co))
# self.cache["A2"]=self.co
#
# self.co=self.cache["A2"]*(1-self.cache["A2"])*self.co
# self.grads["db2"]=(1/self.batch_size)*np.sum(self.co, axis=1, keepdims=True)
# self.grads["dW2"]=(1/self.batch_size)*np.dot(self.co, self.cache["A1"].T)
# self.co=np.dot(self.body["W2"].T,self.co)
# self.co[self.cache["Z1"]<=0]=0
# self.grads["db1"]=(1/self.batch_size)*np.sum(self.co, axis=1, keepdims=True)
# self.grads["dW1"]=(1/self.batch_size)*np.dot(self.co, self.cache["A0"].T)
# self.co=np.dot(self.body["W1"].T,self.co)

# %%
print(nn.body)
# Out:
# {'W2': array([[-0.10038231,  0.38593571,  0.17835774,  0.68952639]]), 'b2': array([[ 0.]]), 'W1': array([[ 0.40481249,  0.90233884],
#        [-1.10733643,  0.94799482],
#        [-0.19054239, -0.73815418],
#        [-0.28288577, -0.17186319]]), 'b1': array([[ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.]])}

# %%
nn.optimize(X,Y,lr=0.1, num_iterations=10000,report_cost=True, report_cost_freq=500)
# Out:
# Cost after 0 iterations: 0.33090364471874845
# Cost after 100 iterations: 0.3109901157856206
# Cost after 200 iterations: 0.2940967506783396
# Cost after 300 iterations: 0.27949354237475504
# Cost after 400 iterations: 0.26670874283192
# Cost after 500 iterations: 0.2553723295457753
# Cost after 600 iterations: 0.24525803034890456
# Cost after 700 iterations: 0.2361324030370666
# Cost after 800 iterations: 0.2278167434263427
# Cost after 900 iterations: 0.2201747917777546
# Cost after 1000 iterations: 0.21315588864925844
# Cost after 1100 iterations: 0.2066846472149158
# Cost after 1200 iterations: 0.20067038650092803
# Cost after 1300 iterations: 0.19507281796755555
# Cost after 1400 iterations: 0.1898851895782325
# Cost after 1500 iterations: 0.18505343318679493
# Cost after 1600 iterations: 0.18052630387408306
# Cost after 1700 iterations: 0.1762656359857544
# Cost after 1800 iterations: 0.17223932641345813
# Cost after 1900 iterations: 0.16843822910301487
# Cost after 2000 iterations: 0.16484050538055445
# Cost after 2100 iterations: 0.16143477612909643
# Cost after 2200 iterations: 0.15819879603309336
# Cost after 2300 iterations: 0.15512193010703595
# Cost after 2400 iterations: 0.15219443917961462
# Cost after 2500 iterations: 0.14940267244902575
# Cost after 2600 iterations: 0.14675820339504458
# Cost after 2700 iterations: 0.14423990291554595
# Cost after 2800 iterations: 0.14184935984690009
# Cost after 2900 iterations: 0.1395633869606627
# Cost after 3000 iterations: 0.1373769806362485
# Cost after 3100 iterations: 0.13528649412125976
# Cost after 3200 iterations: 0.13328303413654877
# Cost after 3300 iterations: 0.13135953969401595
# Cost after 3400 iterations: 0.12951006645554675
# Cost after 3500 iterations: 0.1277321422590257
# Cost after 3600 iterations: 0.12602407244810196
# Cost after 3700 iterations: 0.1243760784282666
# Cost after 3800 iterations: 0.12278484053584278
# Cost after 3900 iterations: 0.12124577367627412
# Cost after 4000 iterations: 0.11975424990042921
# Cost after 4100 iterations: 0.11830748623365274
# Cost after 4200 iterations: 0.11691087382136162
# Cost after 4300 iterations: 0.1155593717594276
# Cost after 4400 iterations: 0.1142520537349417
# Cost after 4500 iterations: 0.11298484006890173
# Cost after 4600 iterations: 0.11175632561503172
# Cost after 4700 iterations: 0.1105650689768726
# Cost after 4800 iterations: 0.10940678799113789
# Cost after 4900 iterations: 0.10828133577443999
# Cost after 5000 iterations: 0.10718789238308792
# Cost after 5100 iterations: 0.10612262724668116
# Cost after 5200 iterations: 0.10508389143307181
# Cost after 5300 iterations: 0.10407143753250539
# Cost after 5400 iterations: 0.10308496506309701
# Cost after 5500 iterations: 0.10212312599607964
# Cost after 5600 iterations: 0.10118516898335557
# Cost after 5700 iterations: 0.10026944720484718
# Cost after 5800 iterations: 0.09937748253366475
# Cost after 5900 iterations: 0.09850584204453144
# Cost after 6000 iterations: 0.09765335924773436
# Cost after 6100 iterations: 0.0968195243582505
# Cost after 6200 iterations: 0.09600531471055167
# Cost after 6300 iterations: 0.09520881573976968
# Cost after 6400 iterations: 0.09443309368373405
# Cost after 6500 iterations: 0.09367514094967723
# Cost after 6600 iterations: 0.09293253006049304
# Cost after 6700 iterations: 0.0922047540970942
# Cost after 6800 iterations: 0.09149167632175913
# Cost after 6900 iterations: 0.09079327807039354
# Cost after 7000 iterations: 0.09010907178392212
# Cost after 7100 iterations: 0.08943916982313628
# Cost after 7200 iterations: 0.08878376580716216
# Cost after 7300 iterations: 0.08814174478685033
# Cost after 7400 iterations: 0.08751150925258802
# Cost after 7500 iterations: 0.08689268779139067
# Cost after 7600 iterations: 0.08628528146068286
# Cost after 7700 iterations: 0.08568913296441454
# Cost after 7800 iterations: 0.08510539670819964
# Cost after 7900 iterations: 0.08453226671093378
# Cost after 8000 iterations: 0.08396957795099069
# Cost after 8100 iterations: 0.08341668268715834
# Cost after 8200 iterations: 0.08287341483889296
# Cost after 8300 iterations: 0.08233961112595088
# Cost after 8400 iterations: 0.08181487528247937
# Cost after 8500 iterations: 0.0812986509632504
# Cost after 8600 iterations: 0.0807907519929957
# Cost after 8700 iterations: 0.08029170331064626
# Cost after 8800 iterations: 0.07980261693333096
# Cost after 8900 iterations: 0.07932196500598306
# Cost after 9000 iterations: 0.07884883918461735
# Cost after 9100 iterations: 0.07838298037103682
# Cost after 9200 iterations: 0.07792414079338757
# Cost after 9300 iterations: 0.0774721304542811
# Cost after 9400 iterations: 0.07702677945027003
# Cost after 9500 iterations: 0.07658809086771341
# Cost after 9600 iterations: 0.07615593242182038
# Cost after 9700 iterations: 0.07572997409452174
# Cost after 9800 iterations: 0.07531007679838912
# Cost after 9900 iterations: 0.07489610703813278
# Cost after 10000 iterations: 0.07448793891275092
