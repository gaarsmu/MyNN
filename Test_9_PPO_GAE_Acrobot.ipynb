# %%
import os
path = os.environ['MyNN']
os.sys.path.append(path)
import MyNN
import gym
import numpy as np
import collections

# %%
class ACAgent:
    def __init__(self, state_size, action_size, gamma=0.95, lam=0.98,
                 actor_lr=0.001, critic_lr=0.01, method='PPO_CEM', w=0.98):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma  # discount rate
        self.lam = lam # GAE disc rate
        self.actor_lr = actor_lr
        self.critic_lr = critic_lr
        self.method = method
        self.actor = self._build_model()
        self.critic = self._build_vf()
        self.actor.lr = actor_lr
        self.critic.lr = critic_lr
        self.scaler = MyNN.Scaler(state_size,w)
        self.replay_buff_x = None
        self.replay_buff_y = None

    def _build_model(self):
        model = MyNN.MyNN(self.state_size)
        model.add(self.state_size*5, 'Tanh')
        model.add(int(np.sqrt(self.action_size*self.state_size)*5), 'Tanh')
        model.add(self.action_size*5, 'Tanh')
        model.add(self.action_size, 'Softmax')
        model.compile(self.method, 'Adam')
        return model
    
    def _build_vf(self):
        model = MyNN.MyNN(self.state_size)
        model.add(self.state_size*5, 'Tanh')
        model.add(int(np.sqrt(self.action_size)*5), 'Tanh')
        model.add(5, 'Tanh')
        model.add(1, 'Linear')
        model.compile('MSE', 'Adam')
        return model
    
    def value_function_fit(self, x, y):
        if self.replay_buff_x is None:
            x_train, y_train = x, y
        else:
            x_train = np.hstack([x, self.replay_buff_x])
            y_train = np.hstack([y, self.replay_buff_y])
        self.replay_buff_x = x
        self.replay_buff_y = y
        self.critic.optimize(x_train, y_train, num_epochs=10, 
                             report_cost=False, batch_size=128, 
                            lr = self.critic_lr)

    def act(self, state):
        result = self.actor.forward(state, caching='no')
        return result

# %%
def running_reward(rewards, gamma):
    result = []
    run_rew = 0
    for reward in  rewards[0,:][::-1]:
        run_rew = run_rew*gamma + reward
        result.append(run_rew)
    return np.array(result[::-1]).reshape(1,-1)

def encode(actions, action_size):
    result = np.zeros((action_size, actions.shape[1]))
    result[actions, range(actions.shape[1])] = 1
    return result

def add_gae(traj, gamma, lam):
    rewards = traj['rewards'] #*(1-gamma)
    values = traj['values']
    traj['tds'] = rewards - values + np.append(traj['values'][0, 1:] * agent.gamma, 0).reshape(1,-1)
    gae = running_reward(traj['tds'], gamma*lam)
    return gae

# %%
def play_game(agent, render=False):
    state = env.reset().reshape((agent.state_size,1))
    unscaled_states = []
    states = []
    probs = []
    actions = []
    rewards = []
    done = False
    mean, var = agent.scaler.get()
    while not done:
        if render:
            env.render()
        unscaled_states.append(state)
        scaled_state = (state-mean)/var
        states.append(scaled_state)
        prob = agent.act(scaled_state)
        probs.append(prob)
        action = np.random.choice(range(agent.action_size), p=prob[:,0])
        actions.append(action)
        state, reward, done, _ = env.step(action)
        state = state.reshape((agent.state_size,1))
        rewards.append(reward)
        if done:
            break
    return {'unscaled': np.hstack(unscaled_states), 'states' : np.hstack(states),
            'probs': np.hstack(probs), 'actions': np.array(actions).reshape(1,-1),
            'rewards': np.array(rewards).reshape(1,-1)}

# %%
def play_n_games(agent, n=20):
    trajectories = []
    leng = 0
    for i in range(n):
        trajectory = play_game(agent)
        trajectories.append(trajectory)
        leng += trajectory['actions'].shape[1]
        if leng >= 20000:
            break
    return trajectories

# %%
def build_train_set(agent, trajectories):
    for traj in trajectories:
        traj['disc_sum_rew'] = running_reward(traj['rewards'], agent.gamma) #*(1-agent.gamma)
        traj['values'] = agent.critic.forward(traj['states'])
        traj['GAE'] = add_gae(traj, agent.gamma, agent.lam)
        traj['enc_actions'] = encode(traj['actions'], agent.action_size)
    X = np.hstack([t['states'] for t in trajectories])
    Y = np.hstack([t['probs'] for t in trajectories])
    actions = np.hstack([t['enc_actions'] for t in trajectories])
    disc_sum_rew = np.hstack([t['disc_sum_rew'] for t in trajectories])
    adv = np.hstack([t['GAE'] for t in trajectories])
    adv = (adv - adv.mean())/(adv.std() + 1e-6)
    return X, np.clip(Y, 0.001, 0.999), actions, adv, disc_sum_rew

# %%
env = gym.make('Acrobot-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
base_lr = 0.001
agent = ACAgent(state_size, action_size, actor_lr=base_lr,
                critic_lr=base_lr*2, gamma=0.995, lam=0.98, method='PPO_CEM', w=1)
l=0
DKL_targ = 0.005
beta = 1
eta = 30

# %%
results = []
result = -500

# %%
# %%time
for time in range(1, 1001):
    trajectories = play_n_games(agent, n=5)
    agent.scaler.update(np.hstack([t['unscaled'] for t in trajectories]))
    score = np.mean([(np.sum(t['rewards']), np.var(t['rewards'])) for t in trajectories], axis=0)
    X_batch, Y_batch, actions, adv, disc_sum_rew = build_train_set(agent, trajectories)
    for i in range(10):
        A = agent.actor.forward(X_batch)
        DKL = np.sum(Y_batch*np.log(np.divide(Y_batch,A)))/Y_batch.shape[1]
        if DKL > DKL_targ*4:
            print('Beta is too small')
            break
        agent.actor.cache['A0'] = X_batch
        agent.actor.backward(A, Y_batch, adv,actions=actions,
                             beta=beta, eta=eta, DKL=DKL, DKL_targ = DKL_targ)
        agent.actor.number_of_updates +=1
        agent.actor.update_parameters()
    if DKL > DKL_targ*2:
        beta = np.minimum(35, beta*1.5)
        print('Increasing beta')
        if beta > 30:
            agent.actor.lr = np.minimum(agent.actor.lr/1.1, base_lr*0.1)
            print('Decreasing learning rate')
    elif DKL < DKL_targ*0.5:
        beta = np.maximum(1/35, beta/1.5)
        print('Decreasing beta')
        if beta < 1/30:
            agent.actor.lr = np.maximum(agent.actor.lr*1.1, base_lr*10)
            print('Increasing learning rate')
    else:
        print('Beta remains the same')
    agent.value_function_fit(X_batch, disc_sum_rew)
    print(time, score[0], DKL, beta)
    result = result*0.98+score[0]*0.02
    results.append(result)
    if time % 50 == 0:
        agent.actor.save(path='actor_PPO_PONG.mnnd')
        agent.critic.save(path='critic_PPO_PONG.mnnd')
        agent.scaler.save(path='scaler_PPO_PONG.mnnd')
# Out:
# Beta remains the same
# 1 -500.0 0.003901227229019361 1
# Decreasing beta
# 2 -500.0 0.0017463547645250297 0.6666666666666666
# Decreasing beta
# 3 -446.8 0.0018694772017171708 0.4444444444444444
# Beta remains the same
# 4 -481.8 0.004118264345571414 0.4444444444444444
# Decreasing beta
# 5 -465.8 0.0022288125482260563 0.2962962962962963
# Beta remains the same
# 6 -430.2 0.0077842537674462 0.2962962962962963
# Beta remains the same
# 7 -440.2 0.009268151645201292 0.2962962962962963
# Increasing beta
# 8 -425.2 0.01996141048475694 0.4444444444444444
# Beta remains the same
# 9 -411.2 0.0026998430922324664 0.4444444444444444
# Beta remains the same
# 10 -402.8 0.004347369882423751 0.4444444444444444
# Beta remains the same
# 11 -380.2 0.003331521094605571 0.4444444444444444
# Beta remains the same
# 12 -351.6 0.0075181237974528215 0.4444444444444444
# Beta remains the same
# 13 -340.0 0.007522909578493126 0.4444444444444444
# Beta remains the same
# 14 -345.8 0.0035694631494119396 0.4444444444444444
# Beta remains the same
# 15 -334.0 0.00471397212218961 0.4444444444444444
# Beta remains the same
# 16 -348.4 0.00588270151082064 0.4444444444444444
# Beta remains the same
# 17 -345.8 0.006011159650810934 0.4444444444444444
# Beta remains the same
# 18 -316.0 0.0027006855886011734 0.4444444444444444
# Beta remains the same
# 19 -270.4 0.009570015718477173 0.4444444444444444
# Beta remains the same
# 20 -258.6 0.004435096148908482 0.4444444444444444
# Decreasing beta
# 21 -251.8 0.0021041986449924777 0.2962962962962963
# Decreasing beta
# 22 -315.4 0.0018895168137390396 0.19753086419753085
# Decreasing beta
# 23 -214.4 0.001393311427526777 0.1316872427983539
# Beta remains the same
# 24 -239.6 0.004577676086705086 0.1316872427983539
# Beta is too small
# Increasing beta
# 25 -273.2 0.021172545091043833 0.19753086419753085
# Increasing beta
# 26 -310.6 0.017807906979809423 0.2962962962962963
# Beta remains the same
# 27 -232.2 0.003384211581622196 0.2962962962962963
# Beta remains the same
# 28 -218.8 0.005809000189987444 0.2962962962962963
# Increasing beta
# 29 -191.4 0.01825626361916631 0.4444444444444444
# Beta remains the same
# 30 -200.0 0.005809167776846289 0.4444444444444444
# Beta remains the same
# 31 -190.6 0.007713948336907934 0.4444444444444444
# Beta remains the same
# 32 -156.2 0.003110807532522258 0.4444444444444444
# Beta remains the same
# 33 -129.6 0.0077299011390045596 0.4444444444444444
# Beta remains the same
# 34 -161.8 0.004628121173701794 0.4444444444444444
# Increasing beta
# 35 -149.4 0.013343095400820232 0.6666666666666666
# Beta is too small
# Increasing beta
# 36 -125.6 0.021784573517757193 1.0
# Beta remains the same
# 37 -128.8 0.003136558288584466 1.0
# Beta remains the same
# 38 -107.6 0.00268898835939343 1.0
# Beta remains the same
# 39 -137.2 0.002798756260372601 1.0
# Beta remains the same
# 40 -119.0 0.00788382088973135 1.0
# Increasing beta
# 41 -101.6 0.0142078928712949 1.5
# Beta remains the same
# 42 -104.2 0.008235369191008474 1.5
# Beta remains the same
# 43 -107.6 0.00373940861845809 1.5
# Beta remains the same
# 44 -114.8 0.0025677928149921217 1.5
# Beta remains the same
# 45 -105.0 0.0028393390717617413 1.5
# Beta remains the same
# 46 -132.0 0.0030110752109841514 1.5
# Decreasing beta
# 47 -115.4 0.001476035366533786 1.0
# Increasing beta
# 48 -115.8 0.017952122992692242 1.5
# Decreasing beta
# 49 -128.4 0.0016879081229369446 1.0
# Beta remains the same
# 50 -110.6 0.0073392484709264814 1.0
# Decreasing beta
# 51 -126.8 0.0022658682150874447 0.6666666666666666
# Decreasing beta
# 52 -105.4 0.0017909501248838673 0.4444444444444444
# Beta is too small
# Increasing beta
# 53 -120.4 0.020877741823026676 0.6666666666666666
# Beta remains the same
# 54 -103.2 0.00574732755375017 0.6666666666666666
# Beta remains the same
# 55 -118.4 0.0036242903323436605 0.6666666666666666
# Decreasing beta
# 56 -110.0 0.0020592670006075913 0.4444444444444444
# Decreasing beta
# 57 -102.6 0.001719113943595638 0.2962962962962963
# Decreasing beta
# 58 -100.6 0.0008121249307970529 0.19753086419753085
# Beta remains the same
# 59 -107.8 0.005191369112498567 0.19753086419753085
# Increasing beta
# 60 -100.6 0.01656754830138315 0.2962962962962963
# Beta remains the same
# 61 -116.0 0.00971143112398641 0.2962962962962963
# Beta remains the same
# 62 -92.2 0.0033592146387471968 0.2962962962962963
# Beta is too small
# Increasing beta
# 63 -94.6 0.023405804043751522 0.4444444444444444
# Beta remains the same
# 64 -117.0 0.0037868794498767014 0.4444444444444444
# Beta remains the same
# 65 -88.4 0.008323089393719188 0.4444444444444444
# Beta is too small
# Increasing beta
# 66 -90.2 0.02367502924539419 0.6666666666666666
# Decreasing beta
# 67 -89.0 0.0021631608052080846 0.4444444444444444
# Beta remains the same
# 68 -88.4 0.0030581095922828446 0.4444444444444444
# Increasing beta
# 69 -90.2 0.015775404642875645 0.6666666666666666
# Decreasing beta
# 70 -88.8 0.002141877084980394 0.4444444444444444
# Beta is too small
# Increasing beta
# 71 -86.2 0.02009905962478862 0.6666666666666666
# Decreasing beta
# 72 -82.8 0.0012249519886638213 0.4444444444444444
# Decreasing beta
# 73 -94.2 0.0021301074995857053 0.2962962962962963
# Increasing beta
# 74 -92.6 0.01669458235048622 0.4444444444444444
# Increasing beta
# 75 -95.2 0.019533169067894797 0.6666666666666666
# Beta remains the same
# 76 -125.4 0.004466375018985835 0.6666666666666666
# Beta remains the same
# 77 -85.4 0.009947493617622396 0.6666666666666666
# Decreasing beta
# 78 -88.4 0.0019892149640832594 0.4444444444444444
# Beta remains the same
# 79 -93.0 0.005494191126372724 0.4444444444444444
# Beta remains the same
# 80 -89.8 0.0027298370379059225 0.4444444444444444
# Increasing beta
# 81 -89.0 0.014483264411947354 0.6666666666666666
# Decreasing beta
# 82 -79.8 0.001103220785634133 0.4444444444444444
# Beta remains the same
# 83 -84.6 0.008668338434367009 0.4444444444444444
# Increasing beta
# 84 -100.6 0.013743528634774807 0.6666666666666666
# Beta remains the same
# 85 -104.0 0.002985931190804586 0.6666666666666666
# Beta remains the same
# 86 -92.0 0.004280819733420455 0.6666666666666666
# Beta remains the same
# 87 -92.4 0.002895653961145234 0.6666666666666666
# Beta remains the same
# 88 -97.4 0.008326972751093691 0.6666666666666666
# Beta remains the same
# 89 -87.2 0.007673722763973617 0.6666666666666666
# Beta is too small
# Increasing beta
# 90 -129.2 0.030076800163605755 1.0
# Beta remains the same
# 91 -86.2 0.0036788441056933964 1.0
# Decreasing beta
# 92 -95.2 0.002413796673220527 0.6666666666666666
# Beta remains the same
# 93 -108.6 0.005855310864904388 0.6666666666666666
# Beta is too small
# Increasing beta
# 94 -87.4 0.020590307325052907 1.0
# Beta remains the same
# 95 -95.4 0.0035345930146671108 1.0
# Increasing beta
# 96 -84.2 0.017521738543781903 1.5
# Beta remains the same
# 97 -84.4 0.0034815622307736217 1.5
# Beta remains the same
# 98 -140.4 0.002545275508152044 1.5
# Beta remains the same
# 99 -79.2 0.0034165251362784535 1.5
# Decreasing beta
# 100 -86.0 0.0020594331045891644 1.0
# Beta remains the same
# 101 -118.4 0.008515645813215096 1.0
# Beta remains the same
# 102 -104.6 0.004061207825297453 1.0
# Beta remains the same
# 103 -84.6 0.009499461421732733 1.0
# Beta remains the same
# 104 -94.0 0.002799523673932039 1.0
# Beta remains the same
# 105 -79.4 0.008319730369226204 1.0
# Beta remains the same
# 106 -91.2 0.003304382694474283 1.0
# Increasing beta
# 107 -93.2 0.010379503974709546 1.5
# Increasing beta
# 108 -88.2 0.015459431644096454 2.25
# Decreasing beta
# 109 -89.6 0.001187223750018077 1.5
# Beta remains the same
# 110 -88.8 0.0031043936196818345 1.5
# Decreasing beta
# 111 -81.2 0.0014006432605503767 1.0
# Decreasing beta
# 112 -81.8 0.0016093762020028331 0.6666666666666666
# Decreasing beta
# 113 -92.2 0.0014813483480162171 0.4444444444444444
# Increasing beta
# 114 -82.6 0.012884190697587424 0.6666666666666666
# Beta is too small
# Increasing beta
# 115 -86.6 0.021747713205139813 1.0
# Beta remains the same
# 116 -86.6 0.004017560703031691 1.0
# Beta remains the same
# 117 -89.2 0.009841649081592341 1.0
# Beta remains the same
# 118 -84.2 0.0035017224364079316 1.0
# Beta is too small
# Increasing beta
# 119 -149.2 0.023248891758422468 1.5
# Increasing beta
# 120 -84.0 0.011827156612925443 2.25
# Beta remains the same
# 121 -89.6 0.004419877681222548 2.25
# Beta remains the same
# 122 -130.2 0.002877082043190936 2.25
# Decreasing beta
# 123 -99.0 0.001815073513067102 1.5
# Beta remains the same
# 124 -77.8 0.005802325130766645 1.5
# Beta remains the same
# 125 -91.6 0.0029483620344363426 1.5
# Beta remains the same
# 126 -97.0 0.002784685586066367 1.5
# Beta remains the same
# 127 -80.8 0.006976853949506469 1.5
# Beta remains the same
# 128 -92.4 0.004195835949019119 1.5
# Decreasing beta
# 129 -86.6 0.001673890931576438 1.0
# Beta remains the same
# 130 -74.4 0.0074673071887498685 1.0
# Beta remains the same
# 131 -88.2 0.006973822376567263 1.0
# Increasing beta
# 132 -85.4 0.010341657445349041 1.5
# Beta remains the same
# 133 -92.4 0.007265805471982758 1.5
# Decreasing beta
# 134 -90.2 0.0016286434604408538 1.0
# Beta remains the same
# 135 -106.0 0.005572134028919977 1.0
# Beta remains the same
# 136 -88.2 0.007819938215033646 1.0
# Beta remains the same
# 137 -82.4 0.00837916273770851 1.0
# Decreasing beta
# 138 -134.4 0.0020357036174743796 0.6666666666666666
# Increasing beta
# 139 -88.8 0.013667102643660473 1.0
# Beta remains the same
# 140 -84.8 0.003908832844018028 1.0
# Beta remains the same
# 141 -90.0 0.003316002364281042 1.0
# Decreasing beta
# 142 -84.8 0.0024442591859548065 0.6666666666666666
# Beta remains the same
# 143 -94.0 0.0038187345830765873 0.6666666666666666
# Beta remains the same
# 144 -84.6 0.0056680160405905835 0.6666666666666666
# Beta remains the same
# 145 -104.6 0.004410800552150886 0.6666666666666666
# Beta remains the same
# 146 -80.6 0.005486601102867309 0.6666666666666666
# Beta remains the same
# 147 -88.4 0.009558453279259305 0.6666666666666666
# Increasing beta
# 148 -87.8 0.010462730109065364 1.0
# Increasing beta
# 149 -91.0 0.010897533964749306 1.5
# Beta remains the same
# 150 -86.0 0.0034562793838672896 1.5
# Decreasing beta
# 151 -110.2 0.0019727521080667903 1.0
# Increasing beta
# 152 -83.6 0.01557253791661046 1.5
# Beta remains the same
# 153 -88.6 0.004897852192037547 1.5
# Beta remains the same
# 154 -85.6 0.0027644311645263413 1.5
# Decreasing beta
# 155 -111.4 0.0013536665891272347 1.0
# Increasing beta
# 156 -85.0 0.011704436157144773 1.5
# Beta remains the same
# 157 -78.6 0.006214155725124698 1.5
# Decreasing beta
# 158 -88.8 0.0015738849798852034 1.0
# Beta remains the same
# 159 -77.8 0.007641234680554307 1.0
# Beta remains the same
# 160 -82.0 0.0062226054045604025 1.0
# Beta remains the same
# 161 -99.0 0.00624589392536638 1.0
# Beta remains the same
# 162 -80.4 0.008076243173348823 1.0
# Beta is too small
# Increasing beta
# 163 -77.2 0.024984905931046835 1.5
# Decreasing beta
# 164 -82.6 0.0018792708314194805 1.0
# Beta remains the same
# 165 -80.2 0.009244481278036372 1.0
# Decreasing beta
# 166 -119.2 0.0019749822702276533 0.6666666666666666
# Decreasing beta
# 167 -91.0 0.0018482347614361791 0.4444444444444444
# Increasing beta
# 168 -91.4 0.015577046220501886 0.6666666666666666
# Increasing beta
# 169 -92.0 0.013431072657190155 1.0
# Beta is too small
# Increasing beta
# 170 -71.4 0.022755435090974267 1.5
# Beta remains the same
# 171 -89.4 0.005839550474621346 1.5
# Beta remains the same
# 172 -76.8 0.006350797284617582 1.5
# Increasing beta
# 173 -81.2 0.010449843660904788 2.25
# Beta remains the same
# 174 -86.0 0.0025175312516709683 2.25
# Beta remains the same
# 175 -75.0 0.002855461786435759 2.25
# Decreasing beta
# 176 -84.2 0.002486622167905618 1.5
# Beta remains the same
# 177 -89.0 0.005808757532036513 1.5
# Beta remains the same
# 178 -82.4 0.005895931298380069 1.5
# Beta remains the same
# 179 -86.8 0.00826872309780431 1.5
# Beta remains the same
# 180 -81.2 0.0052955454575553595 1.5
# Decreasing beta
# 181 -82.2 0.0018698261853943225 1.0
# Beta remains the same
# 182 -80.6 0.007973533322920648 1.0
# Beta remains the same
# 183 -84.8 0.00853180450719175 1.0
# Beta remains the same
# 184 -88.6 0.007895812644544756 1.0
# Beta remains the same
# 185 -85.0 0.009452805903741535 1.0
# Beta remains the same
# 186 -131.0 0.0026843198637210917 1.0
# Increasing beta
# 187 -79.2 0.01090173458940919 1.5
# Beta remains the same
# 188 -81.8 0.004851317903740575 1.5
# Decreasing beta
# 189 -83.0 0.0016175809772907654 1.0
# Beta remains the same
# 190 -79.6 0.00905941493455587 1.0
# Beta remains the same
# 191 -77.6 0.007613937065673302 1.0
# Decreasing beta
# 192 -71.0 0.0018125314131622744 0.6666666666666666
# Beta remains the same
# 193 -90.6 0.003335442807615999 0.6666666666666666
# Beta remains the same
# 194 -78.0 0.009980683584430224 0.6666666666666666
# Increasing beta
# 195 -87.6 0.01701363088629198 1.0
# Beta remains the same
# 196 -96.2 0.0030904883792991483 1.0
# Beta is too small
# Increasing beta
# 197 -102.6 0.02017939907931357 1.5
# Beta remains the same
# 198 -83.0 0.009319351746416417 1.5
# Beta remains the same
# 199 -76.8 0.004969446726314856 1.5
# Increasing beta
# 200 -116.6 0.015628820689357684 2.25
# Beta remains the same
# 201 -83.2 0.004070512515232981 2.25
# Decreasing beta
# 202 -93.0 0.0021693971769557734 1.5
# Increasing beta
# 203 -71.0 0.010048713876814653 2.25
# Decreasing beta
# 204 -82.6 0.0018938901524959424 1.5
# Beta remains the same
# 205 -76.4 0.0045683266081356505 1.5
# Beta remains the same
# 206 -86.4 0.0026354805485690343 1.5
# Beta remains the same
# 207 -73.8 0.003961784631068978 1.5
# Decreasing beta
# 208 -93.2 0.0018188112492274675 1.0
# Beta remains the same
# 209 -81.4 0.003446788843020194 1.0
# Beta remains the same
# 210 -76.6 0.009102613147450592 1.0
# Beta remains the same
# 211 -82.0 0.007150043188885537 1.0
# Beta remains the same
# 212 -87.4 0.0051957665848470684 1.0
# Increasing beta
# 213 -99.6 0.010572021415034903 1.5
# Beta remains the same
# 214 -80.0 0.00460949271602518 1.5
# Beta remains the same
# 215 -93.6 0.0037436234749580115 1.5
# Beta remains the same
# 216 -120.4 0.00393021270662989 1.5
# Beta remains the same
# 217 -80.4 0.00283430061596011 1.5
# Beta remains the same
# 218 -94.8 0.005717614860887618 1.5
# Decreasing beta
# 219 -80.0 0.0022993661438513277 1.0
# Decreasing beta
# 220 -89.6 0.0023150283651034906 0.6666666666666666
# Beta remains the same
# 221 -85.8 0.004441700721579767 0.6666666666666666
# Beta is too small
# Increasing beta
# 222 -94.2 0.024444472805349095 1.0
# Beta remains the same
# 223 -83.2 0.0059915854449745015 1.0
# Beta remains the same
# 224 -108.6 0.005376158726767228 1.0
# Increasing beta
# 225 -87.0 0.013548029236398022 1.5
# Beta remains the same
# 226 -79.0 0.006730502843564503 1.5
# Beta remains the same
# 227 -85.0 0.005672598500074807 1.5
# Beta remains the same
# 228 -93.8 0.005458197659071439 1.5
# Beta remains the same
# 229 -80.2 0.003660782017981616 1.5
# Beta is too small
# Increasing beta
# 230 -83.6 0.023640357686796783 2.25
# Beta remains the same
# 231 -82.2 0.004478728799159493 2.25
# Decreasing beta
# 232 -79.0 0.0017681882660049197 1.5
# Beta remains the same
# 233 -82.8 0.004352627112038848 1.5
# Increasing beta
# 234 -79.4 0.012433446843958243 2.25
# Decreasing beta
# 235 -82.2 0.0018813968245075504 1.5
# Beta remains the same
# 236 -85.6 0.003083863147718486 1.5
# Beta remains the same
# 237 -80.4 0.0033219187270249993 1.5
# Beta remains the same
# 238 -81.4 0.0025556062373373817 1.5
# Beta remains the same
# 239 -92.2 0.007423482350049064 1.5
# Beta remains the same
# 240 -106.4 0.004834503723564068 1.5
# Beta remains the same
# 241 -78.0 0.0027563784862113176 1.5
# Decreasing beta
# 242 -101.2 0.0023555335551786578 1.0
# Increasing beta
# 243 -77.8 0.013069909579781944 1.5
# Beta remains the same
# 244 -86.6 0.007369557581313418 1.5
# Beta remains the same
# 245 -71.8 0.005970291609319884 1.5
# Beta is too small
# Increasing beta
# 246 -77.0 0.02321041027211442 2.25
# Beta remains the same
# 247 -101.8 0.004380845013999974 2.25
# Beta remains the same
# 248 -81.6 0.003666721138450417 2.25
# Decreasing beta
# 249 -86.2 0.0018312446396436225 1.5
# Beta remains the same
# 250 -77.8 0.0037808747309397792 1.5
# Beta remains the same
# 251 -83.6 0.002974000436413173 1.5
# Beta remains the same
# 252 -81.0 0.004995788861525276 1.5
# Decreasing beta
# 253 -98.6 0.0022265388278214647 1.0
# Increasing beta
# 254 -92.2 0.01954810389067852 1.5
# Beta remains the same
# 255 -80.4 0.0035259370345388764 1.5
# Increasing beta
# 256 -77.6 0.011551760323613467 2.25
# Beta remains the same
# 257 -95.8 0.007509412922421046 2.25
# Beta remains the same
# 258 -84.8 0.004335799044994171 2.25
# Beta remains the same
# 259 -77.8 0.003116783787410843 2.25
# Beta remains the same
# 260 -95.6 0.003402917267355948 2.25
# Beta remains the same
# 261 -84.8 0.0027139908880939984 2.25
# Beta remains the same
# 262 -72.2 0.0031095001451748885 2.25
# Beta remains the same
# 263 -80.0 0.003055484207831484 2.25
# Decreasing beta
# 264 -76.4 0.002436295325405743 1.5
# Beta remains the same
# 265 -88.6 0.004127716823836726 1.5
# Decreasing beta
# 266 -85.6 0.0023596855594095467 1.0
# Beta remains the same
# 267 -90.8 0.004850068798065851 1.0
# Beta remains the same
# 268 -81.6 0.0034898002729656903 1.0
# Beta remains the same
# 269 -80.6 0.007828840004432874 1.0
# Beta remains the same
# 270 -80.6 0.003716685899026918 1.0
# Beta remains the same
# 271 -79.2 0.007682645249279644 1.0
# Increasing beta
# 272 -81.2 0.012170310884680464 1.5
# Beta is too small
# Increasing beta
# 273 -89.6 0.020074416468546397 2.25
# Beta remains the same
# 274 -96.8 0.00482718044288212 2.25
# Beta remains the same
# 275 -85.4 0.0076206286600000415 2.25
# Decreasing beta
# 276 -89.6 0.002384148239349258 1.5
# Beta remains the same
# 277 -84.2 0.004916013893825372 1.5
# Beta remains the same
# 278 -77.2 0.0042910938472038645 1.5
# Increasing beta
# 279 -74.8 0.01241871915917858 2.25
# Beta remains the same
# 280 -95.0 0.00255515585494127 2.25
# Beta remains the same
# 281 -87.2 0.0029314393177491435 2.25
# Increasing beta
# 282 -88.0 0.010002137398134377 3.375
# Beta remains the same
# 283 -87.0 0.0030559446770834797 3.375
# Decreasing beta
# 284 -107.2 0.0023410248003594325 2.25
# Beta remains the same
# 285 -80.6 0.003419527817758317 2.25
# Decreasing beta
# 286 -92.0 0.0018476339952480767 1.5
# Decreasing beta
# 287 -92.6 0.0019340968292905884 1.0
# Increasing beta
# 288 -75.8 0.01248475864772472 1.5
# Beta remains the same
# 289 -99.4 0.0028865312000787924 1.5
# Increasing beta
# 290 -109.6 0.013402355302473998 2.25
# Beta remains the same
# 291 -83.0 0.0031648517360887713 2.25
# Beta remains the same
# 292 -79.6 0.002510602608103277 2.25
# Decreasing beta
# 293 -84.0 0.001758363885941108 1.5
# Beta remains the same
# 294 -72.0 0.003364278737367081 1.5
# Beta remains the same
# 295 -72.8 0.006666724312464243 1.5
# Beta remains the same
# 296 -91.8 0.0033191006806195713 1.5
# Beta remains the same
# 297 -94.2 0.004439776128499649 1.5
# Beta remains the same
# 298 -102.8 0.009252072947261963 1.5
# Beta remains the same
# 299 -83.4 0.005619993649745058 1.5
# Decreasing beta
# 300 -89.4 0.0018423125136792385 1.0
# Beta is too small
# Increasing beta
# 301 -78.8 0.023379524983285334 1.5
# Beta remains the same
# 302 -75.4 0.003855830349828528 1.5
# Decreasing beta
# 303 -84.0 0.0023277544856163705 1.0
# Beta remains the same
# 304 -82.8 0.002756812160808044 1.0
# Beta remains the same
# 305 -79.4 0.004129242785682654 1.0
# Beta remains the same
# 306 -81.8 0.003311072372393513 1.0
# Beta remains the same
# 307 -77.8 0.005488451562948691 1.0
# Beta remains the same
# 308 -86.0 0.003948358291523646 1.0
# Increasing beta
# 309 -74.8 0.012790824277542181 1.5
# Decreasing beta
# 310 -78.6 0.002354173905284424 1.0
# Increasing beta
# 311 -74.2 0.014271141367589411 1.5
# Increasing beta
# 312 -69.2 0.01024366554677168 2.25
# Decreasing beta
# 313 -82.0 0.002260209239579402 1.5
# Beta remains the same
# 314 -81.2 0.003091104411550665 1.5
# Beta remains the same
# 315 -99.2 0.002615002141820331 1.5
# Beta remains the same
# 316 -80.4 0.0074193487487932515 1.5
# Beta remains the same
# 317 -73.4 0.00800272533490713 1.5
# Beta remains the same
# 318 -77.0 0.004360554729868531 1.5
# Beta remains the same
# 319 -106.4 0.0025834910402384717 1.5
# Beta remains the same
# 320 -79.4 0.005323587318437104 1.5
# Beta remains the same
# 321 -84.4 0.005199688535998015 1.5
# Beta remains the same
# 322 -78.0 0.0030599862471020994 1.5
# Decreasing beta
# 323 -91.2 0.0022800412281012306 1.0
# Beta remains the same
# 324 -93.8 0.006368389907458325 1.0
# Beta remains the same
# 325 -83.6 0.006177249181805616 1.0
# Beta remains the same
# 326 -109.2 0.002722162957427169 1.0
# Increasing beta
# 327 -73.8 0.01929529269430905 1.5
# Decreasing beta
# 328 -97.6 0.0021559247999069623 1.0
# Beta remains the same
# 329 -83.2 0.0025785351960031203 1.0
# Increasing beta
# 330 -81.6 0.012477222520533631 1.5
# Increasing beta
# 331 -86.8 0.013013730303183745 2.25
# Beta remains the same
# 332 -82.8 0.0041005105077680706 2.25
# Beta remains the same
# 333 -80.2 0.0052626313840551065 2.25
# Beta remains the same
# 334 -84.8 0.00267428674484198 2.25
# Decreasing beta
# 335 -76.0 0.0024070346733175213 1.5
# Beta remains the same
# 336 -89.2 0.004368918939654008 1.5
# Increasing beta
# 337 -101.4 0.011645226427089133 2.25
# Beta remains the same
# 338 -77.8 0.005252687468134864 2.25
# Beta remains the same
# 339 -102.8 0.005210845641870524 2.25
# Beta remains the same
# 340 -86.2 0.0038209826859389906 2.25
# Beta remains the same
# 341 -81.2 0.0026316574636140525 2.25
# Beta remains the same
# 342 -78.2 0.004922627196775042 2.25
# Decreasing beta
# 343 -84.4 0.00238611710266694 1.5
# Beta remains the same
# 344 -77.6 0.0030668926183042913 1.5
# Beta remains the same
# 345 -72.4 0.004266120081150172 1.5
# Beta remains the same
# 346 -77.0 0.005135705167426448 1.5
# Decreasing beta
# 347 -84.8 0.0021062179604021286 1.0
# Increasing beta
# 348 -79.0 0.01283732906430679 1.5
# Increasing beta
# 349 -77.4 0.011142484029065378 2.25
# Beta remains the same
# 350 -87.0 0.00329122393544339 2.25
# Beta remains the same
# 351 -98.4 0.0034189678012527046 2.25
# Beta remains the same
# 352 -70.0 0.0031222810092819044 2.25
# Beta remains the same
# 353 -83.6 0.0041376545119215236 2.25
# Beta remains the same
# 354 -75.2 0.005401439159080531 2.25
# Decreasing beta
# 355 -75.8 0.0018980916382771605 1.5
# Beta remains the same
# 356 -71.0 0.0027385403780982166 1.5
# Decreasing beta
# 357 -90.8 0.0020930032148212315 1.0
# Increasing beta
# 358 -92.8 0.010909805972582752 1.5
# Beta remains the same
# 359 -78.0 0.00341531123849727 1.5
# Beta remains the same
# 360 -78.2 0.004431626392481892 1.5
# Decreasing beta
# 361 -84.0 0.001906218455235876 1.0
# Beta is too small
# Increasing beta
# 362 -72.6 0.021526762162206444 1.5
# Increasing beta
# 363 -76.8 0.016289413656487832 2.25
# Beta remains the same
# 364 -84.0 0.007472449996062231 2.25
# Beta remains the same
# 365 -78.0 0.0028523013115580283 2.25
# Beta remains the same
# 366 -78.4 0.003016137095286551 2.25
# Beta remains the same
# 367 -79.0 0.003259596169944731 2.25
# Beta remains the same
# 368 -84.6 0.003492967297976072 2.25
# Beta remains the same
# 369 -88.4 0.0032158224346251763 2.25
# Decreasing beta
# 370 -98.2 0.00239393733260924 1.5
# Beta remains the same
# 371 -106.6 0.002573549783719783 1.5
# Increasing beta
# 372 -86.4 0.012053872855925329 2.25
# Beta remains the same
# 373 -87.6 0.0027686905185705032 2.25
# Beta remains the same
# 374 -89.0 0.002717731257657791 2.25
# Beta remains the same
# 375 -88.0 0.004198622751150731 2.25
# Beta remains the same
# 376 -92.8 0.0032521280766492273 2.25
# Beta remains the same
# 377 -101.2 0.0037063583886297433 2.25
# Beta remains the same
# 378 -141.0 0.002673859078328604 2.25
# Beta remains the same
# 379 -80.4 0.004883617609454518 2.25
# Beta remains the same
# 380 -89.0 0.0027742221372838356 2.25
# Beta remains the same
# 381 -75.8 0.0030034406125451795 2.25
# Decreasing beta
# 382 -87.8 0.0016026743237610246 1.5
# Beta remains the same
# 383 -75.6 0.0033462189755923744 1.5
# Beta remains the same
# 384 -98.2 0.0034137183389980237 1.5
# Beta remains the same
# 385 -75.2 0.0029666011676568534 1.5
# Increasing beta
# 386 -96.2 0.011621438567629936 2.25
# Beta remains the same
# 387 -81.6 0.004840144836221427 2.25
# Decreasing beta
# 388 -93.0 0.002184410831450745 1.5
# Beta remains the same
# 389 -80.2 0.003674804027961709 1.5
# Decreasing beta
# 390 -86.2 0.002091876753805423 1.0
# Beta is too small
# Increasing beta
# 391 -77.0 0.021792600833603428 1.5
# Increasing beta
# 392 -71.0 0.016172625607005185 2.25
# Decreasing beta
# 393 -77.6 0.0021381244292779495 1.5
# Beta remains the same
# 394 -81.2 0.0042616749742186355 1.5
# Decreasing beta
# 395 -87.2 0.0023094120632691038 1.0
# Beta remains the same
# 396 -79.6 0.005148096594148658 1.0
# Increasing beta
# 397 -75.4 0.01782130103967218 1.5
# Beta remains the same
# 398 -80.2 0.003303332295596008 1.5
# Increasing beta
# 399 -95.8 0.012447302272268023 2.25
# Decreasing beta
# 400 -95.4 0.002015949414599129 1.5
# Increasing beta
# 401 -80.2 0.012185852210529754 2.25
# Beta remains the same
# 402 -73.0 0.008430039324648366 2.25
# Beta is too small
# Increasing beta
# 403 -80.8 0.023634643567617585 3.375
# Beta remains the same
# 404 -77.0 0.003072766301973243 3.375
# Decreasing beta
# 405 -111.2 0.002236632078507752 2.25
# Decreasing beta
# 406 -82.8 0.0013133109873159278 1.5
# Increasing beta
# 407 -78.6 0.011851581524782124 2.25
# Beta remains the same
# 408 -84.4 0.003367205506857155 2.25
# Decreasing beta
# 409 -105.0 0.001662346139028783 1.5
# Beta remains the same
# 410 -111.8 0.0044822707218356225 1.5
# Beta remains the same
# 411 -80.4 0.007236043419650623 1.5
# Decreasing beta
# 412 -106.4 0.001014753158249546 1.0
# Beta remains the same
# 413 -88.0 0.0039015993791356794 1.0
# Beta remains the same
# 414 -82.0 0.009197184540214443 1.0
# Decreasing beta
# 415 -105.4 0.001493829768815447 0.6666666666666666
# Decreasing beta
# 416 -95.8 0.0011535848040702286 0.4444444444444444
# Beta remains the same
# 417 -88.2 0.008644985455147995 0.4444444444444444
# Beta remains the same
# 418 -88.8 0.007175200931345847 0.4444444444444444
# Increasing beta
# 419 -86.6 0.01236311199861742 0.6666666666666666
# Decreasing beta
# 420 -110.6 0.002099078764970691 0.4444444444444444
# Increasing beta
# 421 -77.0 0.013646495827596356 0.6666666666666666
# Decreasing beta
# 422 -116.0 0.0020891127402331584 0.4444444444444444
# Increasing beta
# 423 -80.6 0.01291381906382161 0.6666666666666666
# Beta remains the same
# 424 -83.4 0.005197234730407594 0.6666666666666666
# Beta is too small
# Increasing beta
# 425 -73.2 0.021271640629547603 1.0
# Beta remains the same
# 426 -108.0 0.004260010686960741 1.0
# Decreasing beta
# 427 -82.0 0.000892876326693595 0.6666666666666666
# Beta is too small
# Increasing beta
# 428 -90.8 0.020284290733297013 1.0
# Decreasing beta
# 429 -133.6 0.0011323591331352618 0.6666666666666666
# Beta remains the same
# 430 -82.8 0.005957945232857376 0.6666666666666666
# Decreasing beta
# 431 -86.4 0.0017049943510548833 0.4444444444444444
# Beta remains the same
# 432 -83.4 0.003333445752645778 0.4444444444444444
# Increasing beta
# 433 -83.0 0.010516840808783168 0.6666666666666666
# Decreasing beta
# 434 -94.0 0.0022392795088527783 0.4444444444444444
# Beta is too small
# Increasing beta
# 435 -74.8 0.024578060586511116 0.6666666666666666
# Beta remains the same
# 436 -82.2 0.0052606514567310105 0.6666666666666666
# Beta remains the same
# 437 -83.8 0.0065876822361513225 0.6666666666666666
# Increasing beta
# 438 -114.8 0.012128740981666023 1.0
# Beta remains the same
# 439 -89.4 0.003356832211918654 1.0
# Decreasing beta
# 440 -104.4 0.0013777872681672158 0.6666666666666666
# Beta remains the same
# 441 -110.8 0.005881588699282895 0.6666666666666666
# Beta remains the same
# 442 -92.2 0.006885627676935886 0.6666666666666666
# Decreasing beta
# 443 -82.6 0.0024624813122356985 0.4444444444444444
# Increasing beta
# 444 -74.6 0.01087441013913718 0.6666666666666666
# Decreasing beta
# 445 -93.2 0.002372302887338591 0.4444444444444444
# Beta is too small
# Increasing beta
# 446 -71.4 0.021504950826106654 0.6666666666666666
# Increasing beta
# 447 -85.8 0.012511410857225728 1.0
# Beta remains the same
# 448 -110.6 0.005580585910012202 1.0
# Decreasing beta
# 449 -99.2 0.0014579733645251785 0.6666666666666666
# Decreasing beta
# 450 -101.8 0.001577239534485475 0.4444444444444444
# Beta is too small
# Increasing beta
# 451 -80.4 0.021739559395065187 0.6666666666666666
# Beta remains the same
# 452 -96.0 0.0030415120221896274 0.6666666666666666
# Beta remains the same
# 453 -100.2 0.004935129749023574 0.6666666666666666
# Beta is too small
# Increasing beta
# 454 -74.6 0.02032885773537349 1.0
# Increasing beta
# 455 -77.8 0.010772773557462036 1.5
# Beta remains the same
# 456 -82.6 0.0037136537647478197 1.5
# Beta remains the same
# 457 -75.8 0.009665638997012739 1.5
# Beta remains the same
# 458 -85.2 0.0029432249779137443 1.5
# Beta remains the same
# 459 -93.8 0.0029557912426271594 1.5
# Beta remains the same
# 460 -81.8 0.005098477314523254 1.5
# Beta is too small
# Increasing beta
# 461 -89.8 0.023135524599076425 2.25
# Decreasing beta
# 462 -83.2 0.00218853424098866 1.5
# Beta remains the same
# 463 -88.6 0.0027824007993329227 1.5
# Beta remains the same
# 464 -69.6 0.005573342985158805 1.5
# Beta remains the same
# 465 -75.4 0.006837561651091005 1.5
# Beta remains the same
# 466 -79.8 0.002587757684476307 1.5
# Decreasing beta
# 467 -82.4 0.0022340219698798085 1.0
# Decreasing beta
# 468 -80.4 0.002341219267684232 0.6666666666666666
# Beta remains the same
# 469 -100.4 0.008501905389306298 0.6666666666666666
# Beta is too small
# Increasing beta
# 470 -81.0 0.022791997781336688 1.0
# Beta remains the same
# 471 -71.8 0.0044507697844040385 1.0
# Decreasing beta
# 472 -78.0 0.0023719658448563374 0.6666666666666666
# Beta remains the same
# 473 -83.0 0.006972686189053557 0.6666666666666666
# Increasing beta
# 474 -77.4 0.01875336966161007 1.0
# Beta remains the same
# 475 -71.8 0.007155333885109802 1.0
# Increasing beta
# 476 -72.8 0.014677598035132565 1.5
# Increasing beta
# 477 -77.8 0.01517218457893551 2.25
# Decreasing beta
# 478 -129.8 0.0020785890683760575 1.5
# Beta remains the same
# 479 -80.0 0.002855699679205874 1.5
# Beta remains the same
# 480 -87.2 0.005043812244762755 1.5
# Beta remains the same
# 481 -76.8 0.002707706897663247 1.5
# Beta remains the same
# 482 -101.4 0.005736641172732842 1.5
# Beta remains the same
# 483 -81.6 0.00877720705193159 1.5
# Beta remains the same
# 484 -78.4 0.005692676203603859 1.5
# Beta remains the same
# 485 -74.0 0.006442306342056114 1.5
# Decreasing beta
# 486 -82.4 0.001892512466820521 1.0
# Beta remains the same
# 487 -89.0 0.008480369908390016 1.0
# Increasing beta
# 488 -96.6 0.010810288682089487 1.5
# Beta remains the same
# 489 -98.6 0.00349850373314519 1.5
# Beta remains the same
# 490 -80.2 0.0051498975302419845 1.5
# Decreasing beta
# 491 -79.6 0.0018786155476781241 1.0
# Beta remains the same
# 492 -101.8 0.00451500180520756 1.0
# Beta is too small
# Increasing beta
# 493 -97.2 0.020834413614866643 1.5
# Increasing beta
# 494 -72.0 0.013623946142623713 2.25
# Beta remains the same
# 495 -110.6 0.003647786696732545 2.25
# Decreasing beta
# 496 -81.2 0.0014931667899383242 1.5
# Beta remains the same
# 497 -84.2 0.0041252357561042145 1.5
# Increasing beta
# 498 -99.6 0.012848952020126862 2.25
# Beta remains the same
# 499 -73.6 0.003496594711900411 2.25
# Decreasing beta
# 500 -78.2 0.0015976717048541654 1.5
# Increasing beta
# 501 -86.2 0.014419607678158862 2.25
# Beta remains the same
# 502 -77.8 0.004672887092625145 2.25
# Decreasing beta
# 503 -82.8 0.0012736230770699591 1.5
# Beta remains the same
# 504 -83.6 0.00687714279888982 1.5
# Decreasing beta
# 505 -82.6 0.0014367503051864535 1.0
# Beta remains the same
# 506 -96.2 0.0037753424848213702 1.0
# Beta remains the same
# 507 -83.2 0.003962535498658833 1.0
# Increasing beta
# 508 -76.0 0.01701299342420996 1.5
# Beta remains the same
# 509 -89.4 0.006486419963134791 1.5
# Beta remains the same
# 510 -82.4 0.005900282959659503 1.5
# Beta remains the same
# 511 -96.4 0.002602637873612703 1.5
# Decreasing beta
# 512 -75.8 0.0023554312026541524 1.0
# Increasing beta
# 513 -74.8 0.011169787682908097 1.5
# Decreasing beta
# 514 -85.8 0.002046324709902701 1.0
# Increasing beta
# 515 -95.8 0.017381175333206576 1.5
# Beta remains the same
# 516 -86.2 0.006652822441971239 1.5
# Beta remains the same
# 517 -92.0 0.0029788017862078927 1.5
# Decreasing beta
# 518 -77.6 0.0023825353676485543 1.0
# Decreasing beta
# 519 -85.6 0.001667734493796457 0.6666666666666666
# Beta remains the same
# 520 -76.8 0.005401542473553774 0.6666666666666666
# Beta remains the same
# 521 -76.4 0.008931493146993673 0.6666666666666666
# Beta remains the same
# 522 -79.0 0.0096402787884972 0.6666666666666666
# Beta remains the same
# 523 -98.4 0.007223168980403565 0.6666666666666666
# Beta is too small
# Increasing beta
# 524 -84.2 0.02321949387968026 1.0
# Beta is too small
# Increasing beta
# 525 -81.0 0.02013309863148034 1.5
# Beta remains the same
# 526 -69.8 0.00916519112099423 1.5
# Beta remains the same
# 527 -99.4 0.0033856328996685523 1.5
# Beta remains the same
# 528 -83.0 0.008581847628252554 1.5
# Beta remains the same
# 529 -75.6 0.0026257710383483257 1.5
# Beta remains the same
# 530 -77.2 0.0032243521549616383 1.5
# Decreasing beta
# 531 -100.0 0.0018549113441434961 1.0
# Beta remains the same
# 532 -87.0 0.003542334333511246 1.0
# Beta is too small
# Increasing beta
# 533 -75.6 0.02359244927734404 1.5
# Beta remains the same
# 534 -81.4 0.004862427908952949 1.5
# Decreasing beta
# 535 -86.2 0.001283008614026472 1.0
# Increasing beta
# 536 -75.2 0.015825945143723454 1.5
# Decreasing beta
# 537 -88.6 0.0010972916326464914 1.0
# Beta remains the same
# 538 -90.4 0.007681911054854254 1.0
# Beta remains the same
# 539 -82.8 0.006243156651378622 1.0
# Beta remains the same
# 540 -85.0 0.004187450118142888 1.0
# Decreasing beta
# 541 -87.8 0.0017892421763115098 0.6666666666666666
# Beta remains the same
# 542 -79.2 0.0029004767002778465 0.6666666666666666
# Beta remains the same
# 543 -109.2 0.009858294733551065 0.6666666666666666
# Beta is too small
# Increasing beta
# 544 -81.2 0.022128178619935726 1.0
# Beta is too small
# Increasing beta
# 545 -74.8 0.030173343743864267 1.5
# Beta remains the same
# 546 -82.2 0.007358047021531194 1.5
# Beta remains the same
# 547 -85.4 0.006926283143968487 1.5
# Beta is too small
# Increasing beta
# 548 -85.0 0.021590307161602856 2.25
# Beta remains the same
# 549 -73.4 0.0025964922511014002 2.25
# Beta remains the same
# 550 -85.0 0.0034896339346811986 2.25
# Decreasing beta
# 551 -73.0 0.001706165803782934 1.5
# Decreasing beta
# 552 -90.6 0.0021933999130394786 1.0
# Decreasing beta
# 553 -107.2 0.0017530325581663795 0.6666666666666666
# Beta is too small
# Increasing beta
# 554 -85.8 0.02299784486065435 1.0
# Beta is too small
# Increasing beta
# 555 -74.0 0.02459986258257221 1.5
# Beta remains the same
# 556 -81.2 0.00994871323487403 1.5
# Decreasing beta
# 557 -121.2 0.001959913056038666 1.0
# Beta is too small
# Increasing beta
# 558 -80.6 0.02337773576537471 1.5
# Decreasing beta
# 559 -77.0 0.0020380900731074773 1.0
# Increasing beta
# 560 -78.2 0.011042101788071792 1.5
# Beta remains the same
# 561 -93.0 0.0040305366628153455 1.5
# Beta remains the same
# 562 -71.0 0.003262525379148477 1.5
# Increasing beta
# 563 -88.2 0.01436261063847737 2.25
# Decreasing beta
# 564 -95.2 0.0022334565394604208 1.5
# Beta remains the same
# 565 -88.0 0.003046945489248299 1.5
# Decreasing beta
# 566 -188.4 0.0016054886270814295 1.0
# Beta remains the same
# 567 -95.4 0.006631944646140234 1.0
# Increasing beta
# 568 -109.8 0.012194104643004907 1.5
# Beta remains the same
# 569 -78.4 0.0036020963588034327 1.5
# Decreasing beta
# 570 -87.2 0.0022948460606332867 1.0
# Increasing beta
# 571 -87.6 0.016913538980023984 1.5
# Beta remains the same
# 572 -87.2 0.004403548987407116 1.5
# Beta remains the same
# 573 -77.8 0.004561843161672447 1.5
# Decreasing beta
# 574 -78.6 0.0022794687548643843 1.0
# Beta remains the same
# 575 -83.2 0.009434980627226796 1.0
# Beta remains the same
# 576 -83.4 0.0070559146473965825 1.0
# Beta remains the same
# 577 -82.2 0.009259918677114828 1.0
# Beta remains the same
# 578 -92.4 0.0025427756918734055 1.0
# Increasing beta
# 579 -80.8 0.010962707029509779 1.5
# Beta remains the same
# 580 -97.8 0.004026459317411714 1.5
# Decreasing beta
# 581 -105.4 0.001474218654512289 1.0
# Beta remains the same
# 582 -79.4 0.008751342919039007 1.0
# Increasing beta
# 583 -81.8 0.011236572001410516 1.5
# Beta remains the same
# 584 -82.0 0.005316884457892672 1.5
# Beta remains the same
# 585 -81.6 0.006018851442926591 1.5
# Beta remains the same
# 586 -73.8 0.004011936292887765 1.5
# Decreasing beta
# 587 -96.8 0.002308037658941858 1.0
# Decreasing beta
# 588 -96.0 0.0016712158081009785 0.6666666666666666
# Beta is too small
# Increasing beta
# 589 -67.2 0.024633513889671634 1.0
# Increasing beta
# 590 -90.4 0.014026128660094471 1.5
# Beta remains the same
# 591 -108.4 0.0038294723367288427 1.5
# Beta remains the same
# 592 -90.4 0.0041167774544091625 1.5
# Beta remains the same
# 593 -104.6 0.0030747943896815887 1.5
# Beta remains the same
# 594 -75.6 0.0025221727296673466 1.5
# Beta remains the same
# 595 -76.2 0.005419414283938283 1.5
# Decreasing beta
# 596 -79.8 0.0017743154368517011 1.0
# Increasing beta
# 597 -84.2 0.012025571953893567 1.5
# Beta remains the same
# 598 -124.4 0.003808563054146449 1.5
# Decreasing beta
# 599 -84.8 0.0010779866368047597 1.0
# Beta remains the same
# 600 -73.8 0.009266540859801718 1.0
# Increasing beta
# 601 -74.4 0.015282534730870642 1.5
# Decreasing beta
# 602 -82.4 0.0014736924413421692 1.0
# Beta remains the same
# 603 -81.2 0.008696108429230923 1.0
# Increasing beta
# 604 -74.8 0.013048659255639814 1.5
# Decreasing beta
# 605 -78.0 0.002444908995459683 1.0
# Beta remains the same
# 606 -97.2 0.008171154735538108 1.0
# Decreasing beta
# 607 -87.2 0.001621305400601458 0.6666666666666666
# Beta remains the same
# 608 -78.2 0.005061454738454295 0.6666666666666666
# Beta remains the same
# 609 -74.4 0.002886203259567461 0.6666666666666666
# Increasing beta
# 610 -89.8 0.013700206622657052 1.0
# Increasing beta
# 611 -73.6 0.01627152909552941 1.5
# Decreasing beta
# 612 -77.8 0.0018232007649785576 1.0
# Increasing beta
# 613 -73.4 0.011934537303530241 1.5
# Decreasing beta
# 614 -82.6 0.0014203072467019583 1.0
# Beta remains the same
# 615 -86.4 0.005057506775704674 1.0
# Beta remains the same
# 616 -78.2 0.003086802346751267 1.0
# Increasing beta
# 617 -76.8 0.011483335798123728 1.5
# Decreasing beta
# 618 -75.4 0.002262588117708868 1.0
# Beta is too small
# Increasing beta
# 619 -72.8 0.021895469297160602 1.5
# Beta remains the same
# 620 -91.8 0.006224698228716793 1.5
# Beta remains the same
# 621 -90.2 0.004033536734848403 1.5
# Decreasing beta
# 622 -71.4 0.0021511924516336837 1.0
# Increasing beta
# 623 -77.8 0.011641131639945335 1.5
# Beta remains the same
# 624 -78.0 0.004396011233639653 1.5
# Beta remains the same
# 625 -79.8 0.00481649865681352 1.5
# Beta remains the same
# 626 -88.4 0.00578899526979536 1.5
# Beta remains the same
# 627 -81.6 0.005865105080669639 1.5
# Increasing beta
# 628 -83.4 0.010021239706871075 2.25
# Beta remains the same
# 629 -87.4 0.002504233876086081 2.25
# Decreasing beta
# 630 -81.2 0.0020996700728721 1.5
# Beta remains the same
# 631 -90.4 0.00782895565894758 1.5
# Beta remains the same
# 632 -75.2 0.00922723449998978 1.5
# Beta remains the same
# 633 -89.4 0.005051065105524809 1.5
# Decreasing beta
# 634 -83.6 0.0022077691540113484 1.0
# Beta remains the same
# 635 -83.2 0.0030990838519770665 1.0
# Beta remains the same
# 636 -74.2 0.007075505629746622 1.0
# Beta remains the same
# 637 -82.4 0.007583867936471914 1.0
# Beta remains the same
# 638 -76.6 0.0027538920976301635 1.0
# Beta remains the same
# 639 -85.0 0.0028922624457243676 1.0
# Decreasing beta
# 640 -93.8 0.0022362762931936904 0.6666666666666666
# Beta remains the same
# 641 -81.4 0.004531481468343658 0.6666666666666666
# Beta remains the same
# 642 -74.4 0.0035181194766746447 0.6666666666666666
# Beta remains the same
# 643 -94.4 0.005034134331019331 0.6666666666666666
# Beta is too small
# Increasing beta
# 644 -72.4 0.020877874049945466 1.0
# Increasing beta
# 645 -68.2 0.018292858950293485 1.5
# Decreasing beta
# 646 -83.6 0.002085036531891559 1.0
# Decreasing beta
# 647 -81.0 0.001656040641150577 0.6666666666666666
# Beta is too small
# Increasing beta
# 648 -84.2 0.020021554177557306 1.0
# Beta remains the same
# 649 -97.8 0.002822340660013725 1.0
# Beta remains the same
# 650 -95.6 0.0027970693677760307 1.0
# Beta is too small
# Increasing beta
# 651 -66.0 0.023407608184494423 1.5
# Beta remains the same
# 652 -71.2 0.005255256075199013 1.5
# Increasing beta
# 653 -81.8 0.01383748386072159 2.25
# Increasing beta
# 654 -75.2 0.012181259340176812 3.375
# Decreasing beta
# 655 -84.0 0.0014703377498052985 2.25
# Decreasing beta
# 656 -89.2 0.0015225437842871664 1.5
# Beta remains the same
# 657 -96.8 0.007073875687364092 1.5
# Decreasing beta
# 658 -85.4 0.0019481244321616286 1.0
# Increasing beta
# 659 -94.4 0.012442249043303006 1.5
# Decreasing beta
# 660 -85.2 0.001988970732649244 1.0
# Beta is too small
# Increasing beta
# 661 -78.4 0.022471430469597594 1.5
# Beta remains the same
# 662 -79.2 0.004413278967129218 1.5
# Increasing beta
# 663 -77.6 0.012674182898459063 2.25
# Decreasing beta
# 664 -79.2 0.0020397522042661324 1.5
# Beta remains the same
# 665 -72.8 0.002977831890770479 1.5
# Beta remains the same
# 666 -80.4 0.0066019355294943466 1.5
# Beta remains the same
# 667 -80.2 0.004073443553796537 1.5
# Beta is too small
# Increasing beta
# 668 -74.6 0.02359641197810938 2.25
# Beta remains the same
# 669 -79.0 0.009363597652782609 2.25
# Decreasing beta
# 670 -100.2 0.001713705331606496 1.5
# Beta is too small
# Increasing beta
# 671 -70.4 0.03325457512881996 2.25
# Beta is too small
# Increasing beta
# 672 -71.8 0.022999327662281313 3.375
# Decreasing beta
# 673 -85.0 0.0020102031260578455 2.25
# Decreasing beta
# 674 -98.2 0.001682295529793357 1.5
# Decreasing beta
# 675 -78.2 0.0023566380599367204 1.0
# Beta remains the same
# 676 -78.8 0.003774087406754775 1.0
# Decreasing beta
# 677 -95.4 0.0024848276128314408 0.6666666666666666
# Beta remains the same
# 678 -76.8 0.008998562041103683 0.6666666666666666
# Beta remains the same
# 679 -84.4 0.003744413319256066 0.6666666666666666
# Beta remains the same
# 680 -85.0 0.004988481472184481 0.6666666666666666
# Beta remains the same
# 681 -98.8 0.003065096994960673 0.6666666666666666
# Beta is too small
# Increasing beta
# 682 -83.2 0.020847684783547153 1.0
# Decreasing beta
# 683 -84.0 0.0013887206272344362 0.6666666666666666
# Decreasing beta
# 684 -94.6 0.0017559704067180602 0.4444444444444444
# Decreasing beta
# 685 -109.8 0.0022450622404540203 0.2962962962962963
# Beta remains the same
# 686 -79.8 0.008742850980623948 0.2962962962962963
# Increasing beta
# 687 -113.2 0.017182361198545583 0.4444444444444444
# Increasing beta
# 688 -88.4 0.013553641431030243 0.6666666666666666
# Beta remains the same
# 689 -88.2 0.007954592695647345 0.6666666666666666
# Beta remains the same
# 690 -89.4 0.006339038603329642 0.6666666666666666
# Beta is too small
# Increasing beta
# 691 -77.2 0.020263418521347193 1.0
# Beta is too small
# Increasing beta
# 692 -72.0 0.021781915381649274 1.5
# Beta remains the same
# 693 -71.4 0.004516508180798003 1.5
# Beta remains the same
# 694 -107.0 0.0028429162918784936 1.5
# Beta remains the same
# 695 -84.2 0.003951247310606166 1.5
# Beta remains the same
# 696 -78.8 0.006721440628861568 1.5
# Decreasing beta
# 697 -107.0 0.0013331579781429125 1.0
# Beta remains the same
# 698 -81.8 0.002609631134279602 1.0
# Beta is too small
# Increasing beta
# 699 -78.0 0.024174134919165677 1.5
# Decreasing beta
# 700 -82.6 0.001943352609516271 1.0
# Beta remains the same
# 701 -94.6 0.004707457195445587 1.0
# Beta remains the same
# 702 -86.0 0.0032437173873379717 1.0
# Beta remains the same
# 703 -102.2 0.0062126692580019936 1.0
# Increasing beta
# 704 -85.0 0.011331254412380391 1.5
# Decreasing beta
# 705 -101.6 0.0023061549053405234 1.0
# Decreasing beta
# 706 -85.4 0.0020045092944166484 0.6666666666666666
# Beta is too small
# Increasing beta
# 707 -77.6 0.02226185355819625 1.0
# Beta remains the same
# 708 -74.0 0.0031788637801038132 1.0
# Beta remains the same
# 709 -69.0 0.009379188767220771 1.0
# Decreasing beta
# 710 -90.8 0.002244345427272218 0.6666666666666666
# Beta remains the same
# 711 -74.0 0.0065093012026751695 0.6666666666666666
# Beta is too small
# Increasing beta
# 712 -73.0 0.045482089520794966 1.0
# Beta remains the same
# 713 -83.0 0.00997810990098501 1.0
# Beta remains the same
# 714 -73.0 0.0062250806498092125 1.0
# Beta remains the same
# 715 -78.2 0.00406362178150135 1.0
# Decreasing beta
# 716 -99.4 0.0021114163282823914 0.6666666666666666
# Increasing beta
# 717 -86.6 0.015216030390739621 1.0
# Increasing beta
# 718 -77.4 0.010639958826055985 1.5
# Beta remains the same
# 719 -81.0 0.009232167567328335 1.5
# Beta remains the same
# 720 -111.4 0.0026418921541550926 1.5
# Decreasing beta
# 721 -129.2 0.0011010826387006804 1.0
# Decreasing beta
# 722 -183.4 0.001734242708956808 0.6666666666666666
# Beta remains the same
# 723 -90.6 0.003182651146982147 0.6666666666666666
# Decreasing beta
# 724 -92.0 0.002175046773629348 0.4444444444444444
# Beta remains the same
# 725 -92.4 0.007775048721488665 0.4444444444444444
# Beta remains the same
# 726 -83.4 0.003160708040825104 0.4444444444444444
# Decreasing beta
# 727 -80.4 0.00047442163467816776 0.2962962962962963
# Increasing beta
# 728 -92.0 0.014960478494793912 0.4444444444444444
# Beta remains the same
# 729 -89.6 0.004897745177915064 0.4444444444444444
# Beta is too small
# Increasing beta
# 730 -90.0 0.027144760560819086 0.6666666666666666
# Beta remains the same
# 731 -98.6 0.0025766624710456447 0.6666666666666666
# Increasing beta
# 732 -83.2 0.011432130364332167 1.0
# Decreasing beta
# 733 -89.8 0.0013183604029551588 0.6666666666666666
# Beta remains the same
# 734 -86.0 0.006186373076762073 0.6666666666666666
# Beta remains the same
# 735 -104.6 0.006015228169146309 0.6666666666666666
# Beta remains the same
# 736 -91.4 0.005706310496549683 0.6666666666666666
# Beta remains the same
# 737 -92.8 0.006623244414376365 0.6666666666666666
# Beta remains the same
# 738 -85.0 0.0038921561269798038 0.6666666666666666
# Beta remains the same
# 739 -87.0 0.00545864708526702 0.6666666666666666
# Decreasing beta
# 740 -80.6 0.001985783509183567 0.4444444444444444
# Increasing beta
# 741 -93.8 0.010137754004038877 0.6666666666666666
# Beta remains the same
# 742 -106.8 0.0041736929308649464 0.6666666666666666
# Beta remains the same
# 743 -103.2 0.0058443311487102 0.6666666666666666
# Beta is too small
# Increasing beta
# 744 -133.2 0.04932586743166975 1.0
# Beta remains the same
# 745 -90.0 0.005761534763927596 1.0
# Beta remains the same
# 746 -80.6 0.005845447693834653 1.0
# Increasing beta
# 747 -83.2 0.011736438905744885 1.5
# Beta remains the same
# 748 -87.2 0.004370755888945663 1.5
# Beta remains the same
# 749 -115.8 0.006405740581998268 1.5
# Beta remains the same
# 750 -80.0 0.003689733099975626 1.5
# Decreasing beta
# 751 -121.6 0.0020782395794633293 1.0
# Beta remains the same
# 752 -84.8 0.0047776623657455365 1.0
# Decreasing beta
# 753 -101.6 0.0008846540835628119 0.6666666666666666
# Increasing beta
# 754 -89.4 0.011269089931370893 1.0
# Beta remains the same
# 755 -83.8 0.008289859065109274 1.0
# Beta remains the same
# 756 -90.6 0.002518903622448708 1.0
# Decreasing beta
# 757 -84.0 0.0022311957664635403 0.6666666666666666
# Increasing beta
# 758 -77.4 0.013252375675995225 1.0
# Beta remains the same
# 759 -77.8 0.0025655732262090556 1.0
# Beta remains the same
# 760 -82.2 0.006307342388442544 1.0
# Decreasing beta
# 761 -84.8 0.0018041465885146536 0.6666666666666666
# Increasing beta
# 762 -91.2 0.010617041432039368 1.0
# Increasing beta
# 763 -77.0 0.013324138823828106 1.5
# Decreasing beta
# 764 -81.6 0.002028064838600408 1.0
# Beta remains the same
# 765 -91.4 0.004990139388214876 1.0
# Beta remains the same
# 766 -78.4 0.004552655466407247 1.0
# Increasing beta
# 767 -83.2 0.010088163953185878 1.5
# Beta remains the same
# 768 -104.8 0.006935127634047501 1.5
# Beta remains the same
# 769 -82.2 0.0053894275659320074 1.5
# Beta remains the same
# 770 -84.2 0.005440829576789033 1.5
# Beta remains the same
# 771 -75.6 0.0055035489706004755 1.5
# Beta remains the same
# 772 -84.8 0.005911620835170445 1.5
# Beta remains the same
# 773 -91.8 0.0032249581779650307 1.5
# Beta remains the same
# 774 -74.0 0.007782350029178672 1.5
# Decreasing beta
# 775 -82.8 0.002424855730142002 1.0
# Beta remains the same
# 776 -82.4 0.005022783205111275 1.0
# Beta remains the same
# 777 -85.0 0.004560838765017566 1.0
# Beta remains the same
# 778 -86.0 0.0042030351075259785 1.0
# Beta remains the same
# 779 -88.8 0.003661209819099627 1.0
# Increasing beta
# 780 -92.0 0.012611239229797788 1.5
# Beta remains the same
# 781 -78.4 0.008360738388343359 1.5
# Beta remains the same
# 782 -78.4 0.0034608449876518408 1.5
# Beta remains the same
# 783 -75.0 0.00645037069396077 1.5
# Beta remains the same
# 784 -90.2 0.0025105889062631208 1.5
# Decreasing beta
# 785 -88.2 0.002403110234569816 1.0
# Beta remains the same
# 786 -80.0 0.009509566846234052 1.0
# Beta remains the same
# 787 -71.0 0.007157079783996703 1.0
# Decreasing beta
# 788 -87.2 0.002424832090503636 0.6666666666666666
# Beta remains the same
# 789 -114.2 0.004820373008464752 0.6666666666666666
# Beta remains the same
# 790 -79.2 0.006360260095284026 0.6666666666666666
# Beta is too small
# Increasing beta
# 791 -85.4 0.020750935105501196 1.0
# Beta remains the same
# 792 -79.8 0.00543365599782201 1.0
# Increasing beta
# 793 -90.4 0.014426672451661043 1.5
# Increasing beta
# 794 -86.8 0.01620260266097172 2.25
# Beta remains the same
# 795 -79.4 0.004193149610180707 2.25
# Decreasing beta
# 796 -85.4 0.0016972915872791804 1.5
# Decreasing beta
# 797 -76.6 0.0019781881483538865 1.0
# Decreasing beta
# 798 -102.0 0.0019728570872844593 0.6666666666666666
# Beta remains the same
# 799 -87.0 0.005304056301568447 0.6666666666666666
# Increasing beta
# 800 -79.0 0.011331210146730277 1.0
# Increasing beta
# 801 -81.2 0.01631650185246474 1.5
# Beta remains the same
# 802 -80.6 0.004168166859766627 1.5
# Beta remains the same
# 803 -119.4 0.004198900694302709 1.5
# Decreasing beta
# 804 -85.8 0.0013540024887793473 1.0
# Beta remains the same
# 805 -83.8 0.0034175133578869575 1.0
# Beta remains the same
# 806 -71.0 0.007007309187944023 1.0
# Decreasing beta
# 807 -77.6 0.001185705923278161 0.6666666666666666
# Beta remains the same
# 808 -82.2 0.0033739772953029715 0.6666666666666666
# Beta is too small
# Increasing beta
# 809 -74.8 0.020340163550668977 1.0
# Increasing beta
# 810 -78.6 0.010478578907301257 1.5
# Decreasing beta
# 811 -91.0 0.0012070245743430548 1.0
# Decreasing beta
# 812 -98.8 0.0021764745499269138 0.6666666666666666
# Beta is too small
# Increasing beta
# 813 -79.0 0.023591773021861016 1.0
# Increasing beta
# 814 -77.6 0.011777073861220561 1.5
# Beta remains the same
# 815 -77.0 0.004675821174058976 1.5
# Decreasing beta
# 816 -74.2 0.0012993238900461698 1.0
# Beta remains the same
# 817 -75.4 0.00291990053480841 1.0
# Beta remains the same
# 818 -116.2 0.002844103925346894 1.0
# Beta remains the same
# 819 -79.8 0.0028100573872371433 1.0
# Beta remains the same
# 820 -86.6 0.00270664529177996 1.0
# Beta remains the same
# 821 -99.2 0.006330697828910599 1.0
# Beta remains the same
# 822 -83.6 0.004991979899092551 1.0
# Increasing beta
# 823 -84.0 0.011073122172114806 1.5
# Decreasing beta
# 824 -90.0 0.0007865525976235294 1.0
# Decreasing beta
# 825 -89.4 0.0015368294287776035 0.6666666666666666
# Beta remains the same
# 826 -104.2 0.009716641991819396 0.6666666666666666
# Beta remains the same
# 827 -103.0 0.0028599713266518898 0.6666666666666666
# Increasing beta
# 828 -73.0 0.0102499386217578 1.0
# Beta remains the same
# 829 -80.2 0.006627752492060741 1.0
# Decreasing beta
# 830 -114.0 0.002037082691451901 0.6666666666666666
# Beta is too small
# Increasing beta
# 831 -76.0 0.022291570821856718 1.0
# Beta remains the same
# 832 -108.2 0.004742039211935059 1.0
# Beta is too small
# Increasing beta
# 833 -73.2 0.026589107169464034 1.5
# Beta remains the same
# 834 -82.6 0.006980218872647532 1.5
# Decreasing beta
# 835 -83.0 0.0018382551136641506 1.0
# Beta remains the same
# 836 -101.4 0.0053512092473886235 1.0
# Beta remains the same
# 837 -85.4 0.006361227004117038 1.0
# Beta remains the same
# 838 -87.8 0.009302352950149143 1.0
# Beta remains the same
# 839 -93.8 0.003461898842065989 1.0
# Beta remains the same
# 840 -79.8 0.0044077106840991346 1.0
# Beta remains the same
# 841 -79.6 0.004961388683698927 1.0
# Increasing beta
# 842 -77.2 0.014969719052496151 1.5
# Beta remains the same
# 843 -80.6 0.006168532623472949 1.5
# Beta remains the same
# 844 -78.6 0.0094184231148681 1.5
# Increasing beta
# 845 -92.8 0.010660088448071104 2.25
# Decreasing beta
# 846 -81.4 0.0020299463245860897 1.5
# Decreasing beta
# 847 -77.6 0.0022213246909302303 1.0
# Beta remains the same
# 848 -83.4 0.002505537834412505 1.0
# Decreasing beta
# 849 -84.8 0.0018478244238527123 0.6666666666666666
# Beta remains the same
# 850 -85.6 0.007486599452184648 0.6666666666666666
# Beta is too small
# Increasing beta
# 851 -112.4 0.024673245654017028 1.0
# Increasing beta
# 852 -77.0 0.011128542740938963 1.5
# Beta remains the same
# 853 -77.6 0.0034226873901903594 1.5
# Beta remains the same
# 854 -96.8 0.003563963304707895 1.5
# Beta remains the same
# 855 -86.8 0.008001421532240881 1.5
# Beta remains the same
# 856 -122.4 0.003954545735508162 1.5
# Decreasing beta
# 857 -86.4 0.001493531853829295 1.0
# Beta remains the same
# 858 -79.6 0.00802742092375152 1.0
# Beta remains the same
# 859 -80.6 0.004790185880993165 1.0
# Decreasing beta
# 860 -83.8 0.002197077764848455 0.6666666666666666
# Beta remains the same
# 861 -94.2 0.009678111876832374 0.6666666666666666
# Beta remains the same
# 862 -82.2 0.0044469505487235 0.6666666666666666
# Decreasing beta
# 863 -81.4 0.0022120786089565897 0.4444444444444444
# Increasing beta
# 864 -86.8 0.013298575749944981 0.6666666666666666
# Beta is too small
# Increasing beta
# 865 -79.2 0.02192114620766822 1.0
# Beta remains the same
# 866 -81.4 0.009414272162391152 1.0
# Beta remains the same
# 867 -81.4 0.003665950292626535 1.0
# Beta remains the same
# 868 -86.2 0.005813182338167433 1.0
# Beta remains the same
# 869 -98.6 0.004315693315845387 1.0
# Decreasing beta
# 870 -80.8 0.002434593507856967 0.6666666666666666
# Beta is too small
# Increasing beta
# 871 -78.6 0.023186005376746085 1.0
# Increasing beta
# 872 -81.8 0.012690575304816031 1.5
# Decreasing beta
# 873 -80.2 0.0021630643277910544 1.0
# Increasing beta
# 874 -90.8 0.017576325155122054 1.5
# Decreasing beta
# 875 -87.2 0.0024775479847400006 1.0
# Decreasing beta
# 876 -85.4 0.002345245433704172 0.6666666666666666
# Increasing beta
# 877 -86.2 0.014668957186466223 1.0
# Beta remains the same
# 878 -77.4 0.002873645934001824 1.0
# Decreasing beta
# 879 -130.0 0.0017034217421326757 0.6666666666666666
# Decreasing beta
# 880 -98.2 0.0022292339220720005 0.4444444444444444
# Beta is too small
# Increasing beta
# 881 -79.2 0.023877031710368757 0.6666666666666666
# Beta is too small
# Increasing beta
# 882 -73.0 0.0204736052068561 1.0
# Beta remains the same
# 883 -108.4 0.005949984821786991 1.0
# Beta remains the same
# 884 -96.8 0.0038975403110518103 1.0
# Beta is too small
# Increasing beta
# 885 -75.6 0.021074333652188706 1.5
# Beta remains the same
# 886 -79.6 0.0033667771357757253 1.5
# Beta remains the same
# 887 -80.6 0.004561871352382651 1.5
# Beta remains the same
# 888 -90.6 0.004477979661823016 1.5
# Decreasing beta
# 889 -78.4 0.0012691639933982046 1.0
# Beta remains the same
# 890 -76.6 0.004553887166847914 1.0
# Beta remains the same
# 891 -83.0 0.003814990020534827 1.0
# Beta remains the same
# 892 -88.8 0.005443444321429561 1.0
# Increasing beta
# 893 -77.8 0.011672246737918881 1.5
# Decreasing beta
# 894 -87.2 0.001767411945562364 1.0
# Beta is too small
# Increasing beta
# 895 -84.8 0.020989958970852568 1.5
# Decreasing beta
# 896 -89.6 0.0020667362673130268 1.0
# Increasing beta
# 897 -81.8 0.012950211674025904 1.5
# Decreasing beta
# 898 -78.0 0.0013762074096381816 1.0
# Beta is too small
# Increasing beta
# 899 -88.4 0.02214252104520737 1.5
# Beta remains the same
# 900 -78.2 0.00635653873592485 1.5
# Beta remains the same
# 901 -97.8 0.008961688135420972 1.5
# Beta remains the same
# 902 -78.4 0.002787227225674294 1.5
# Beta remains the same
# 903 -89.6 0.0025808836604252067 1.5
# Beta remains the same
# 904 -72.8 0.002643164329593397 1.5
# Beta remains the same
# 905 -80.8 0.002581407357071029 1.5
# Decreasing beta
# 906 -70.4 0.0016163736894412384 1.0
# Beta remains the same
# 907 -88.2 0.003085532787957219 1.0
# Beta remains the same
# 908 -76.6 0.0026117139916160275 1.0
# Beta remains the same
# 909 -76.8 0.006910441234760972 1.0
# Beta remains the same
# 910 -87.2 0.005866769602499215 1.0
# Beta remains the same
# 911 -91.4 0.0028273506654027374 1.0
# Beta is too small
# Increasing beta
# 912 -72.8 0.020383313294370736 1.5
# Decreasing beta
# 913 -85.0 0.0021408572481002386 1.0
# Beta remains the same
# 914 -91.0 0.002615765200703986 1.0
# Increasing beta
# 915 -81.8 0.01243197429208954 1.5
# Beta remains the same
# 916 -99.2 0.0025234613349747344 1.5
# Decreasing beta
# 917 -83.8 0.0018712512081268246 1.0
# Beta remains the same
# 918 -88.8 0.0035511192036970364 1.0
# Beta is too small
# Increasing beta
# 919 -100.4 0.026274190207041744 1.5
# Beta remains the same
# 920 -83.2 0.00442828112332391 1.5
# Beta remains the same
# 921 -87.6 0.002638893504992068 1.5
# Decreasing beta
# 922 -79.4 0.002295541049287401 1.0
# Beta remains the same
# 923 -92.2 0.002576312748184095 1.0
# Decreasing beta
# 924 -134.8 0.0019027988993992242 0.6666666666666666
# Beta is too small
# Increasing beta
# 925 -99.2 0.02240619657952214 1.0
# Increasing beta
# 926 -83.6 0.0136949978449601 1.5
# Beta remains the same
# 927 -74.6 0.005501089019136173 1.5
# Decreasing beta
# 928 -112.4 0.0019109141300785346 1.0
# Beta remains the same
# 929 -93.2 0.009971091391476743 1.0
# Increasing beta
# 930 -75.2 0.012679082138764992 1.5
# Decreasing beta
# 931 -105.6 0.0016065521599114923 1.0
# Decreasing beta
# 932 -103.2 0.0009030838547452177 0.6666666666666666
# Increasing beta
# 933 -84.0 0.014743247540254604 1.0
# Beta remains the same
# 934 -105.0 0.008231863072367668 1.0
# Decreasing beta
# 935 -83.0 0.0013831400780411809 0.6666666666666666
# Increasing beta
# 936 -81.0 0.01167157903573719 1.0
# Decreasing beta
# 937 -81.0 0.000921584181908175 0.6666666666666666
# Beta is too small
# Increasing beta
# 938 -90.0 0.02200100922811918 1.0
# Beta remains the same
# 939 -79.4 0.004384907365839903 1.0
# Beta remains the same
# 940 -87.6 0.0028268557789166227 1.0
# Beta remains the same
# 941 -83.0 0.006926424629755921 1.0
# Increasing beta
# 942 -76.4 0.013224201773556528 1.5
# Decreasing beta
# 943 -78.0 0.0018791687688184083 1.0
# Decreasing beta
# 944 -75.0 0.002298901567513112 0.6666666666666666
# Beta is too small
# Increasing beta
# 945 -75.4 0.028644976224060852 1.0
# Beta remains the same
# 946 -87.8 0.00261296313166591 1.0
# Beta remains the same
# 947 -84.8 0.0048872142629986706 1.0
# Decreasing beta
# 948 -78.0 0.0012993462822055676 0.6666666666666666
# Increasing beta
# 949 -78.4 0.013194256150315694 1.0
# Beta remains the same
# 950 -79.0 0.004181428408189921 1.0
# Beta remains the same
# 951 -73.2 0.0027717935846788997 1.0
# Increasing beta
# 952 -78.8 0.011364722264792584 1.5
# Decreasing beta
# 953 -79.8 0.0021744049200578246 1.0
# Beta remains the same
# 954 -90.0 0.005979826741847569 1.0
# Beta is too small
# Increasing beta
# 955 -82.4 0.02477990798402459 1.5
# Beta remains the same
# 956 -80.2 0.009604576811241371 1.5
# Beta remains the same
# 957 -96.0 0.006755106098715985 1.5
# Decreasing beta
# 958 -79.2 0.001698116876304945 1.0
# Beta remains the same
# 959 -83.2 0.005503299017092022 1.0
# Beta remains the same
# 960 -100.2 0.005309132610501493 1.0
# Beta is too small
# Increasing beta
# 961 -75.4 0.020595908447183318 1.5
# Decreasing beta
# 962 -82.8 0.001682308030835295 1.0
# Decreasing beta
# 963 -91.2 0.0013521244550671126 0.6666666666666666
# Decreasing beta
# 964 -93.0 0.0017366107590714205 0.4444444444444444
# Increasing beta
# 965 -79.4 0.01773656268748988 0.6666666666666666
# Beta remains the same
# 966 -81.4 0.0030168437653799135 0.6666666666666666
# Beta remains the same
# 967 -85.2 0.004703167762409724 0.6666666666666666
# Increasing beta
# 968 -78.2 0.01024822877748108 1.0
# Decreasing beta
# 969 -78.4 0.0019191576300829597 0.6666666666666666
# Increasing beta
# 970 -78.4 0.010577471227964206 1.0
# Beta remains the same
# 971 -82.8 0.0032820589993946023 1.0
# Increasing beta
# 972 -75.6 0.013650315708702775 1.5
# Beta remains the same
# 973 -87.6 0.002562876205020149 1.5
# Decreasing beta
# 974 -86.4 0.0020185384214384964 1.0
# Beta remains the same
# 975 -78.0 0.0074886594279181045 1.0
# Beta remains the same
# 976 -75.0 0.008738183925491423 1.0
# Decreasing beta
# 977 -87.2 0.0013572078753808204 0.6666666666666666
# Beta remains the same
# 978 -81.0 0.0066410024765772135 0.6666666666666666
# Decreasing beta
# 979 -94.6 0.002270782678125569 0.4444444444444444
# Beta remains the same
# 980 -80.2 0.00671040668672041 0.4444444444444444
# Increasing beta
# 981 -77.6 0.01416491374014375 0.6666666666666666
# Beta remains the same
# 982 -71.4 0.006961766969727823 0.6666666666666666
# Decreasing beta
# 983 -80.2 0.0018009376404594262 0.4444444444444444
# Beta is too small
# Increasing beta
# 984 -76.4 0.023337831830543724 0.6666666666666666
# Beta is too small
# Increasing beta
# 985 -77.2 0.02446062170041436 1.0
# Increasing beta
# 986 -80.2 0.01209111100720479 1.5
# Decreasing beta
# 987 -88.4 0.0012901920210564928 1.0
# Decreasing beta
# 988 -79.8 0.001445591926676234 0.6666666666666666
# Beta remains the same
# 989 -119.8 0.004029618919235201 0.6666666666666666
# Decreasing beta
# 990 -81.4 0.002131719906470694 0.4444444444444444
# Beta remains the same
# 991 -89.6 0.0071822584044693135 0.4444444444444444
# Beta remains the same
# 992 -79.6 0.006415533158925852 0.4444444444444444
# Beta is too small
# Increasing beta
# 993 -85.4 0.021070080652519314 0.6666666666666666
# Beta remains the same
# 994 -81.6 0.0034737397676986616 0.6666666666666666
# Increasing beta
# 995 -78.2 0.01111501352494946 1.0
# Increasing beta
# 996 -87.2 0.016093583036942378 1.5
# Beta remains the same
# 997 -78.2 0.0032816577657514487 1.5
# Increasing beta
# 998 -97.6 0.015594613461995687 2.25
# Decreasing beta
# 999 -77.8 0.001844378177322228 1.5
# Decreasing beta
# 1000 -76.0 0.0016819328274061654 1.0
# CPU times: user 9min 51s, sys: 3min 49s, total: 13min 41s
# Wall time: 8min 28s

# %%
traj = play_game(agent, render=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(results)
plt.show()
